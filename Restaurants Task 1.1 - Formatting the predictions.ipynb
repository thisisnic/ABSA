# %% [markdown]
# In this notebook, I will convert the data into a format suitable for using with the linear chain CRF library.  The format in question is IOB format and is used to tag individual tokens within sentences.  Tokens at the beginning of an aspect phrase are tagged as 'B'; tokens within an aspect phrase but not at the beginning are tagged as 'I', and tokens not belonging to an aspect phrase are tagged as 'O'.

# %%
import pickle
with open('restaurant.pickle', 'rb') as handle:
    data = pickle.load(handle)

# %%
data
# Out:
#         id                                               text  \
# 0     3121               But the staff was so horrible to us.
# 1     2777  To be completely fair, the only redeeming fact...
# 2     1634  The food is uniformly exceptional, with a very...
# 3     2534  Where Gabriela personaly greets you and recomm...
# 4      583  For those that go once and don't enjoy it, all...
# ...    ...                                                ...
# 3039  1063                     But that is highly forgivable.
# 3040   777  From the appetizers we ate, the dim sum and ot...
# 3041   875  When we arrived at 6:00 PM, the restaurant was...
# 3042   671  Each table has a pot of boiling water sunken i...
# 3043   617          I am going to the mid town location next.
#
#                                            aspect_terms  \
# 0     [{'term': 'staff', 'polarity': 'negative', 'fr...
# 1     [{'term': 'food', 'polarity': 'positive', 'fro...
# 2     [{'term': 'food', 'polarity': 'positive', 'fro...
# 3                                                    []
# 4                                                    []
# ...                                                 ...
# 3039                                                 []
# 3040  [{'term': 'appetizers', 'polarity': 'positive'...
# 3041                                                 []
# 3042  [{'term': 'table', 'polarity': 'neutral', 'fro...
# 3043                                                 []
#
#                                       aspect_categories
# 0     [{'category': 'service', 'polarity': 'negative'}]
# 1     [{'category': 'food', 'polarity': 'positive'},...
# 2        [{'category': 'food', 'polarity': 'positive'}]
# 3     [{'category': 'service', 'polarity': 'positive'}]
# 4     [{'category': 'anecdotes/miscellaneous', 'pola...
# ...                                                 ...
# 3039  [{'category': 'anecdotes/miscellaneous', 'pola...
# 3040     [{'category': 'food', 'polarity': 'positive'}]
# 3041  [{'category': 'anecdotes/miscellaneous', 'pola...
# 3042      [{'category': 'food', 'polarity': 'neutral'}]
# 3043  [{'category': 'anecdotes/miscellaneous', 'pola...
#
# [3044 rows x 4 columns]

# %%
data["aspect_terms"][0]
# Out:
# [{'term': 'staff', 'polarity': 'negative', 'from': 8, 'to': 13}]

# %% [markdown]
# The first thing I want to do is go from the from fields as represented here; as a character span, to updated fields, represented as a token span.
#
# I think that the only sane way to do this, is for each token we also need its character span in the sentence so then we can match them up.
#
# I suppose the way to do it would literally to be to find the indices of the span in the sentence that matches the current token. If there is a single match then that's fine. If there are multiple matches, use some sort of counter to detect current state (i.e. perhaps use the spans of the previous and next detected words as upper and lower bounds) in order to resolve it. If there are no matches, we probably have a data error.

# %%
import spacy
nlp = spacy.load("en_core_web_lg")

# %%
def check_perfect_match(doc, aspects):
    """ Detect if we can find the aspects as a direct match """ 
    detected = [x.text for x in doc for aspect in aspects if x.text == aspect['term']]
    match = set([x['term'] for x in aspects]) == set(detected)
    return match

# %% [markdown]
# OK, let's test out this function on one of the rows in our data - can we match the aspects to the tokens in the sentence?

# %%
i = 5
sentence = data["text"][i]
doc = nlp(sentence)
aspects = data["aspect_terms"][i]

print(doc)
print(aspects)
check_perfect_match(doc, aspects)
# Out:
# Not only was the food outstanding, but the little 'perks' were great.
# [{'term': 'food', 'polarity': 'positive', 'from': 17, 'to': 21}, {'term': 'perks', 'polarity': 'positive', 'from': 51, 'to': 56}]
# True

# %% [markdown]
# That seems to have worked! Let's go through our data and see if this works for every row or not.

# %%
# find the ones we can't match
for i in range(len(data)):
    sentence = data["text"][i]
    doc = nlp(sentence)
    aspects = data["aspect_terms"][i]
    match = check_perfect_match(doc, aspects)
    if not match:
        print(i)
# Out:
# 7
# 16
# 26
# 28
# 31
# 32
# 41
# 48
# 50
# 51
# 52
# 54
# 57
# 59
# 60
# 69
# 72
# 77
# 82
# 93
# 105
# 106
# 108
# 114
# 121
# 126
# 127
# 129
# 130
# 133
# 134
# 135
# 136
# 141
# 142
# 146
# 147
# 149
# 150
# 152
# 153
# 160
# 162
# 165
# 169
# 170
# 176
# 177
# 185
# 187
# 188
# 195
# 198
# 199
# 204
# 208
# 220
# 221
# 226
# 230
# 232
# 235
# 239
# 242
# 246
# 252
# 253
# 254
# 258
# 259
# 262
# 269
# 275
# 279
# 282
# 283
# 284
# 285
# 293
# 294
# 298
# 302
# 305
# 314
# 324
# 330
# 332
# 336
# 338
# 343
# 347
# 349
# 359
# 361
# 380
# 388
# 391
# 392
# 393
# 404
# 407
# 410
# 414
# 415
# 416
# 417
# 424
# 433
# 435
# 442
# 443
# 448
# 450
# 452
# 455
# 458
# 462
# 467
# 477
# 489
# 500
# 502
# 507
# 508
# 513
# 514
# 515
# 517
# 519
# 526
# 528
# 534
# 538
# 539
# 540
# 541
# 547
# 549
# 555
# 561
# 575
# 577
# 589
# 593
# 601
# 604
# 605
# 616
# 618
# 627
# 629
# 631
# 633
# 636
# 642
# 643
# 653
# 661
# 662
# 664
# 667
# 670
# 675
# 677
# 682
# 685
# 686
# 687
# 694
# 697
# 699
# 700
# 703
# 705
# 708
# 710
# 716
# 717
# 721
# 730
# 733
# 735
# 736
# 738
# 744
# 746
# 748
# 753
# 756
# 762
# 771
# 779
# 780
# 781
# 785
# 788
# 789
# 790
# 791
# 802
# 806
# 807
# 815
# 817
# 820
# 821
# 828
# 832
# 841
# 843
# 844
# 846
# 847
# 848
# 854
# 857
# 858
# 861
# 866
# 867
# 870
# 871
# 877
# 879
# 882
# 883
# 886
# 898
# 899
# 902
# 904
# 910
# 916
# 917
# 919
# 920
# 926
# 934
# 939
# 940
# 950
# 951
# 952
# 954
# 956
# 960
# 966
# 968
# 972
# 975
# 978
# 980
# 983
# 985
# 986
# 997
# 1009
# 1011
# 1012
# 1016
# 1017
# 1018
# 1020
# 1021
# 1024
# 1029
# 1037
# 1041
# 1042
# 1044
# 1046
# 1047
# 1058
# 1062
# 1066
# 1068
# 1071
# 1074
# 1084
# 1085
# 1087
# 1091
# 1092
# 1096
# 1099
# 1105
# 1107
# 1112
# 1118
# 1124
# 1125
# 1127
# 1131
# 1132
# 1134
# 1139
# 1140
# 1145
# 1147
# 1153
# 1160
# 1165
# 1167
# 1173
# 1177
# 1183
# 1187
# 1197
# 1198
# 1199
# 1203
# 1205
# 1208
# 1210
# 1211
# 1215
# 1216
# 1217
# 1226
# 1227
# 1228
# 1229
# 1231
# 1234
# 1235
# 1237
# 1240
# 1241
# 1242
# 1244
# 1251
# 1252
# 1256
# 1259
# 1262
# 1264
# 1267
# 1273
# 1277
# 1282
# 1283
# 1287
# 1289
# 1292
# 1298
# 1303
# 1306
# 1310
# 1312
# 1317
# 1321
# 1322
# 1326
# 1337
# 1339
# 1343
# 1346
# 1351
# 1354
# 1361
# 1365
# 1367
# 1370
# 1371
# 1375
# 1391
# 1400
# 1409
# 1415
# 1416
# 1421
# 1422
# 1434
# 1436
# 1438
# 1439
# 1442
# 1457
# 1460
# 1462
# 1478
# 1479
# 1481
# 1496
# 1500
# 1503
# 1504
# 1510
# 1519
# 1520
# 1523
# 1524
# 1526
# 1527
# 1533
# 1537
# 1538
# 1549
# 1551
# 1555
# 1557
# 1561
# 1565
# 1574
# 1579
# 1602
# 1604
# 1613
# 1619
# 1620
# 1623
# 1626
# 1627
# 1630
# 1635
# 1636
# 1641
# 1642
# 1645
# 1650
# 1651
# 1652
# 1654
# 1655
# 1656
# 1660
# 1664
# 1669
# 1673
# 1674
# 1676
# 1680
# 1684
# 1691
# 1694
# 1702
# 1706
# 1708
# 1711
# 1712
# 1717
# 1719
# 1731
# 1745
# 1749
# 1760
# 1762
# 1768
# 1774
# 1775
# 1776
# 1783
# 1784
# 1787
# 1790
# 1794
# 1799
# 1801
# 1804
# 1810
# 1811
# 1821
# 1823
# 1829
# 1831
# 1832
# 1833
# 1834
# 1835
# 1838
# 1854
# 1873
# 1876
# 1882
# 1885
# 1886
# 1891
# 1898
# 1902
# 1905
# 1906
# 1914
# 1916
# 1919
# 1921
# 1925
# 1930
# 1934
# 1944
# 1958
# 1959
# 1961
# 1965
# 1966
# 1973
# 1978
# 1984
# 1985
# 1990
# 1991
# 1992
# 1996
# 2000
# 2006
# 2008
# 2009
# 2012
# 2014
# 2016
# 2025
# 2029
# 2047
# 2048
# 2052
# 2053
# 2056
# 2069
# 2071
# 2079
# 2080
# 2081
# 2085
# 2086
# 2089
# 2092
# 2093
# 2098
# 2099
# 2100
# 2106
# 2109
# 2112
# 2115
# 2123
# 2126
# 2127
# 2128
# 2131
# 2139
# 2142
# 2146
# 2148
# 2154
# 2158
# 2160
# 2163
# 2164
# 2167
# 2172
# 2185
# 2188
# 2194
# 2202
# 2203
# 2204
# 2206
# 2209
# 2223
# 2241
# 2244
# 2245
# 2248
# 2250
# 2251
# 2260
# 2261
# 2267
# 2271
# 2274
# 2276
# 2277
# 2284
# 2287
# 2291
# 2294
# 2299
# 2302
# 2313
# 2324
# 2338
# 2340
# 2341
# 2347
# 2353
# 2354
# 2356
# 2357
# 2362
# 2372
# 2377
# 2402
# 2405
# 2421
# 2425
# 2435
# 2439
# 2440
# 2448
# 2450
# 2452
# 2457
# 2461
# 2477
# 2480
# 2484
# 2487
# 2493
# 2494
# 2495
# 2497
# 2499
# 2501
# 2504
# 2515
# 2517
# 2530
# 2543
# 2545
# 2556
# 2557
# 2575
# 2582
# 2585
# 2586
# 2587
# 2589
# 2595
# 2599
# 2609
# 2629
# 2630
# 2639
# 2641
# 2646
# 2650
# 2656
# 2657
# 2662
# 2665
# 2681
# 2683
# 2684
# 2688
# 2690
# 2691
# 2692
# 2699
# 2707
# 2712
# 2725
# 2732
# 2737
# 2752
# 2760
# 2762
# 2764
# 2771
# 2772
# 2773
# 2774
# 2779
# 2787
# 2794
# 2800
# 2806
# 2809
# 2819
# 2820
# 2822
# 2833
# 2834
# 2836
# 2841
# 2843
# 2844
# 2849
# 2853
# 2855
# 2857
# 2860
# 2862
# 2866
# 2869
# 2874
# 2877
# 2879
# 2883
# 2888
# 2890
# 2894
# 2895
# 2898
# 2901
# 2905
# 2907
# 2916
# 2920
# 2926
# 2927
# 2930
# 2931
# 2933
# 2935
# 2945
# 2948
# 2949
# 2950
# 2952
# 2955
# 2970
# 2972
# 2973
# 2978
# 2981
# 2986
# 2992
# 2996
# 3003
# 3005
# 3006
# 3007
# 3019
# 3037
# 3038
# 3040
# 3042

# %% [markdown]
# There are lots of mismatches!  Let's look deeper at one of them to find the source(s) of error.

# %%
i = 16
sentence = data["text"][i]
doc = nlp(sentence)
aspects = data["aspect_terms"][i]
print(sentence)
print(aspects)
# Out:
# The pizza is the best if you like thin crusted pizza.
# [{'term': 'pizza', 'polarity': 'positive', 'from': 4, 'to': 9}, {'term': 'thin crusted pizza', 'polarity': 'neutral', 'from': 34, 'to': 52}]

# %% [markdown]
# OK, so this method doesn't pick up multiword phrases.  I suppose the way to do it would be to split the aspect term using spacy so that there should be a perfect match in terms of tokenisation between the aspect term and the sentence, and then detect the first word and move iteratively.

# %%
doc
# Out:
# The pizza is the best if you like thin crusted pizza.

# %%
j = 1
phrase = nlp(aspects[j]['term'])

# %%
def find_phrase(doc, phrase):
    phrase_position = 0
    sentence_position = 0

    tagged_tokens = []
    # while we are not at the end of the sentence and have not detected the full phrase
    while(sentence_position < len(doc) and phrase_position < len(phrase)):
        current_target = phrase[phrase_position]
        current_token = doc[sentence_position]
        if current_token.text == current_target.text:
            if phrase_position == 0:
                tagged_tokens.append((current_token.text, 'B'))
            else:
                tagged_tokens.append((current_token, 'I'))

            phrase_position += 1
            sentence_position += 1

        else:
            tagged_tokens.append((current_token, 'O'))
            sentence_position +=1

    return tagged_tokens

find_phrase(doc, phrase)
# Out:
# [(The, 'O'),
#  (pizza, 'O'),
#  (is, 'O'),
#  (the, 'O'),
#  (best, 'O'),
#  (if, 'O'),
#  (you, 'O'),
#  (like, 'O'),
#  ('thin', 'B'),
#  (crusted, 'I'),
#  (pizza, 'I')]

# %% [markdown]
# The problem we now have is that if we have 2 phrases, we want to search for the first one (as they are ordered, and then upon its termination, search immediately for the next one. This will prevent us having multiple matches
#
# Before we make life too complicated, can we do this with spacy? I think I recall spacy tokens having an attribute representing their position in a sentence.

# %%
[(token.text, token.idx) for token in doc]
# Out:
# [('The', 0),
#  ('pizza', 4),
#  ('is', 10),
#  ('the', 13),
#  ('best', 17),
#  ('if', 22),
#  ('you', 25),
#  ('like', 29),
#  ('thin', 34),
#  ('crusted', 39),
#  ('pizza', 47),
#  ('.', 52)]

# %% [markdown]
# Yup! We have the token.idx property and the numbers match! Let's write a function that works with this instead!
#
# I ended up going with a list of dicts in the end as that's the format that the CRF code expects, and it makes the logic of the code flow better than it did with a list of tuples

# %%
tagged_tokens = [{"token": token, "iob_tag": 'O'} for token in doc]

# Use this function if anything goes wrong with the character one
def tag_phrase_backup(tokens, phrase, char_from, char_to):
    
    # initialise as untagged

    phrase_position = 0
    sentence_position = 0
    
    # while we are not at the end of the sentence and have not detected the full phrase
    while(sentence_position < len(tokens) and phrase_position < len(phrase)):
        current_target = phrase[phrase_position]
        current_token = tokens[sentence_position]
        
        if current_token["token"].text == current_target.text:
            if phrase_position == 0:
                current_token["iob_tag"] = "B"
            else:
                current_token["iob_tag"] = "I"

            phrase_position += 1
            sentence_position += 1

        else:
            sentence_position +=1
            
    return tokens

def tag_phrase(tokens, phrase, char_from, char_to):
    
    for current_token in tokens:
        if current_token["token"].idx == char_from:
            current_token["iob_tag"] = "B"
        elif char_to > current_token["token"].idx > char_from:
            current_token["iob_tag"] = "I"
        elif char_to < current_token["token"].idx:
            break
            

    return tokens

# %%
for aspect in aspects:
    char_from = aspect["from"]
    char_to = aspect["to"]
    tagged_tokens = tag_phrase(tagged_tokens, phrase, char_from, char_to)
tagged_tokens
# Out:
# [{'token': The, 'iob_tag': 'O'},
#  {'token': pizza, 'iob_tag': 'B'},
#  {'token': is, 'iob_tag': 'O'},
#  {'token': the, 'iob_tag': 'O'},
#  {'token': best, 'iob_tag': 'O'},
#  {'token': if, 'iob_tag': 'O'},
#  {'token': you, 'iob_tag': 'O'},
#  {'token': like, 'iob_tag': 'O'},
#  {'token': thin, 'iob_tag': 'B'},
#  {'token': crusted, 'iob_tag': 'I'},
#  {'token': pizza, 'iob_tag': 'I'},
#  {'token': ., 'iob_tag': 'O'}]

# %% [markdown]
# Let's check that we have the same number of words tagged in each. As we have used the from and to fields for the tagging, we don't need to check the sets.

# %%
def check_tags(tagged_tokens, aspects):
    word_count_tags = len([x['iob_tag'] for x in tagged_tokens if x['iob_tag'] in ['B', 'I']])
    term_lengths = sum([len(nlp(x['term'])) for x in aspects])
    return word_count_tags == term_lengths

# %%
check_tags(tagged_tokens, aspects)
# Out:
# True

# %% [markdown]
# And now let's test out our tagging method.

# %%
token_list = []
for i in range(len(data)):
    
    # extract row components
    sentence = data["text"][i]
    doc = nlp(sentence)
    aspects = data["aspect_terms"][i]
    tagged_tokens = [{"token": token, "iob_tag": 'O'} for token in doc]

    # cycle through all aspects
    for aspect in aspects:
        char_from = aspect["from"]
        char_to = aspect["to"]
        tagged_tokens = tag_phrase(tagged_tokens, phrase, char_from, char_to)
    
    # check aspects and tags match
    if not check_tags(tagged_tokens, aspects):
        print("Mismatch on row " + str(i))
    else:
        token_list.append(tagged_tokens)

# %%
token_list
# Out:
# [[{'token': But, 'iob_tag': 'O'},
#   {'token': the, 'iob_tag': 'O'},
#   {'token': staff, 'iob_tag': 'B'},
#   {'token': was, 'iob_tag': 'O'},
#   {'token': so, 'iob_tag': 'O'},
#   {'token': horrible, 'iob_tag': 'O'},
#   {'token': to, 'iob_tag': 'O'},
#   {'token': us, 'iob_tag': 'O'},
#   {'token': ., 'iob_tag': 'O'}],
#  [{'token': To, 'iob_tag': 'O'},
#   {'token': be, 'iob_tag': 'O'},
#   {'token': completely, 'iob_tag': 'O'},
#   {'token': fair, 'iob_tag': 'O'},
#   {'token': ,, 'iob_tag': 'O'},
#   {'token': the, 'iob_tag': 'O'},
#   {'token': only, 'iob_tag': 'O'},
#   {'token': redeeming, 'iob_tag': 'O'},
#   {'token': factor, 'iob_tag': 'O'},
#   {'token': was, 'iob_tag': 'O'},
#   {'token': the, 'iob_tag': 'O'},
#   {'token': food, 'iob_tag': 'B'},
#   {'token': ,, 'iob_tag': 'O'},
#   {'token': which, 'iob_tag': 'O'},
#   {'token': was, 'iob_tag': 'O'},
#   {'token': above, 'iob_tag': 'O'},
#   {'token': average, 'iob_tag': 'O'},
#   {'token': ,, 'iob_tag': 'O'},
#   {'token': but, 'iob_tag': 'O'},
#   {'token': could, 'iob_tag': 'O'},
#   {'token': n't, 'iob_tag': 'O'},
#   {'token': make, 'iob_tag': 'O'},
#   {'token': up, 'iob_tag': 'O'},
#   {'token': for, 'iob_tag': 'O'},
#   {'token': all, 'iob_tag': 'O'},
#   {'token': the, 'iob_tag': 'O'},
#   {'token': other, 'iob_tag': 'O'},
#   {'token': deficiencies, 'iob_tag': 'O'},
#   {'token': of, 'iob_tag': 'O'},
#   {'token': Teodora, 'iob_tag': 'O'},
#   {'token': ., 'iob_tag': 'O'}],
#  [{'token': The, 'iob_tag': 'O'},
#   {'token': food, 'iob_tag': 'B'},
#   {'token': is, 'iob_tag': 'O'},
#   {'token': uniformly, 'iob_tag': 'O'},
#   {'token': exceptional, 'iob_tag': 'O'},
#   {'token': ,, 'iob_tag': 'O'},
#   {'token': with, 'iob_tag': 'O'},
#   {'token': a, 'iob_tag': 'O'},
#   {'token': very, 'iob_tag': 'O'},
#   {'token': capable, 'iob_tag': 'O'},
#   {'token': kitchen, 'iob_tag': 'B'},
#   {'token': which, 'iob_tag': 'O'},
#   {'token': will, 'iob_tag': 'O'},
#   {'token': proudly, 'iob_tag': 'O'},
#   {'token': whip, 'iob_tag': 'O'},
#   {'token': up, 'iob_tag': 'O'},
#   {'token': whatever, 'iob_tag': 'O'},
#   {'token': you, 'iob_tag': 'O'},
#   {'token': feel, 'iob_tag': 'O'},
#   {'token': like, 'iob_tag': 'O'},
#   {'token': eating, 'iob_tag': 'O'},
#   {'token': ,, 'iob_tag': 'O'},
#   {'token': whether, 'iob_tag': 'O'},
#   {'token': it, 'iob_tag': 'O'},
#   {'token': 's, 'iob_tag': 'O'},
#   {'token': on, 'iob_tag': 'O'},
#   {'token': the, 'iob_tag': 'O'},
#   {'token': menu, 'iob_tag': 'B'},
#   {'token': or, 'iob_tag': 'O'},
#   {'token': not, 'iob_tag': 'O'},
#   {'token': ., 'iob_tag': 'O'}],
#  [{'token': Where, 'iob_tag': 'O'},
#   {'token': Gabriela, 'iob_tag': 'O'},
#   {'token': personaly, 'iob_tag': 'O'},
#   {'token': greets, 'iob_tag': 'O'},
#   {'token': you, 'iob_tag': 'O'},
#   {'token': and, 'iob_tag': 'O'},
#   {'token': recommends, 'iob_tag': 'O'},
#   {'token': you, 'iob_tag': 'O'},
#   {'token': what, 'iob_tag': 'O'},
#   {'token': to, 'iob_tag': 'O'},
#   {'token': eat, 'iob_tag': 'O'},
#   {'token': ., 'iob_tag': 'O'}],
#  [{'token': For, 'iob_tag': 'O'},
#   {'token': those, 'iob_tag': 'O'},
#   {'token': that, 'iob_tag': 'O'},
#   {'token': go, 'iob_tag': 'O'},
#   {'token': once, 'iob_tag': 'O'},
#   {'token': and, 'iob_tag': 'O'},
#   {'token': do, 'iob_tag': 'O'},
#   {'token': n't, 'iob_tag': 'O'},
#   {'token': enjoy, 'iob_tag': 'O'},
#   {'token': it, 'iob_tag': 'O'},
#   {'token': ,, 'iob_tag': 'O'},
#   {'token': all, 'iob_tag': 'O'},
#   {'token': I, 'iob_tag': 'O'},
#   {'token': can, 'iob_tag': 'O'},
#   {'token': say, 'iob_tag': 'O'},
#   {'token': is, 'iob_tag': 'O'},
#   {'token': that, 'iob_tag': 'O'},
#   {'token': they, 'iob_tag': 'O'},
#   {'token': just, 'iob_tag': 'O'},
#   {'token': do, 'iob_tag': 'O'},
#   {'token': n't, 'iob_tag': 'O'},
#   {'token': get, 'iob_tag': 'O'},
#   {'token': it, 'iob_tag': 'O'},
#   {'token': ., 'iob_tag': 'O'}],
#  [{'token': Not, 'iob_tag': 'O'},
#   {'token': only, 'iob_tag': 'O'},
#   {'token': was, 'iob_tag': 'O'},
#   {'token': the, 'iob_tag': 'O'},
#   {'token': food, 'iob_tag': 'B'},
#   {'token': outstanding, 'iob_tag': 'O'},
#   {'token': ,, 'iob_tag': 'O'},
#   {'token': but, 'iob_tag': 'O'},
#   {'token': the, 'iob_tag': 'O'},
#   {'token': little, 'iob_tag': 'O'},
#   {'token': ', 'iob_tag': 'O'},
#   {'token': perks, 'iob_tag': 'B'},
#   {'token': ', 'iob_tag': 'O'},
#   {'token': were, 'iob_tag': 'O'},
#   {'token': great, 'iob_tag': 'O'},
#   {'token': ., 'iob_tag': 'O'}],
#  [{'token': It, 'iob_tag': 'O'},
#   {'token': is, 'iob_tag': 'O'},
#   {'token': very, 'iob_tag': 'O'},
#   {'token': overpriced, 'iob_tag': 'O'},
#   {'token': and, 'iob_tag': 'O'},
#   {'token': not, 'iob_tag': 'O'},
#   {'token': very, 'iob_tag': 'O'},
#   {'token': tasty, 'iob_tag': 'O'},
#   {'token': ., 'iob_tag': 'O'}],
#  [{'token': Our, 'iob_tag': 'O'},
#   {'token': agreed, 'iob_tag': 'O'},
#   {'token': favorite, 'iob_tag': 'O'},
#   {'token': is, 'iob_tag': 'O'},
#   {'token': the, 'iob_tag': 'O'},
#   {'token': orrechiete, 'iob_tag': 'B'},
#   {'token': with, 'iob_tag': 'I'},
#   {'token': sausage, 'iob_tag': 'I'},
#   {'token': and, 'iob_tag': 'I'},
#   {'token': chicken, 'iob_tag': 'I'},
#   {'token': (, 'iob_tag': 'O'},
#   {'token': usually, 'iob_tag': 'O'},
#   {'token': the, 'iob_tag': 'O'},
#   {'token': waiters, 'iob_tag': 'B'},
#   {'token': are, 'iob_tag': 'O'},
#   {'token': kind, 'iob_tag': 'O'},
#   {'token': enough, 'iob_tag': 'O'},
#   {'token': to, 'iob_tag': 'O'},
#   {'token': split, 'iob_tag': 'O'},
#   {'token': the, 'iob_tag': 'O'},
#   {'token': dish, 'iob_tag': 'B'},
#   {'token': in, 'iob_tag': 'O'},
#   {'token': half, 'iob_tag': 'O'},
#   {'token': so, 'iob_tag': 'O'},
#   {'token': you, 'iob_tag': 'O'},
#   {'token': get, 'iob_tag': 'O'},
#   {'token': to, 'iob_tag': 'O'},
#   {'token': sample, 'iob_tag': 'O'},
#   {'token': both, 'iob_tag': 'O'},
#   {'token': meats, 'iob_tag': 'B'},
#   {'token': ), 'iob_tag': 'O'},
#   {'token': ., 'iob_tag': 'O'}],
#  [{'token': The, 'iob_tag': 'O'},
#   {'token': Bagels, 'iob_tag': 'B'},
#   {'token': have, 'iob_tag': 'O'},
#   {'token': an, 'iob_tag': 'O'},
#   {'token': outstanding, 'iob_tag': 'O'},
#   {'token': taste, 'iob_tag': 'O'},
#   {'token': with, 'iob_tag': 'O'},
#   {'token': a, 'iob_tag': 'O'},
#   {'token': terrific, 'iob_tag': 'O'},
#   {'token': texture, 'iob_tag': 'O'},
#   {'token': ,, 'iob_tag': 'O'},
#   {'token': both, 'iob_tag': 'O'},
#   {'token': chewy, 'iob_tag': 'O'},
#   {'token': yet, 'iob_tag': 'O'},
#   {'token': not, 'iob_tag': 'O'},
#   {'token': gummy, 'iob_tag': 'O'},
#   {'token': ., 'iob_tag': 'O'}],
#  [{'token': Nevertheless, 'iob_tag': 'O'},
#   {'token': the, 'iob_tag': 'O'},
#   {'token': food, 'iob_tag': 'B'},
#   {'token': itself, 'iob_tag': 'O'},
#   {'token': is, 'iob_tag': 'O'},
#   {'token': pretty, 'iob_tag': 'O'},
#   {'token': good, 'iob_tag': 'O'},
#   {'token': ., 'iob_tag': 'O'}],
#  [{'token': i, 'iob_tag': 'O'},
#   {'token': 've, 'iob_tag': 'O'},
#   {'token': noticed, 'iob_tag': 'O'},
#   {'token': megadeth, 'iob_tag': 'O'},
#   {'token': ,, 'iob_tag': 'O'},
#   {'token': mr, 'iob_tag': 'O'},
#   {'token': ., 'iob_tag': 'O'},
#   {'token': scruff, 'iob_tag': 'O'},
#   {'token': ,, 'iob_tag': 'O'},
#   {'token': st, 'iob_tag': 'O'},
#   {'token': ., 'iob_tag': 'O'},
#   {'token': germain, 'iob_tag': 'O'},
#   {'token': ,, 'iob_tag': 'O'},
#   {'token': traditional, 'iob_tag': 'O'},
#   {'token': vietnamese, 'iob_tag': 'O'},
#   {'token': songs, 'iob_tag': 'B'},
#   {'token': ,, 'iob_tag': 'O'},
#   {'token': black, 'iob_tag': 'O'},
#   {'token': sabbath, 'iob_tag': 'O'},
#   {'token': ,, 'iob_tag': 'O'},
#   {'token': jay, 'iob_tag': 'O'},
#   {'token': -, 'iob_tag': 'O'},
#   {'token': z, 'iob_tag': 'O'},
#   {'token': ,, 'iob_tag': 'O'},
#   {'token': and, 'iob_tag': 'O'},
#   {'token': daft, 'iob_tag': 'O'},
#   {'token': punk, 'iob_tag': 'O'},
#   {'token': all, 'iob_tag': 'O'},
#   {'token': being, 'iob_tag': 'O'},
#   {'token': played, 'iob_tag': 'O'},
#   {'token': ., 'iob_tag': 'O'}],
#  [{'token': They, 'iob_tag': 'O'},
#   {'token': did, 'iob_tag': 'O'},
#   {'token': not, 'iob_tag': 'O'},
#   {'token': have, 'iob_tag': 'O'},
#   {'token': mayonnaise, 'iob_tag': 'B'},
#   {'token': ,, 'iob_tag': 'O'},
#   {'token': forgot, 'iob_tag': 'O'},
#   {'token': our, 'iob_tag': 'O'},
#   {'token': toast, 'iob_tag': 'B'},
#   {'token': ,, 'iob_tag': 'O'},
#   {'token': left, 'iob_tag': 'O'},
#   {'token': out, 'iob_tag': 'O'},
#   {'token': ingredients, 'iob_tag': 'B'},
#   {'token': (, 'iob_tag': 'O'},
#   {'token': ie, 'iob_tag': 'O'},
#   {'token': cheese, 'iob_tag': 'B'},
#   {'token': in, 'iob_tag': 'O'},
#   {'token': an, 'iob_tag': 'O'},
#   {'token': omelet, 'iob_tag': 'B'},
#   {'token': ), 'iob_tag': 'O'},
#   {'token': ,, 'iob_tag': 'O'},
#   {'token': below, 'iob_tag': 'O'},
#   {'token': hot, 'iob_tag': 'O'},
#   {'token': temperatures, 'iob_tag': 'O'},
#   {'token': and, 'iob_tag': 'O'},
#   {'token': the, 'iob_tag': 'O'},
#   {'token': bacon, 'iob_tag': 'B'},
#   {'token': was, 'iob_tag': 'O'},
#   {'token': so, 'iob_tag': 'O'},
#   {'token': over, 'iob_tag': 'O'},
#   {'token': cooked, 'iob_tag': 'O'},
#   {'token': it, 'iob_tag': 'O'},
#   {'token': crumbled, 'iob_tag': 'O'},
#   {'token': on, 'iob_tag': 'O'},
#   {'token': the, 'iob_tag': 'O'},
#   {'token': plate, 'iob_tag': 'B'},
#   {'token': when, 'iob_tag': 'O'},
#   {'token': you, 'iob_tag': 'O'},
#   {'token': touched, 'iob_tag': 'O'},
#   {'token': it, 'iob_tag': 'O'},
#   {'token': ., 'iob_tag': 'O'}],
#  [{'token': It, 'iob_tag': 'O'},
#   {'token': took, 'iob_tag': 'O'},
#   {'token': half, 'iob_tag': 'O'},
#   {'token': an, 'iob_tag': 'O'},
#   {'token': hour, 'iob_tag': 'O'},
#   {'token': to, 'iob_tag': 'O'},
#   {'token': get, 'iob_tag': 'O'},
#   {'token': our, 'iob_tag': 'O'},
#   {'token': check, 'iob_tag': 'B'},
#   {'token': ,, 'iob_tag': 'O'},
#   {'token': which, 'iob_tag': 'O'},
#   {'token': was, 'iob_tag': 'O'},
#   {'token': perfect, 'iob_tag': 'O'},
#   {'token': since, 'iob_tag': 'O'},
#   {'token': we, 'iob_tag': 'O'},
#   {'token': could, 'iob_tag': 'O'},
#   {'token': sit, 'iob_tag': 'O'},
#   {'token': ,, 'iob_tag': 'O'},
#   {'token': have, 'iob_tag': 'O'},
#   {'token': drinks, 'iob_tag': 'B'},
#   {'token': and, 'iob_tag': 'O'},
#   {'token': talk, 'iob_tag': 'O'},
#   {'token': !, 'iob_tag': 'O'}],
#  [{'token': The, 'iob_tag': 'O'},
#   {'token': design, 'iob_tag': 'B'},
#   {'token': and, 'iob_tag': 'O'},
#   {'token': atmosphere, 'iob_tag': 'B'},
#   {'token': is, 'iob_tag': 'O'},
#   {'token': just, 'iob_tag': 'O'},
#   {'token': as, 'iob_tag': 'O'},
#   {'token': good, 'iob_tag': 'O'},
#   {'token': ., 'iob_tag': 'O'}],
#  [{'token': He, 'iob_tag': 'O'},
#   {'token': has, 'iob_tag': 'O'},
#   {'token': visited, 'iob_tag': 'O'},
#   {'token': Thailand, 'iob_tag': 'O'},
#   {'token': and, 'iob_tag': 'O'},
#   {'token': is, 'iob_tag': 'O'},
#   {'token': quite, 'iob_tag': 'O'},
#   {'token': expert, 'iob_tag': 'O'},
#   {'token': on, 'iob_tag': 'O'},
#   {'token': the, 'iob_tag': 'O'},
#   {'token': cuisine, 'iob_tag': 'B'},
#   {'token': ., 'iob_tag': 'O'}],
#  [{'token': I, 'iob_tag': 'O'},
#   {'token': would, 'iob_tag': 'O'},
#   {'token': definitely, 'iob_tag': 'O'},
#   {'token': recommend, 'iob_tag': 'O'},
#   {'token': Mary, 'iob_tag': 'O'},
#   {'token': 's, 'iob_tag': 'O'},
#   {'token': and, 'iob_tag': 'O'},
#   {'token': am, 'iob_tag': 'O'},
#   {'token': making, 'iob_tag': 'O'},
#   {'token': it, 'iob_tag': 'O'},
#   {'token': one, 'iob_tag': 'O'},
#   {'token': of, 'iob_tag': 'O'},
#   {'token': my, 'iob_tag': 'O'},
#   {'token': regular, 'iob_tag': 'O'},
#   {'token': neighborhood, 'iob_tag': 'O'},
#   {'token': haunts, 'iob_tag': 'O'},
#   {'token': ., 'iob_tag': 'O'}],
#  [{'token': The, 'iob_tag': 'O'},
#   {'token': pizza, 'iob_tag': 'B'},
#   {'token': is, 'iob_tag': 'O'},
#   {'token': the, 'iob_tag': 'O'},
#   {'token': best, 'iob_tag': 'O'},
#   {'token': if, 'iob_tag': 'O'},
#   {'token': you, 'iob_tag': 'O'},
#   {'token': like, 'iob_tag': 'O'},
#   {'token': thin, 'iob_tag': 'B'},
#   {'token': crusted, 'iob_tag': 'I'},
#   {'token': pizza, 'iob_tag': 'I'},
#   {'token': ., 'iob_tag': 'O'}],
#  [{'token': My, 'iob_tag': 'O'},
#   {'token': Girlfriend, 'iob_tag': 'O'},
#   {'token': and, 'iob_tag': 'O'},
#   {'token': I, 'iob_tag': 'O'},
#   {'token': stumbled, 'iob_tag': 'O'},
#   {'token': onto, 'iob_tag': 'O'},
#   {'token': this, 'iob_tag': 'O'},
#   {'token': hopping, 'iob_tag': 'O'},
#   {'token': place, 'iob_tag': 'O'},
#   {'token': the, 'iob_tag': 'O'},
#   {'token': other, 'iob_tag': 'O'},
#   {'token': night, 'iob_tag': 'O'},
#   {'token': and, 'iob_tag': 'O'},
#   {'token': had, 'iob_tag': 'O'},
#   {'token': a, 'iob_tag': 'O'},
#   {'token': great, 'iob_tag': 'O'},
#   {'token': time, 'iob_tag': 'O'},
#   {'token': !, 'iob_tag': 'O'}],
#  [{'token': He, 'iob_tag': 'O'},
#   {'token': ca, 'iob_tag': 'O'},
#   {'token': n't, 'iob_tag': 'O'},
#   {'token': help, 'iob_tag': 'O'},
#   {'token': ,, 'iob_tag': 'O'},
#   {'token': they, 'iob_tag': 'O'},
#   {'token': 're, 'iob_tag': 'O'},
#   {'token': bought, 'iob_tag': 'O'},
#   {'token': up, 'iob_tag': 'O'},
#   {'token': so, 'iob_tag': 'O'},
#   {'token': fast, 'iob_tag': 'O'},
#   {'token': ., 'iob_tag': 'O'}],
#  [{'token': Secondly, 'iob_tag': 'O'},
#   {'token': ,, 'iob_tag': 'O'},
#   {'token': on, 'iob_tag': 'O'},
#   {'token': this, 'iob_tag': 'O'},
#   {'token': night, 'iob_tag': 'O'},
#   {'token': the, 'iob_tag': 'O'},
#   {'token': place, 'iob_tag': 'O'},
#   {'token': was, 'iob_tag': 'O'},
#   {'token': overwhelmed, 'iob_tag': 'O'},
#   {'token': by, 'iob_tag': 'O'},
#   {'token': upper, 'iob_tag': 'O'},
#   {'token': east, 'iob_tag': 'O'},
#   {'token': side, 'iob_tag': 'O'},
#   {'token': ladies, 'iob_tag': 'O'},
#   {'token': perfume, 'iob_tag': 'O'},
#   {'token': ., 'iob_tag': 'O'}],
#  [{'token': i, 'iob_tag': 'O'},
#   {'token': have, 'iob_tag': 'O'},
#   {'token': eaten, 'iob_tag': 'O'},
#   {'token': here, 'iob_tag': 'O'},
#   {'token': a, 'iob_tag': 'O'},
#   {'token': handful, 'iob_tag': 'O'},
#   {'token': of, 'iob_tag': 'O'},
#   {'token': times, 'iob_tag': 'O'},
#   {'token': ,, 'iob_tag': 'O'},
#   {'token': for, 'iob_tag': 'O'},
#   {'token': no, 'iob_tag': 'O'},
#   {'token': reason, 'iob_tag': 'O'},
#   {'token': besides, 'iob_tag': 'O'},
#   {'token': sheer, 'iob_tag': 'O'},
#   {'token': convenience, 'iob_tag': 'O'},
#   {'token': ., 'iob_tag': 'O'}],
#  [{'token': Obviously, 'iob_tag': 'O'},
#   {'token': run, 'iob_tag': 'O'},
#   {'token': by, 'iob_tag': 'O'},
#   {'token': folks, 'iob_tag': 'O'},
#   {'token': who, 'iob_tag': 'O'},
#   {'token': know, 'iob_tag': 'O'},
#   {'token': a, 'iob_tag': 'O'},
#   {'token': pie, 'iob_tag': 'O'},
#   {'token': ., 'iob_tag': 'O'}],
#  [{'token': We, 'iob_tag': 'O'},
#   {'token': were, 'iob_tag': 'O'},
#   {'token': very, 'iob_tag': 'O'},
#   {'token': disappointed, 'iob_tag': 'O'},
#   {'token': ., 'iob_tag': 'O'}],
#  [{'token': IT, 'iob_tag': 'O'},
#   {'token': IS, 'iob_tag': 'O'},
#   {'token': DEFINITELY, 'iob_tag': 'O'},
#   {'token': SPECIAL, 'iob_tag': 'O'},
#   {'token': AND, 'iob_tag': 'O'},
#   {'token': AFFORDABLE, 'iob_tag': 'O'},
#   {'token': ., 'iob_tag': 'O'}],
#  [{'token': I, 'iob_tag': 'O'},
#   {'token': really, 'iob_tag': 'O'},
#   {'token': liked, 'iob_tag': 'O'},
#   {'token': this, 'iob_tag': 'O'},
#   {'token': place, 'iob_tag': 'O'},
#   {'token': ., 'iob_tag': 'O'}],
#  [{'token': I, 'iob_tag': 'O'},
#   {'token': will, 'iob_tag': 'O'},
#   {'token': be, 'iob_tag': 'O'},
#   {'token': going, 'iob_tag': 'O'},
#   {'token': back, 'iob_tag': 'O'},
#   {'token': very, 'iob_tag': 'O'},
#   {'token': soon, 'iob_tag': 'O'},
#   {'token': ., 'iob_tag': 'O'}],
#  [{'token': All, 'iob_tag': 'O'},
#   {'token': the, 'iob_tag': 'O'},
#   {'token': money, 'iob_tag': 'O'},
#   {'token': went, 'iob_tag': 'O'},
#   {'token': into, 'iob_tag': 'O'},
#   {'token': the, 'iob_tag': 'O'},
#   {'token': interior, 'iob_tag': 'B'},
#   {'token': decoration, 'iob_tag': 'I'},
#   {'token': ,, 'iob_tag': 'O'},
#   {'token': none, 'iob_tag': 'O'},
#   {'token': of, 'iob_tag': 'O'},
#   {'token': it, 'iob_tag': 'O'},
#   {'token': went, 'iob_tag': 'O'},
#   {'token': to, 'iob_tag': 'O'},
#   {'token': the, 'iob_tag': 'O'},
#   {'token': chefs, 'iob_tag': 'B'},
#   {'token': ., 'iob_tag': 'O'}],
#  [{'token': The, 'iob_tag': 'O'},
#   {'token': seats, 'iob_tag': 'B'},
#   {'token': are, 'iob_tag': 'O'},
#   {'token': uncomfortable, 'iob_tag': 'O'},
#   {'token': if, 'iob_tag': 'O'},
#   {'token': you, 'iob_tag': 'O'},
#   {'token': are, 'iob_tag': 'O'},
#   {'token': sitting, 'iob_tag': 'O'},
#   {'token': against, 'iob_tag': 'O'},
#   {'token': the, 'iob_tag': 'O'},
#   {'token': wall, 'iob_tag': 'O'},
#   {'token': on, 'iob_tag': 'O'},
#   {'token': wooden, 'iob_tag': 'O'},
#   {'token': benches, 'iob_tag': 'O'},
#   {'token': ., 'iob_tag': 'O'}],
#  [{'token': I, 'iob_tag': 'O'},
#   {'token': asked, 'iob_tag': 'O'},
#   {'token': for, 'iob_tag': 'O'},
#   {'token': seltzer, 'iob_tag': 'B'},
#   {'token': with, 'iob_tag': 'I'},
#   {'token': lime, 'iob_tag': 'I'},
#   {'token': ,, 'iob_tag': 'O'},
#   {'token': no, 'iob_tag': 'O'},
#   {'token': ice, 'iob_tag': 'O'},
#   {'token': ., 'iob_tag': 'O'}],
#  [{'token': It, 'iob_tag': 'O'},
#   {'token': was, 'iob_tag': 'O'},
#   {'token': pretty, 'iob_tag': 'O'},
#   {'token': inexpensive, 'iob_tag': 'O'},
#   {'token': too, 'iob_tag': 'O'},
#   {'token': ., 'iob_tag': 'O'}],
#  [{'token': Will, 'iob_tag': 'O'},
#   {'token': not, 'iob_tag': 'O'},
#   {'token': be, 'iob_tag': 'O'},
#   {'token': back, 'iob_tag': 'O'},
#   {'token': ., 'iob_tag': 'O'}],
#  [{'token': Do, 'iob_tag': 'O'},
#   {'token': n't, 'iob_tag': 'O'},
#   {'token': go, 'iob_tag': 'O'},
#   {'token': alone, 'iob_tag': 'O'},
#   {'token': ---, 'iob_tag': 'O'},
#   {'token': even, 'iob_tag': 'O'},
#   {'token': two, 'iob_tag': 'O'},
#   {'token': people, 'iob_tag': 'O'},
#   {'token': is, 'iob_tag': 'O'},
#   {'token': n't, 'iob_tag': 'O'},
#   {'token': enough, 'iob_tag': 'O'},
#   {'token': for, 'iob_tag': 'O'},
#   {'token': the, 'iob_tag': 'O'},
#   {'token': whole, 'iob_tag': 'O'},
#   {'token': experience, 'iob_tag': 'O'},
#   {'token': ,, 'iob_tag': 'O'},
#   {'token': with, 'iob_tag': 'O'},
#   {'token': pickles, 'iob_tag': 'B'},
#   {'token': and, 'iob_tag': 'O'},
#   {'token': a, 'iob_tag': 'O'},
#   {'token': selection, 'iob_tag': 'B'},
#   {'token': of, 'iob_tag': 'I'},
#   {'token': meats, 'iob_tag': 'I'},
#   {'token': and, 'iob_tag': 'I'},
#   {'token': seafoods, 'iob_tag': 'I'},
#   {'token': ., 'iob_tag': 'O'}],
#  [{'token': My, 'iob_tag': 'O'},
#   {'token': suggestion, 'iob_tag': 'O'},
#   {'token': is, 'iob_tag': 'O'},
#   {'token': to, 'iob_tag': 'O'},
#   {'token': eat, 'iob_tag': 'B'},
#   {'token': family, 'iob_tag': 'I'},
#   {'token': style, 'iob_tag': 'I'},
#   {'token': because, 'iob_tag': 'O'},
#   {'token': you, 'iob_tag': 'O'},
#   {'token': 'll, 'iob_tag': 'O'},
#   {'token': want, 'iob_tag': 'O'},
#   {'token': to, 'iob_tag': 'O'},
#   {'token': try, 'iob_tag': 'O'},
#   {'token': the, 'iob_tag': 'O'},
#   {'token': other, 'iob_tag': 'O'},
#   {'token': dishes, 'iob_tag': 'B'},
#   {'token': ., 'iob_tag': 'O'}],
#  [{'token': Best, 'iob_tag': 'O'},
#   {'token': of, 'iob_tag': 'O'},
#   {'token': all, 'iob_tag': 'O'},
#   {'token': is, 'iob_tag': 'O'},
#   {'token': the, 'iob_tag': 'O'},
#   {'token': warm, 'iob_tag': 'O'},
#   {'token': vibe, 'iob_tag': 'B'},
#   {'token': ,, 'iob_tag': 'O'},
#   {'token': the, 'iob_tag': 'O'},
#   {'token': owner, 'iob_tag': 'B'},
#   {'token': is, 'iob_tag': 'O'},
#   {'token': super, 'iob_tag': 'O'},
#   {'token': friendly, 'iob_tag': 'O'},
#   {'token': and, 'iob_tag': 'O'},
#   {'token': service, 'iob_tag': 'B'},
#   {'token': is, 'iob_tag': 'O'},
#   {'token': fast, 'iob_tag': 'O'},
#   {'token': ., 'iob_tag': 'O'}],
#  [{'token': This, 'iob_tag': 'O'},
#   {'token': is, 'iob_tag': 'O'},
#   {'token': n't, 'iob_tag': 'O'},
#   {'token': a, 'iob_tag': 'O'},
#   {'token': value, 'iob_tag': 'O'},
#   {'token': joint, 'iob_tag': 'O'},
#   {'token': ., 'iob_tag': 'O'}],
#  [{'token': Faan, 'iob_tag': 'O'},
#   {'token': 's, 'iob_tag': 'O'},
#   {'token': got, 'iob_tag': 'O'},
#   {'token': a, 'iob_tag': 'O'},
#   {'token': great, 'iob_tag': 'O'},
#   {'token': concept, 'iob_tag': 'O'},
#   {'token': but, 'iob_tag': 'O'},
#   {'token': a, 'iob_tag': 'O'},
#   {'token': little, 'iob_tag': 'O'},
#   {'token': rough, 'iob_tag': 'O'},
#   {'token': on, 'iob_tag': 'O'},
#   {'token': the, 'iob_tag': 'O'},
#   {'token': delivery, 'iob_tag': 'B'},
#   {'token': ., 'iob_tag': 'O'}],
#  [{'token': From, 'iob_tag': 'O'},
#   {'token': the, 'iob_tag': 'O'},
#   {'token': incredible, 'iob_tag': 'O'},
#   {'token': food, 'iob_tag': 'B'},
#   {'token': ,, 'iob_tag': 'O'},
#   {'token': to, 'iob_tag': 'O'},
#   {'token': the, 'iob_tag': 'O'},
#   {'token': warm, 'iob_tag': 'O'},
#   {'token': atmosphere, 'iob_tag': 'B'},
#   {'token': ,, 'iob_tag': 'O'},
#   {'token': to, 'iob_tag': 'O'},
#   {'token': the, 'iob_tag': 'O'},
#   {'token': friendly, 'iob_tag': 'O'},
#   {'token': service, 'iob_tag': 'B'},
#   {'token': ,, 'iob_tag': 'O'},
#   {'token': this, 'iob_tag': 'O'},
#   {'token': downtown, 'iob_tag': 'O'},
#   {'token': neighborhood, 'iob_tag': 'O'},
#   {'token': spot, 'iob_tag': 'O'},
#   {'token': does, 'iob_tag': 'O'},
#   {'token': n't, 'iob_tag': 'O'},
#   {'token': miss, 'iob_tag': 'O'},
#   {'token': a, 'iob_tag': 'O'},
#   {'token': beat, 'iob_tag': 'O'},
#   {'token': ., 'iob_tag': 'O'}],
#  [{'token': Great, 'iob_tag': 'O'},
#   {'token': food, 'iob_tag': 'B'},
#   {'token': at, 'iob_tag': 'O'},
#   {'token': REASONABLE, 'iob_tag': 'O'},
#   {'token': prices, 'iob_tag': 'B'},
#   {'token': ,, 'iob_tag': 'O'},
#   {'token': makes, 'iob_tag': 'O'},
#   {'token': for, 'iob_tag': 'O'},
#   {'token': an, 'iob_tag': 'O'},
#   {'token': evening, 'iob_tag': 'O'},
#   {'token': that, 'iob_tag': 'O'},
#   {'token': ca, 'iob_tag': 'O'},
#   {'token': n't, 'iob_tag': 'O'},
#   {'token': be, 'iob_tag': 'O'},
#   {'token': beat, 'iob_tag': 'O'},
#   {'token': !, 'iob_tag': 'O'}],
#  [{'token': Look, 'iob_tag': 'O'},
#   {'token': foward, 'iob_tag': 'O'},
#   {'token': to, 'iob_tag': 'O'},
#   {'token': trying, 'iob_tag': 'O'},
#   {'token': the, 'iob_tag': 'O'},
#   {'token': Ruben, 'iob_tag': 'O'},
#   {'token': upon, 'iob_tag': 'O'},
#   {'token': returning, 'iob_tag': 'O'},
#   {'token': ., 'iob_tag': 'O'}],
#  [{'token': The, 'iob_tag': 'O'},
#   {'token': only, 'iob_tag': 'O'},
#   {'token': other, 'iob_tag': 'O'},
#   {'token': steakhouse, 'iob_tag': 'O'},
#   {'token': that, 'iob_tag': 'O'},
#   {'token': seems, 'iob_tag': 'O'},
#   {'token': to, 'iob_tag': 'O'},
#   {'token': hold, 'iob_tag': 'O'},
#   {'token': a, 'iob_tag': 'O'},
#   {'token': candle, 'iob_tag': 'O'},
#   {'token': to, 'iob_tag': 'O'},
#   {'token': Roth, 'iob_tag': 'O'},
#   {'token': 's, 'iob_tag': 'O'},
#   {'token': is, 'iob_tag': 'O'},
#   {'token': the, 'iob_tag': 'O'},
#   {'token': Strip, 'iob_tag': 'O'},
#   {'token': House, 'iob_tag': 'O'},
#   {'token': ., 'iob_tag': 'O'}],
#  [{'token': We, 'iob_tag': 'O'},
#   {'token': usually, 'iob_tag': 'O'},
#   {'token': go, 'iob_tag': 'O'},
#   {'token': to, 'iob_tag': 'O'},
#   {'token': the, 'iob_tag': 'O'},
#   {'token': Chart, 'iob_tag': 'O'},
#   {'token': House, 'iob_tag': 'O'},
#   {'token': to, 'iob_tag': 'O'},
#   {'token': celebrate, 'iob_tag': 'O'},
#   {'token': a, 'iob_tag': 'O'},
#   {'token': birthday, 'iob_tag': 'O'},
#   {'token': or, 'iob_tag': 'O'},
#   {'token': anniversary, 'iob_tag': 'O'},
#   {'token': ., 'iob_tag': 'O'}],
#  [{'token': this, 'iob_tag': 'O'},
#   {'token': little, 'iob_tag': 'O'},
#   {'token': place, 'iob_tag': 'O'},
#   {'token': has, 'iob_tag': 'O'},
#   {'token': a, 'iob_tag': 'O'},
#   {'token': cute, 'iob_tag': 'O'},
#   {'token': interior, 'iob_tag': 'B'},
#   {'token': decor, 'iob_tag': 'I'},
#   {'token': and, 'iob_tag': 'O'},
#   {'token': affordable, 'iob_tag': 'O'},
#   {'token': city, 'iob_tag': 'O'},
#   {'token': prices, 'iob_tag': 'B'},
#   {'token': ., 'iob_tag': 'O'}],
#  [{'token': You, 'iob_tag': 'O'},
#   {'token': 'll, 'iob_tag': 'O'},
#   {'token': adore, 'iob_tag': 'O'},
#   {'token': it, 'iob_tag': 'O'},
#   {'token': ., 'iob_tag': 'O'}],
#  [{'token': Two, 'iob_tag': 'O'},
#   {'token': words, 'iob_tag': 'O'},
#   {'token': :, 'iob_tag': 'O'},
#   {'token': Free, 'iob_tag': 'O'},
#   {'token': wine, 'iob_tag': 'B'},
#   {'token': ., 'iob_tag': 'O'}],
#  [{'token': The, 'iob_tag': 'O'},
#   {'token': price, 'iob_tag': 'B'},
#   {'token': is, 'iob_tag': 'O'},
#   {'token': reasonable, 'iob_tag': 'O'},
#   {'token': although, 'iob_tag': 'O'},
#   {'token': the, 'iob_tag': 'O'},
#   {'token': service, 'iob_tag': 'B'},
#   {'token': is, 'iob_tag': 'O'},
#   {'token': poor, 'iob_tag': 'O'},
#   {'token': ., 'iob_tag': 'O'}],
#  [{'token': The, 'iob_tag': 'O'},
#   {'token': quantity, 'iob_tag': 'B'},
#   {'token': is, 'iob_tag': 'O'},
#   {'token': also, 'iob_tag': 'O'},
#   {'token': very, 'iob_tag': 'O'},
#   {'token': good, 'iob_tag': 'O'},
#   {'token': ,, 'iob_tag': 'O'},
#   {'token': you, 'iob_tag': 'O'},
#   {'token': will, 'iob_tag': 'O'},
#   {'token': come, 'iob_tag': 'O'},
#   {'token': out, 'iob_tag': 'O'},
#   {'token': satisfied, 'iob_tag': 'O'},
#   {'token': ., 'iob_tag': 'O'}],
#  [{'token': I, 'iob_tag': 'O'},
#   {'token': have, 'iob_tag': 'O'},
#   {'token': been, 'iob_tag': 'O'},
#   {'token': to, 'iob_tag': 'O'},
#   {'token': Roth, 'iob_tag': 'O'},
#   {'token': 's, 'iob_tag': 'O'},
#   {'token': twice, 'iob_tag': 'O'},
#   {'token': and, 'iob_tag': 'O'},
#   {'token': both, 'iob_tag': 'O'},
#   {'token': times, 'iob_tag': 'O'},
#   {'token': were, 'iob_tag': 'O'},
#   {'token': very, 'iob_tag': 'O'},
#   {'token': disappointing, 'iob_tag': 'O'},
#   {'token': ., 'iob_tag': 'O'}],
#  [{'token': Worth, 'iob_tag': 'O'},
#   {'token': visiting, 'iob_tag': 'O'},
#   {'token': the, 'iob_tag': 'O'},
#   {'token': 1st, 'iob_tag': 'O'},
#   {'token': Ave, 'iob_tag': 'O'},
#   {'token': spot, 'iob_tag': 'O'},
#   {'token': because, 'iob_tag': 'O'},
#   {'token': it, 'iob_tag': 'O'},
#   {'token': is, 'iob_tag': 'O'},
#   {'token': the, 'iob_tag': 'O'},
#   {'token': original, 'iob_tag': 'O'},
#   {'token': store, 'iob_tag': 'O'},
#   {'token': ., 'iob_tag': 'O'}],
#  [{'token': I, 'iob_tag': 'O'},
#   {'token': stumbled, 'iob_tag': 'O'},
#   {'token': upon, 'iob_tag': 'O'},
#   {'token': this, 'iob_tag': 'O'},
#   {'token': second, 'iob_tag': 'O'},
#   {'token': floor, 'iob_tag': 'O'},
#   {'token': walk, 'iob_tag': 'O'},
#   {'token': -, 'iob_tag': 'O'},
#   {'token': up, 'iob_tag': 'O'},
#   {'token': two, 'iob_tag': 'O'},
#   {'token': Fridays, 'iob_tag': 'O'},
#   {'token': ago, 'iob_tag': 'O'},
#   {'token': when, 'iob_tag': 'O'},
#   {'token': I, 'iob_tag': 'O'},
#   {'token': was, 'iob_tag': 'O'},
#   {'token': with, 'iob_tag': 'O'},
#   {'token': two, 'iob_tag': 'O'},
#   {'token': friends, 'iob_tag': 'O'},
#   {'token': in, 'iob_tag': 'O'},
#   {'token': town, 'iob_tag': 'O'},
#   {'token': from, 'iob_tag': 'O'},
#   {'token': L.A., 'iob_tag': 'O'},
#   {'token': Being, 'iob_tag': 'O'},
#   {'token': serious, 'iob_tag': 'O'},
#   {'token': sushi, 'iob_tag': 'B'},
#   {'token': lovers, 'iob_tag': 'O'},
#   {'token': ,, 'iob_tag': 'O'},
#   {'token': we, 'iob_tag': 'O'},
#   {'token': sat, 'iob_tag': 'O'},
#   {'token': at, 'iob_tag': 'O'},
#   {'token': the, 'iob_tag': 'O'},
#   {'token': sushi, 'iob_tag': 'B'},
#   {'token': bar, 'iob_tag': 'I'},
#   {'token': to, 'iob_tag': 'O'},
#   {'token': be, 'iob_tag': 'O'},
#   {'token': closer, 'iob_tag': 'O'},
#   {'token': to, 'iob_tag': 'O'},
#   {'token': the, 'iob_tag': 'O'},
#   {'token': action, 'iob_tag': 'O'},
#   {'token': ., 'iob_tag': 'O'}],
#  [{'token': Raga, 'iob_tag': 'O'},
#   {'token': 's, 'iob_tag': 'O'},
#   {'token': is, 'iob_tag': 'O'},
#   {'token': a, 'iob_tag': 'O'},
#   {'token': romantic, 'iob_tag': 'O'},
#   {'token': ,, 'iob_tag': 'O'},
#   {'token': cozy, 'iob_tag': 'O'},
#   {'token': restaurant, 'iob_tag': 'O'},
#   {'token': ., 'iob_tag': 'O'}],
#  [{'token': The, 'iob_tag': 'O'},
#   {'token': fried, 'iob_tag': 'B'},
#   {'token': rice, 'iob_tag': 'I'},
#   {'token': is, 'iob_tag': 'O'},
#   {'token': amazing, 'iob_tag': 'O'},
#   {'token': here, 'iob_tag': 'O'},
#   {'token': ., 'iob_tag': 'O'}],
#  [{'token': Three, 'iob_tag': 'O'},
#   {'token': courses, 'iob_tag': 'B'},
#   {'token': -, 'iob_tag': 'O'},
#   {'token': choices, 'iob_tag': 'O'},
#   {'token': include, 'iob_tag': 'O'},
#   {'token': excellent, 'iob_tag': 'O'},
#   {'token': mussels, 'iob_tag': 'B'},
#   {'token': ,, 'iob_tag': 'O'},
#   {'token': puff, 'iob_tag': 'B'},
#   {'token': pastry, 'iob_tag': 'I'},
#   {'token': goat, 'iob_tag': 'I'},
#   {'token': cheese, 'iob_tag': 'I'},
#   {'token': and, 'iob_tag': 'O'},
#   {'token': salad, 'iob_tag': 'B'},
#   {'token': with, 'iob_tag': 'I'},
#   {'token': a, 'iob_tag': 'I'},
#   {'token': delicious, 'iob_tag': 'I'},
#   {'token': dressing, 'iob_tag': 'I'},
#   {'token': ,, 'iob_tag': 'O'},
#   {'token': and, 'iob_tag': 'O'},
#   {'token': a, 'iob_tag': 'O'},
#   {'token': hanger, 'iob_tag': 'B'},
#   {'token': steak, 'iob_tag': 'I'},
#   {'token': au, 'iob_tag': 'I'},
#   {'token': poivre, 'iob_tag': 'I'},
#   {'token': that, 'iob_tag': 'O'},
#   {'token': is, 'iob_tag': 'O'},
#   {'token': out, 'iob_tag': 'O'},
#   {'token': of, 'iob_tag': 'O'},
#   {'token': this, 'iob_tag': 'O'},
#   {'token': world, 'iob_tag': 'O'},
#   {'token': ., 'iob_tag': 'O'}],
#  [{'token': it, 'iob_tag': 'O'},
#   {'token': 's, 'iob_tag': 'O'},
#   {'token': a, 'iob_tag': 'O'},
#   {'token': perfect, 'iob_tag': 'O'},
#   {'token': place, 'iob_tag': 'O'},
#   {'token': to, 'iob_tag': 'O'},
#   {'token': have, 'iob_tag': 'O'},
#   {'token': a, 'iob_tag': 'O'},
#   {'token': amanzing, 'iob_tag': 'O'},
#   {'token': indian, 'iob_tag': 'B'},
#   {'token': food, 'iob_tag': 'I'},
#   {'token': ., 'iob_tag': 'O'}],
#  [{'token': The, 'iob_tag': 'O'},
#   {'token': place, 'iob_tag': 'B'},
#   {'token': is, 'iob_tag': 'O'},
#   {'token': so, 'iob_tag': 'O'},
#   {'token': cool, 'iob_tag': 'O'},
#   {'token': and, 'iob_tag': 'O'},
#   {'token': the, 'iob_tag': 'O'},
#   {'token': service, 'iob_tag': 'B'},
#   {'token': is, 'iob_tag': 'O'},
#   {'token': prompt, 'iob_tag': 'O'},
#   {'token': and, 'iob_tag': 'O'},
#   {'token': curtious, 'iob_tag': 'O'},
#   {'token': ., 'iob_tag': 'O'}],
#  [{'token': At, 'iob_tag': 'O'},
#   {'token': the, 'iob_tag': 'O'},
#   {'token': end, 'iob_tag': 'O'},
#   {'token': you, 'iob_tag': 'O'},
#   {'token': 're, 'iob_tag': 'O'},
#   {'token': left, 'iob_tag': 'O'},
#   {'token': with, 'iob_tag': 'O'},
#   {'token': a, 'iob_tag': 'O'},
#   {'token': mild, 'iob_tag': 'O'},
#   {'token': broth, 'iob_tag': 'B'},
#   {'token': with, 'iob_tag': 'I'},
#   {'token': noodles, 'iob_tag': 'I'},
#   {'token': that, 'iob_tag': 'O'},
#   {'token': you, 'iob_tag': 'O'},
#   {'token': can, 'iob_tag': 'O'},
#   {'token': slurp, 'iob_tag': 'O'},
#   {'token': out, 'iob_tag': 'O'},
#   {'token': of, 'iob_tag': 'O'},
#   {'token': a, 'iob_tag': 'O'},
#   {'token': cup, 'iob_tag': 'O'},
#   {'token': ., 'iob_tag': 'O'}],
#  [{'token': I, 'iob_tag': 'O'},
#   {'token': just, 'iob_tag': 'O'},
#   {'token': wonder, 'iob_tag': 'O'},
#   {'token': how, 'iob_tag': 'O'},
#   {'token': you, 'iob_tag': 'O'},
#   {'token': can, 'iob_tag': 'O'},
#   {'token': have, 'iob_tag': 'O'},
#   {'token': such, 'iob_tag': 'O'},
#   {'token': a, 'iob_tag': 'O'},
#   {'token': delicious, 'iob_tag': 'O'},
#   {'token': meal, 'iob_tag': 'B'},
#   {'token': for, 'iob_tag': 'O'},
#   {'token': such, 'iob_tag': 'O'},
#   {'token': little, 'iob_tag': 'O'},
#   {'token': money, 'iob_tag': 'B'},
#   {'token': ., 'iob_tag': 'O'}],
#  [{'token': The, 'iob_tag': 'O'},
#   {'token': food, 'iob_tag': 'B'},
#   {'token': was, 'iob_tag': 'O'},
#   {'token': delicious, 'iob_tag': 'O'},
#   {'token': but, 'iob_tag': 'O'},
#   {'token': do, 'iob_tag': 'O'},
#   {'token': not, 'iob_tag': 'O'},
#   {'token': come, 'iob_tag': 'O'},
#   {'token': here, 'iob_tag': 'O'},
#   {'token': on, 'iob_tag': 'O'},
#   {'token': a, 'iob_tag': 'O'},
#   {'token': empty, 'iob_tag': 'O'},
#   {'token': stomach, 'iob_tag': 'O'},
#   {'token': ., 'iob_tag': 'O'}],
#  [{'token': The, 'iob_tag': 'O'},
#   {'token': wine, 'iob_tag': 'B'},
#   {'token': list, 'iob_tag': 'I'},
#   {'token': is, 'iob_tag': 'O'},
#   {'token': excellent, 'iob_tag': 'O'},
#   {'token': ., 'iob_tag': 'O'}],
#  [{'token': so, 'iob_tag': 'O'},
#   {'token': garantuan, 'iob_tag': 'O'},
#   {'token': that, 'iob_tag': 'O'},
#   {'token': you, 'iob_tag': 'O'},
#   {'token': ca, 'iob_tag': 'O'},
#   {'token': n't, 'iob_tag': 'O'},
#   {'token': fit, 'iob_tag': 'O'},
#   {'token': them, 'iob_tag': 'O'},
#   {'token': in, 'iob_tag': 'O'},
#   {'token': a, 'iob_tag': 'O'},
#   {'token': toaster, 'iob_tag': 'O'},
#   {'token': ., 'iob_tag': 'O'}],
#  [{'token': I, 'iob_tag': 'O'},
#   {'token': ve, 'iob_tag': 'O'},
#   {'token': been, 'iob_tag': 'O'},
#   {'token': to, 'iob_tag': 'O'},
#   {'token': many, 'iob_tag': 'O'},
#   {'token': Thai, 'iob_tag': 'O'},
#   {'token': restaurants, 'iob_tag': 'O'},
#   {'token': in, 'iob_tag': 'O'},
#   {'token': Manhattan, 'iob_tag': 'O'},
#   {'token': before, 'iob_tag': 'O'},
#   {'token': ,, 'iob_tag': 'O'},
#   {'token': and, 'iob_tag': 'O'},
#   {'token': Toons, 'iob_tag': 'O'},
#   {'token': is, 'iob_tag': 'O'},
#   {'token': by, 'iob_tag': 'O'},
#   {'token': far, 'iob_tag': 'O'},
#   {'token': the, 'iob_tag': 'O'},
#   {'token': best, 'iob_tag': 'O'},
#   {'token': Thai, 'iob_tag': 'B'},
#   {'token': food, 'iob_tag': 'I'},
#   {'token': I, 'iob_tag': 'O'},
#   {'token': ve, 'iob_tag': 'O'},
#   {'token': had, 'iob_tag': 'O'},
#   {'token': (, 'iob_tag': 'O'},
#   {'token': except, 'iob_tag': 'O'},
#   {'token': for, 'iob_tag': 'O'},
#   {'token': my, 'iob_tag': 'O'},
#   {'token': mom, 'iob_tag': 'O'},
#   {'token': 's, 'iob_tag': 'O'},
#   {'token': of, 'iob_tag': 'O'},
#   {'token': course, 'iob_tag': 'O'},
#   {'token': ), 'iob_tag': 'O'},
#   {'token': ., 'iob_tag': 'O'}],
#  [{'token': They, 'iob_tag': 'O'},
#   {'token': would, 'iob_tag': 'O'},
#   {'token': nt, 'iob_tag': 'O'},
#   {'token': even, 'iob_tag': 'O'},
#   {'token': let, 'iob_tag': 'O'},
#   {'token': me, 'iob_tag': 'O'},
#   {'token': finish, 'iob_tag': 'O'},
#   {'token': my, 'iob_tag': 'O'},
#   {'token': glass, 'iob_tag': 'B'},
#   {'token': of, 'iob_tag': 'I'},
#   {'token': wine, 'iob_tag': 'I'},
#   {'token': before, 'iob_tag': 'O'},
#   {'token': offering, 'iob_tag': 'O'},
#   {'token': another, 'iob_tag': 'O'},
#   {'token': ., 'iob_tag': 'O'}],
#  [{'token': I, 'iob_tag': 'O'},
#   {'token': highly, 'iob_tag': 'O'},
#   {'token': recommend, 'iob_tag': 'O'},
#   {'token': the, 'iob_tag': 'O'},
#   {'token': Sophia, 'iob_tag': 'O'},
#   {'token': pizza, 'iob_tag': 'O'},
#   {'token': ., 'iob_tag': 'O'}],
#  [{'token': Whem, 'iob_tag': 'O'},
#   {'token': asked, 'iob_tag': 'O'},
#   {'token': ,, 'iob_tag': 'O'},
#   {'token': we, 'iob_tag': 'O'},
#   {'token': had, 'iob_tag': 'O'},
#   {'token': to, 'iob_tag': 'O'},
#   {'token': ask, 'iob_tag': 'O'},
#   {'token': more, 'iob_tag': 'O'},
#   {'token': detailed, 'iob_tag': 'O'},
#   {'token': questions, 'iob_tag': 'O'},
#   {'token': so, 'iob_tag': 'O'},
#   {'token': that, 'iob_tag': 'O'},
#   {'token': we, 'iob_tag': 'O'},
#   {'token': knew, 'iob_tag': 'O'},
#   {'token': what, 'iob_tag': 'O'},
#   {'token': the, 'iob_tag': 'O'},
#   {'token': specials, 'iob_tag': 'B'},
#   {'token': were, 'iob_tag': 'O'},
#   {'token': ., 'iob_tag': 'O'}],
#  [{'token': This, 'iob_tag': 'O'},
#   {'token': is, 'iob_tag': 'O'},
#   {'token': a, 'iob_tag': 'O'},
#   {'token': consistently, 'iob_tag': 'O'},
#   {'token': great, 'iob_tag': 'O'},
#   {'token': place, 'iob_tag': 'O'},
#   {'token': to, 'iob_tag': 'O'},
#   {'token': dine, 'iob_tag': 'B'},
#   {'token': for, 'iob_tag': 'O'},
#   {'token': lunch, 'iob_tag': 'B'},
#   {'token': or, 'iob_tag': 'O'},
#   {'token': dinner, 'iob_tag': 'B'},
#   {'token': ., 'iob_tag': 'O'}],
#  [{'token': Nice, 'iob_tag': 'O'},
#   {'token': atmosphere, 'iob_tag': 'B'},
#   {'token': ,, 'iob_tag': 'O'},
#   {'token': the, 'iob_tag': 'O'},
#   {'token': service, 'iob_tag': 'B'},
#   {'token': was, 'iob_tag': 'O'},
#   {'token': very, 'iob_tag': 'O'},
#   {'token': pleasant, 'iob_tag': 'O'},
#   {'token': and, 'iob_tag': 'O'},
#   {'token': the, 'iob_tag': 'O'},
#   {'token': desert, 'iob_tag': 'B'},
#   {'token': was, 'iob_tag': 'O'},
#   {'token': good, 'iob_tag': 'O'},
#   {'token': ., 'iob_tag': 'O'}],
#  [{'token': All, 'iob_tag': 'O'},
#   {'token': the, 'iob_tag': 'O'},
#   {'token': people, 'iob_tag': 'O'},
#   {'token': that, 'iob_tag': 'O'},
#   {'token': I, 'iob_tag': 'O'},
#   {'token': bring, 'iob_tag': 'O'},
#   {'token': there, 'iob_tag': 'O'},
#   {'token': go, 'iob_tag': 'O'},
#   {'token': back, 'iob_tag': 'O'},
#   {'token': on, 'iob_tag': 'O'},
#   {'token': their, 'iob_tag': 'O'},
#   {'token': own, 'iob_tag': 'O'},
#   {'token': and, 'iob_tag': 'O'},
#   {'token': bring, 'iob_tag': 'O'},
#   {'token': THEIR, 'iob_tag': 'O'},
#   {'token': friends, 'iob_tag': 'O'},
#   {'token': !, 'iob_tag': 'O'}],
#  [{'token': After, 'iob_tag': 'O'},
#   {'token': really, 'iob_tag': 'O'},
#   {'token': enjoying, 'iob_tag': 'O'},
#   {'token': ourselves, 'iob_tag': 'O'},
#   {'token': at, 'iob_tag': 'O'},
#   {'token': the, 'iob_tag': 'O'},
#   {'token': bar, 'iob_tag': 'B'},
#   {'token': we, 'iob_tag': 'O'},
#   {'token': sat, 'iob_tag': 'O'},
#   {'token': down, 'iob_tag': 'O'},
#   {'token': at, 'iob_tag': 'O'},
#   {'token': a, 'iob_tag': 'O'},
#   {'token': table, 'iob_tag': 'B'},
#   {'token': and, 'iob_tag': 'O'},
#   {'token': had, 'iob_tag': 'O'},
#   {'token': dinner, 'iob_tag': 'B'},
#   {'token': ., 'iob_tag': 'O'}],
#  [{'token': Fabulous, 'iob_tag': 'O'},
#   {'token': service, 'iob_tag': 'B'},
#   {'token': ,, 'iob_tag': 'O'},
#   {'token': fantastic, 'iob_tag': 'O'},
#   {'token': food, 'iob_tag': 'B'},
#   {'token': ,, 'iob_tag': 'O'},
#   {'token': and, 'iob_tag': 'O'},
#   {'token': a, 'iob_tag': 'O'},
#   {'token': chilled, 'iob_tag': 'O'},
#   {'token': out, 'iob_tag': 'O'},
#   {'token': atmosphere, 'iob_tag': 'B'},
#   {'token': and, 'iob_tag': 'O'},
#   {'token': environment, 'iob_tag': 'B'},
#   {'token': ., 'iob_tag': 'O'}],
#  [{'token': Not, 'iob_tag': 'O'},
#   {'token': what, 'iob_tag': 'O'},
#   {'token': I, 'iob_tag': 'O'},
#   {'token': wanted, 'iob_tag': 'O'},
#   {'token': to, 'iob_tag': 'O'},
#   {'token': hear, 'iob_tag': 'O'},
#   {'token': ., 'iob_tag': 'O'}],
#  [{'token': Try, 'iob_tag': 'O'},
#   {'token': the, 'iob_tag': 'O'},
#   {'token': lasagnette, 'iob_tag': 'B'},
#   {'token': appetizer, 'iob_tag': 'I'},
#   {'token': ., 'iob_tag': 'O'}],
#  [{'token': Pricey, 'iob_tag': 'O'},
#   {'token': ,, 'iob_tag': 'O'},
#   {'token': but, 'iob_tag': 'O'},
#   {'token': worth, 'iob_tag': 'O'},
#   {'token': a, 'iob_tag': 'O'},
#   {'token': try, 'iob_tag': 'O'},
#   {'token': ,, 'iob_tag': 'O'},
#   {'token': at, 'iob_tag': 'O'},
#   {'token': least, 'iob_tag': 'O'},
#   {'token': once, 'iob_tag': 'O'},
#   {'token': ., 'iob_tag': 'O'}],
#  [{'token': I, 'iob_tag': 'O'},
#   {'token': 've, 'iob_tag': 'O'},
#   {'token': been, 'iob_tag': 'O'},
#   {'token': there, 'iob_tag': 'O'},
#   {'token': a, 'iob_tag': 'O'},
#   {'token': few, 'iob_tag': 'O'},
#   {'token': times, 'iob_tag': 'O'},
#   {'token': ,, 'iob_tag': 'O'},
#   {'token': and, 'iob_tag': 'O'},
#   {'token': I, 'iob_tag': 'O'},
#   {'token': usually, 'iob_tag': 'O'},
#   {'token': end, 'iob_tag': 'O'},
#   {'token': up, 'iob_tag': 'O'},
#   {'token': sitting, 'iob_tag': 'O'},
#   {'token': next, 'iob_tag': 'O'},
#   {'token': to, 'iob_tag': 'O'},
#   {'token': some, 'iob_tag': 'O'},
#   {'token': pretty, 'iob_tag': 'O'},
#   {'token': odd, 'iob_tag': 'O'},
#   {'token': people, 'iob_tag': 'O'},
#   {'token': ., 'iob_tag': 'O'}],
#  [{'token': I, 'iob_tag': 'O'},
#   {'token': liked, 'iob_tag': 'O'},
#   {'token': the, 'iob_tag': 'O'},
#   {'token': beer, 'iob_tag': 'B'},
#   {'token': selection, 'iob_tag': 'I'},
#   {'token': !, 'iob_tag': 'O'}],
#  [{'token': Great, 'iob_tag': 'O'},
#   {'token': food, 'iob_tag': 'B'},
#   {'token': ,, 'iob_tag': 'O'},
#   {'token': good, 'iob_tag': 'O'},
#   {'token': size, 'iob_tag': 'O'},
#   {'token': menu, 'iob_tag': 'B'},
#   {'token': ,, 'iob_tag': 'O'},
#   {'token': great, 'iob_tag': 'O'},
#   {'token': service, 'iob_tag': 'B'},
#   {'token': and, 'iob_tag': 'O'},
#   {'token': an, 'iob_tag': 'O'},
#   {'token': unpretensious, 'iob_tag': 'O'},
#   {'token': setting, 'iob_tag': 'B'},
#   {'token': ., 'iob_tag': 'O'}],
#  [{'token': Go, 'iob_tag': 'O'},
#   {'token': here, 'iob_tag': 'O'},
#   {'token': for, 'iob_tag': 'O'},
#   {'token': a, 'iob_tag': 'O'},
#   {'token': romantic, 'iob_tag': 'O'},
#   {'token': dinner, 'iob_tag': 'B'},
#   {'token': but, 'iob_tag': 'O'},
#   {'token': not, 'iob_tag': 'O'},
#   {'token': for, 'iob_tag': 'O'},
#   {'token': an, 'iob_tag': 'O'},
#   {'token': all, 'iob_tag': 'O'},
#   {'token': out, 'iob_tag': 'O'},
#   {'token': wow, 'iob_tag': 'O'},
#   {'token': dining, 'iob_tag': 'B'},
#   {'token': experience, 'iob_tag': 'O'},
#   {'token': ., 'iob_tag': 'O'}],
#  [{'token': Ca, 'iob_tag': 'O'},
#   {'token': n't, 'iob_tag': 'O'},
#   {'token': wait, 'iob_tag': 'O'},
#   {'token': to, 'iob_tag': 'O'},
#   {'token': go, 'iob_tag': 'O'},
#   {'token': back, 'iob_tag': 'O'},
#   {'token': ., 'iob_tag': 'O'}],
#  [{'token': I, 'iob_tag': 'O'},
#   {'token': grew, 'iob_tag': 'O'},
#   {'token': up, 'iob_tag': 'O'},
#   {'token': eating, 'iob_tag': 'O'},
#   {'token': Dosa, 'iob_tag': 'B'},
#   {'token': and, 'iob_tag': 'O'},
#   {'token': have, 'iob_tag': 'O'},
#   {'token': yet, 'iob_tag': 'O'},
#   {'token': to, 'iob_tag': 'O'},
#   {'token': find, 'iob_tag': 'O'},
#   {'token': a, 'iob_tag': 'O'},
#   {'token': place, 'iob_tag': 'O'},
#   {'token': in, 'iob_tag': 'O'},
#   {'token': NY, 'iob_tag': 'O'},
#   {'token': to, 'iob_tag': 'O'},
#   {'token': satisfy, 'iob_tag': 'O'},
#   {'token': my, 'iob_tag': 'O'},
#   {'token': taste, 'iob_tag': 'O'},
#   {'token': buds, 'iob_tag': 'O'},
#   {'token': ., 'iob_tag': 'O'}],
#  [{'token': Wine, 'iob_tag': 'B'},
#   {'token': list, 'iob_tag': 'I'},
#   {'token': selection, 'iob_tag': 'I'},
#   {'token': is, 'iob_tag': 'O'},
#   {'token': good, 'iob_tag': 'O'},
#   {'token': and, 'iob_tag': 'O'},
#   {'token': wine, 'iob_tag': 'B'},
#   {'token': -, 'iob_tag': 'I'},
#   {'token': by, 'iob_tag': 'I'},
#   {'token': -, 'iob_tag': 'I'},
#   {'token': the, 'iob_tag': 'I'},
#   {'token': -, 'iob_tag': 'I'},
#   {'token': glass, 'iob_tag': 'I'},
#   {'token': was, 'iob_tag': 'O'},
#   {'token': generously, 'iob_tag': 'O'},
#   {'token': filled, 'iob_tag': 'O'},
#   {'token': to, 'iob_tag': 'O'},
#   {'token': the, 'iob_tag': 'O'},
#   {'token': top, 'iob_tag': 'O'},
#   {'token': ., 'iob_tag': 'O'}],
#  [{'token': With, 'iob_tag': 'O'},
#   {'token': the, 'iob_tag': 'O'},
#   {'token': great, 'iob_tag': 'O'},
#   {'token': variety, 'iob_tag': 'O'},
#   {'token': on, 'iob_tag': 'O'},
#   {'token': the, 'iob_tag': 'O'},
#   {'token': menu, 'iob_tag': 'B'},
#   {'token': ,, 'iob_tag': 'O'},
#   {'token': I, 'iob_tag': 'O'},
#   {'token': eat, 'iob_tag': 'O'},
#   {'token': here, 'iob_tag': 'O'},
#   {'token': often, 'iob_tag': 'O'},
#   {'token': and, 'iob_tag': 'O'},
#   {'token': never, 'iob_tag': 'O'},
#   {'token': get, 'iob_tag': 'O'},
#   {'token': bored, 'iob_tag': 'O'},
#   {'token': ., 'iob_tag': 'O'}],
#  [{'token': The, 'iob_tag': 'O'},
#   {'token': menu, 'iob_tag': 'B'},
#   {'token': is, 'iob_tag': 'O'},
#   {'token': very, 'iob_tag': 'O'},
#   {'token': limited, 'iob_tag': 'O'},
#   {'token': -, 'iob_tag': 'O'},
#   {'token': i, 'iob_tag': 'O'},
#   {'token': think, 'iob_tag': 'O'},
#   {'token': we, 'iob_tag': 'O'},
#   {'token': counted, 'iob_tag': 'O'},
#   {'token': 4, 'iob_tag': 'O'},
#   {'token': or, 'iob_tag': 'O'},
#   {'token': 5, 'iob_tag': 'O'},
#   {'token': entrees, 'iob_tag': 'B'},
#   {'token': ., 'iob_tag': 'O'}],
#  [{'token': If, 'iob_tag': 'O'},
#   {'token': you, 'iob_tag': 'O'},
#   {'token': are, 'iob_tag': 'O'},
#   {'token': a, 'iob_tag': 'O'},
#   {'token': carnivore, 'iob_tag': 'O'},
#   {'token': ,, 'iob_tag': 'O'},
#   {'token': come, 'iob_tag': 'O'},
#   {'token': hungry, 'iob_tag': 'O'},
#   {'token': and, 'iob_tag': 'O'},
#   {'token': you, 'iob_tag': 'O'},
#   {'token': will, 'iob_tag': 'O'},
#   {'token': leave, 'iob_tag': 'O'},
#   {'token': more, 'iob_tag': 'O'},
#   {'token': satisfied, 'iob_tag': 'O'},
#   {'token': than, 'iob_tag': 'O'},
#   {'token': you, 'iob_tag': 'O'},
#   {'token': have, 'iob_tag': 'O'},
#   {'token': ever, 'iob_tag': 'O'},
#   {'token': been, 'iob_tag': 'O'},
#   {'token': ., 'iob_tag': 'O'}],
#  [{'token': The, 'iob_tag': 'O'},
#   {'token': menu, 'iob_tag': 'B'},
#   {'token': is, 'iob_tag': 'O'},
#   {'token': limited, 'iob_tag': 'O'},
#   {'token': but, 'iob_tag': 'O'},
#   {'token': almost, 'iob_tag': 'O'},
#   {'token': all, 'iob_tag': 'O'},
#   {'token': of, 'iob_tag': 'O'},
#   {'token': the, 'iob_tag': 'O'},
#   {'token': dishes, 'iob_tag': 'B'},
#   {'token': are, 'iob_tag': 'O'},
#   {'token': excellent, 'iob_tag': 'O'},
#   {'token': ., 'iob_tag': 'O'}],
#  [{'token': Not, 'iob_tag': 'O'},
#   {'token': too, 'iob_tag': 'O'},
#   {'token': crazy, 'iob_tag': 'O'},
#   {'token': about, 'iob_tag': 'O'},
#   {'token': their, 'iob_tag': 'O'},
#   {'token': sake, 'iob_tag': 'B'},
#   {'token': martini, 'iob_tag': 'I'},
#   {'token': ., 'iob_tag': 'O'}],
#  [{'token': Great, 'iob_tag': 'O'},
#   {'token': bagels, 'iob_tag': 'B'},
#   {'token': ,, 'iob_tag': 'O'},
#   {'token': spreads, 'iob_tag': 'B'},
#   {'token': and, 'iob_tag': 'O'},
#   {'token': a, 'iob_tag': 'O'},
#   {'token': good, 'iob_tag': 'O'},
#   {'token': place, 'iob_tag': 'O'},
#   {'token': to, 'iob_tag': 'O'},
#   {'token': hang, 'iob_tag': 'O'},
#   {'token': out, 'iob_tag': 'O'},
#   {'token': in, 'iob_tag': 'O'},
#   {'token': ., 'iob_tag': 'O'}],
#  [{'token': The, 'iob_tag': 'O'},
#   {'token': service, 'iob_tag': 'B'},
#   {'token': varys, 'iob_tag': 'O'},
#   {'token': from, 'iob_tag': 'O'},
#   {'token': day, 'iob_tag': 'O'},
#   {'token': to, 'iob_tag': 'O'},
#   {'token': day-, 'iob_tag': 'O'},
#   {'token': sometimes, 'iob_tag': 'O'},
#   {'token': they, 'iob_tag': 'O'},
#   {'token': 're, 'iob_tag': 'O'},
#   {'token': very, 'iob_tag': 'O'},
#   {'token': nice, 'iob_tag': 'O'},
#   {'token': ,, 'iob_tag': 'O'},
#   {'token': and, 'iob_tag': 'O'},
#   {'token': sometimes, 'iob_tag': 'O'},
#   {'token': not, 'iob_tag': 'O'},
#   {'token': ., 'iob_tag': 'O'}],
#  [{'token': whoever, 'iob_tag': 'O'},
#   {'token': the, 'iob_tag': 'O'},
#   {'token': jazz, 'iob_tag': 'O'},
#   {'token': duo, 'iob_tag': 'O'},
#   {'token': was, 'iob_tag': 'O'},
#   {'token': ,, 'iob_tag': 'O'},
#   {'token': they, 'iob_tag': 'O'},
#   {'token': were, 'iob_tag': 'O'},
#   {'token': on, 'iob_tag': 'O'},
#   {'token': POINT, 'iob_tag': 'O'},
#   {'token': ., 'iob_tag': 'O'}],
#  [{'token': One, 'iob_tag': 'O'},
#   {'token': thing, 'iob_tag': 'O'},
#   {'token': I, 'iob_tag': 'O'},
#   {'token': liked, 'iob_tag': 'O'},
#   {'token': about, 'iob_tag': 'O'},
#   {'token': this, 'iob_tag': 'O'},
#   {'token': place, 'iob_tag': 'O'},
#   {'token': is, 'iob_tag': 'O'},
#   {'token': that, 'iob_tag': 'O'},
#   {'token': I, 'iob_tag': 'O'},
#   {'token': never, 'iob_tag': 'O'},
#   {'token': felt, 'iob_tag': 'O'},
#   {'token': rushed, 'iob_tag': 'O'},
#   {'token': or, 'iob_tag': 'O'},
#   {'token': pressured, 'iob_tag': 'O'},
#   {'token': to, 'iob_tag': 'O'},
#   {'token': give, 'iob_tag': 'O'},
#   {'token': up, 'iob_tag': 'O'},
#   {'token': my, 'iob_tag': 'O'},
#   {'token': table, 'iob_tag': 'B'},
#   {'token': ot, 'iob_tag': 'O'},
#   {'token': incoming, 'iob_tag': 'O'},
#   {'token': guests, 'iob_tag': 'O'},
#   {'token': ., 'iob_tag': 'O'}],
#  [{'token': This, 'iob_tag': 'O'},
#   {'token': place, 'iob_tag': 'O'},
#   {'token': is, 'iob_tag': 'O'},
#   {'token': a, 'iob_tag': 'O'},
#   {'token': great, 'iob_tag': 'O'},
#   {'token': bargain, 'iob_tag': 'O'},
#   {'token': ., 'iob_tag': 'O'}],
#  [{'token': We, 'iob_tag': 'O'},
#   {'token': happened, 'iob_tag': 'O'},
#   {'token': upon, 'iob_tag': 'O'},
#   {'token': this, 'iob_tag': 'O'},
#   {'token': place, 'iob_tag': 'O'},
#   {'token': purely, 'iob_tag': 'O'},
#   {'token': by, 'iob_tag': 'O'},
#   {'token': accident, 'iob_tag': 'O'},
#   {'token': and, 'iob_tag': 'O'},
#   {'token': were, 'iob_tag': 'O'},
#   {'token': pleased, 'iob_tag': 'O'},
#   {'token': with, 'iob_tag': 'O'},
#   {'token': the, 'iob_tag': 'O'},
#   {'token': results, 'iob_tag': 'O'},
#   {'token': ., 'iob_tag': 'O'}],
#  [{'token': Unfortunately, 'iob_tag': 'O'},
#   {'token': ,, 'iob_tag': 'O'},
#   {'token': the, 'iob_tag': 'O'},
#   {'token': food, 'iob_tag': 'B'},
#   {'token': is, 'iob_tag': 'O'},
#   {'token': outstanding, 'iob_tag': 'O'},
#   {'token': ,, 'iob_tag': 'O'},
#   {'token': but, 'iob_tag': 'O'},
#   {'token': everything, 'iob_tag': 'O'},
#   {'token': else, 'iob_tag': 'O'},
#   {'token': about, 'iob_tag': 'O'},
#   {'token': this, 'iob_tag': 'O'},
#   {'token': restaurant, 'iob_tag': 'O'},
#   {'token': is, 'iob_tag': 'O'},
#   {'token': the, 'iob_tag': 'O'},
#   {'token': pits, 'iob_tag': 'O'},
#   {'token': ., 'iob_tag': 'O'}],
#  [{'token': Deff, 'iob_tag': 'O'},
#   {'token': recimmend, 'iob_tag': 'O'},
#   {'token': Bukhara, 'iob_tag': 'O'},
#   {'token': they, 'iob_tag': 'O'},
#   {'token': also, 'iob_tag': 'O'},
#   {'token': have, 'iob_tag': 'O'},
#   {'token': opened, 'iob_tag': 'O'},
#   {'token': two, 'iob_tag': 'O'},
#   {'token': new, 'iob_tag': 'O'},
#   {'token': locations, 'iob_tag': 'O'},
#   {'token': guess, 'iob_tag': 'O'},
#   {'token': ill, 'iob_tag': 'O'},
#   {'token': try, 'iob_tag': 'O'},
#   {'token': them, 'iob_tag': 'O'},
#   {'token': out, 'iob_tag': 'O'},
#   {'token': ., 'iob_tag': 'O'}],
#  [{'token': We, 'iob_tag': 'O'},
# ...
#  [{'token': We, 'iob_tag': 'O'},
#   {'token': had, 'iob_tag': 'O'},
#   {'token': champagne, 'iob_tag': 'B'},
#   {'token': and, 'iob_tag': 'O'},
#   {'token': caviar, 'iob_tag': 'B'},
#   {'token': and, 'iob_tag': 'O'},
#   {'token': felt, 'iob_tag': 'O'},
#   {'token': like, 'iob_tag': 'O'},
#   {'token': princesses, 'iob_tag': 'O'},
#   {'token': !, 'iob_tag': 'O'}],
#  [{'token': The, 'iob_tag': 'O'},
#   {'token': shrimp, 'iob_tag': 'B'},
#   {'token': scampi, 'iob_tag': 'I'},
#   {'token': was, 'iob_tag': 'O'},
#   {'token': excellent, 'iob_tag': 'O'},
#   {'token': and, 'iob_tag': 'O'},
#   {'token': the, 'iob_tag': 'O'},
#   {'token': antipasti, 'iob_tag': 'B'},
#   {'token': were, 'iob_tag': 'O'},
#   {'token': plentiful, 'iob_tag': 'O'},
#   {'token': ., 'iob_tag': 'O'}],
#  [{'token': I, 'iob_tag': 'O'},
#   {'token': am, 'iob_tag': 'O'},
#   {'token': surprised, 'iob_tag': 'O'},
#   {'token': to, 'iob_tag': 'O'},
#   {'token': say, 'iob_tag': 'O'},
#   {'token': the, 'iob_tag': 'O'},
#   {'token': least, 'iob_tag': 'O'},
#   {'token': and, 'iob_tag': 'O'},
#   {'token': find, 'iob_tag': 'O'},
#   {'token': such, 'iob_tag': 'O'},
#   {'token': practice, 'iob_tag': 'O'},
#   {'token': not, 'iob_tag': 'O'},
#   {'token': worth, 'iob_tag': 'O'},
#   {'token': the, 'iob_tag': 'O'},
#   {'token': effort, 'iob_tag': 'O'},
#   {'token': ., 'iob_tag': 'O'}],
#  [{'token': When, 'iob_tag': 'O'},
#   {'token': my, 'iob_tag': 'O'},
#   {'token': dessert, 'iob_tag': 'B'},
#   {'token': came, 'iob_tag': 'O'},
#   {'token': ,, 'iob_tag': 'O'},
#   {'token': there, 'iob_tag': 'O'},
#   {'token': was, 'iob_tag': 'O'},
#   {'token': a, 'iob_tag': 'O'},
#   {'token': candle, 'iob_tag': 'O'},
#   {'token': in, 'iob_tag': 'O'},
#   {'token': it, 'iob_tag': 'O'},
#   {'token': -, 'iob_tag': 'O'},
#   {'token': not, 'iob_tag': 'O'},
#   {'token': because, 'iob_tag': 'O'},
#   {'token': anyone, 'iob_tag': 'O'},
#   {'token': asked, 'iob_tag': 'O'},
#   {'token': for, 'iob_tag': 'O'},
#   {'token': one, 'iob_tag': 'O'},
#   {'token': -, 'iob_tag': 'O'},
#   {'token': but, 'iob_tag': 'O'},
#   {'token': because, 'iob_tag': 'O'},
#   {'token': the, 'iob_tag': 'O'},
#   {'token': waiter, 'iob_tag': 'B'},
#   {'token': must, 'iob_tag': 'O'},
#   {'token': have, 'iob_tag': 'O'},
#   {'token': seen, 'iob_tag': 'O'},
#   {'token': me, 'iob_tag': 'O'},
#   {'token': opening, 'iob_tag': 'O'},
#   {'token': my, 'iob_tag': 'O'},
#   {'token': birthday, 'iob_tag': 'O'},
#   {'token': card, 'iob_tag': 'O'},
#   {'token': and, 'iob_tag': 'O'},
#   {'token': gift, 'iob_tag': 'O'},
#   {'token': ,, 'iob_tag': 'O'},
#   {'token': and, 'iob_tag': 'O'},
#   {'token': said, 'iob_tag': 'O'},
#   {'token': he, 'iob_tag': 'O'},
#   {'token': knew, 'iob_tag': 'O'},
#   {'token': it, 'iob_tag': 'O'},
#   {'token': was, 'iob_tag': 'O'},
#   {'token': a, 'iob_tag': 'O'},
#   {'token': special, 'iob_tag': 'O'},
#   {'token': occassion, 'iob_tag': 'O'},
#   {'token': of, 'iob_tag': 'O'},
#   {'token': some, 'iob_tag': 'O'},
#   {'token': sort, 'iob_tag': 'O'},
#   {'token': ., 'iob_tag': 'O'}],
#  [{'token': I, 'iob_tag': 'O'},
#   {'token': got, 'iob_tag': 'O'},
#   {'token': the, 'iob_tag': 'O'},
#   {'token': $, 'iob_tag': 'O'},
#   {'token': 10, 'iob_tag': 'O'},
#   {'token': 10-piece, 'iob_tag': 'O'},
#   {'token': dim, 'iob_tag': 'B'},
#   {'token': sum, 'iob_tag': 'I'},
#   {'token': combo, 'iob_tag': 'I'},
#   {'token': ,, 'iob_tag': 'O'},
#   {'token': every, 'iob_tag': 'O'},
#   {'token': bite, 'iob_tag': 'O'},
#   {'token': of, 'iob_tag': 'O'},
#   {'token': which, 'iob_tag': 'O'},
#   {'token': was, 'iob_tag': 'O'},
#   {'token': great, 'iob_tag': 'O'},
#   {'token': ., 'iob_tag': 'O'}],
#  [{'token': There, 'iob_tag': 'O'},
#   {'token': are, 'iob_tag': 'O'},
#   {'token': other, 'iob_tag': 'O'},
#   {'token': Vietnamese, 'iob_tag': 'O'},
#   {'token': restaurants, 'iob_tag': 'O'},
#   {'token': in, 'iob_tag': 'O'},
#   {'token': the, 'iob_tag': 'O'},
#   {'token': chinatown, 'iob_tag': 'O'},
#   {'token': area, 'iob_tag': 'O'},
#   {'token': and, 'iob_tag': 'O'},
#   {'token': you, 'iob_tag': 'O'},
#   {'token': can, 'iob_tag': 'O'},
#   {'token': forget, 'iob_tag': 'O'},
#   {'token': about, 'iob_tag': 'O'},
#   {'token': those, 'iob_tag': 'O'},
#   {'token': ., 'iob_tag': 'O'}],
#  [{'token': There, 'iob_tag': 'O'},
#   {'token': is, 'iob_tag': 'O'},
#   {'token': also, 'iob_tag': 'O'},
#   {'token': very, 'iob_tag': 'O'},
#   {'token': limited, 'iob_tag': 'O'},
#   {'token': seating, 'iob_tag': 'B'},
#   {'token': and, 'iob_tag': 'O'},
#   {'token': there, 'iob_tag': 'O'},
#   {'token': can, 'iob_tag': 'O'},
#   {'token': be, 'iob_tag': 'O'},
#   {'token': a, 'iob_tag': 'O'},
#   {'token': substantial, 'iob_tag': 'O'},
#   {'token': wait, 'iob_tag': 'B'},
#   {'token': in, 'iob_tag': 'O'},
#   {'token': getting, 'iob_tag': 'O'},
#   {'token': food, 'iob_tag': 'B'},
#   {'token': at, 'iob_tag': 'O'},
#   {'token': peak, 'iob_tag': 'O'},
#   {'token': times, 'iob_tag': 'O'},
#   {'token': ., 'iob_tag': 'O'}],
#  [{'token': If, 'iob_tag': 'O'},
#   {'token': it, 'iob_tag': 'O'},
#   {'token': 's, 'iob_tag': 'O'},
#   {'token': just, 'iob_tag': 'O'},
#   {'token': a, 'iob_tag': 'O'},
#   {'token': quick, 'iob_tag': 'O'},
#   {'token': martini, 'iob_tag': 'B'},
#   {'token': at, 'iob_tag': 'O'},
#   {'token': the, 'iob_tag': 'O'},
#   {'token': bar, 'iob_tag': 'B'},
#   {'token': (, 'iob_tag': 'O'},
#   {'token': which, 'iob_tag': 'O'},
#   {'token': I, 'iob_tag': 'O'},
#   {'token': recommend, 'iob_tag': 'O'},
#   {'token': Jeffery, 'iob_tag': 'O'},
#   {'token': 's, 'iob_tag': 'O'},
#   {'token': ), 'iob_tag': 'O'},
#   {'token': or, 'iob_tag': 'O'},
#   {'token': a, 'iob_tag': 'O'},
#   {'token': mind, 'iob_tag': 'O'},
#   {'token': blowing, 'iob_tag': 'O'},
#   {'token': Roast, 'iob_tag': 'B'},
#   {'token': Chicken, 'iob_tag': 'I'},
#   {'token': ,, 'iob_tag': 'O'},
#   {'token': go, 'iob_tag': 'O'},
#   {'token': to, 'iob_tag': 'O'},
#   {'token': Village, 'iob_tag': 'O'},
#   {'token': !, 'iob_tag': 'O'}],
#  [{'token': No, 'iob_tag': 'O'},
#   {'token': thanks, 'iob_tag': 'O'},
#   {'token': !, 'iob_tag': 'O'},
#   {'token': !, 'iob_tag': 'O'},
#   {'token': !, 'iob_tag': 'O'}],
#  [{'token': There, 'iob_tag': 'O'},
#   {'token': was, 'iob_tag': 'O'},
#   {'token': a, 'iob_tag': 'O'},
#   {'token': long, 'iob_tag': 'O'},
#   {'token': wait, 'iob_tag': 'B'},
#   {'token': for, 'iob_tag': 'O'},
#   {'token': a, 'iob_tag': 'O'},
#   {'token': table, 'iob_tag': 'B'},
#   {'token': outside, 'iob_tag': 'O'},
#   {'token': ,, 'iob_tag': 'O'},
#   {'token': but, 'iob_tag': 'O'},
#   {'token': it, 'iob_tag': 'O'},
#   {'token': was, 'iob_tag': 'O'},
#   {'token': a, 'iob_tag': 'O'},
#   {'token': little, 'iob_tag': 'O'},
#   {'token': too, 'iob_tag': 'O'},
#   {'token': hot, 'iob_tag': 'O'},
#   {'token': in, 'iob_tag': 'O'},
#   {'token': the, 'iob_tag': 'O'},
#   {'token': sun, 'iob_tag': 'O'},
#   {'token': anyway, 'iob_tag': 'O'},
#   {'token': so, 'iob_tag': 'O'},
#   {'token': our, 'iob_tag': 'O'},
#   {'token': insde, 'iob_tag': 'B'},
#   {'token': table, 'iob_tag': 'I'},
#   {'token': was, 'iob_tag': 'O'},
#   {'token': very, 'iob_tag': 'O'},
#   {'token': nice, 'iob_tag': 'O'},
#   {'token': ., 'iob_tag': 'O'}],
#  [{'token': I, 'iob_tag': 'O'},
#   {'token': would, 'iob_tag': 'O'},
#   {'token': definently, 'iob_tag': 'O'},
#   {'token': recommend, 'iob_tag': 'O'},
#   {'token': this, 'iob_tag': 'O'},
#   {'token': restaurant, 'iob_tag': 'O'},
#   {'token': ., 'iob_tag': 'O'}],
#  [{'token': The, 'iob_tag': 'O'},
#   {'token': prices, 'iob_tag': 'B'},
#   {'token': are, 'iob_tag': 'O'},
#   {'token': wonderfully, 'iob_tag': 'O'},
#   {'token': low, 'iob_tag': 'O'},
#   {'token': ., 'iob_tag': 'O'}],
#  [{'token': If, 'iob_tag': 'O'},
#   {'token': you, 'iob_tag': 'O'},
#   {'token': like, 'iob_tag': 'O'},
#   {'token': spicy, 'iob_tag': 'B'},
#   {'token': food, 'iob_tag': 'I'},
#   {'token': get, 'iob_tag': 'O'},
#   {'token': the, 'iob_tag': 'O'},
#   {'token': chicken, 'iob_tag': 'B'},
#   {'token': vindaloo, 'iob_tag': 'I'},
#   {'token': ., 'iob_tag': 'O'}],
#  [{'token': I, 'iob_tag': 'O'},
#   {'token': lOVE, 'iob_tag': 'O'},
#   {'token': THIS, 'iob_tag': 'O'},
#   {'token': PLACE, 'iob_tag': 'O'},
#   {'token': !, 'iob_tag': 'O'}],
#  [{'token': I, 'iob_tag': 'O'},
#   {'token': have, 'iob_tag': 'O'},
#   {'token': never, 'iob_tag': 'O'},
#   {'token': been, 'iob_tag': 'O'},
#   {'token': disappointed, 'iob_tag': 'O'},
#   {'token': but, 'iob_tag': 'O'},
#   {'token': their, 'iob_tag': 'O'},
#   {'token': true, 'iob_tag': 'O'},
#   {'token': strength, 'iob_tag': 'O'},
#   {'token': lays, 'iob_tag': 'O'},
#   {'token': in, 'iob_tag': 'O'},
#   {'token': their, 'iob_tag': 'O'},
#   {'token': amazingly, 'iob_tag': 'O'},
#   {'token': delicious, 'iob_tag': 'O'},
#   {'token': and, 'iob_tag': 'O'},
#   {'token': cheap, 'iob_tag': 'O'},
#   {'token': lunch, 'iob_tag': 'B'},
#   {'token': specials, 'iob_tag': 'I'},
#   {'token': ., 'iob_tag': 'O'}],
#  [{'token': So, 'iob_tag': 'O'},
#   {'token': much, 'iob_tag': 'O'},
#   {'token': more, 'iob_tag': 'O'},
#   {'token': than, 'iob_tag': 'O'},
#   {'token': the, 'iob_tag': 'O'},
#   {'token': usual, 'iob_tag': 'O'},
#   {'token': bar, 'iob_tag': 'B'},
#   {'token': food, 'iob_tag': 'I'},
#   {'token': ,, 'iob_tag': 'O'},
#   {'token': go, 'iob_tag': 'O'},
#   {'token': there, 'iob_tag': 'O'},
#   {'token': to, 'iob_tag': 'O'},
#   {'token': enjoy, 'iob_tag': 'O'},
#   {'token': the, 'iob_tag': 'O'},
#   {'token': menu, 'iob_tag': 'B'},
#   {'token': while, 'iob_tag': 'O'},
#   {'token': sampling, 'iob_tag': 'O'},
#   {'token': one, 'iob_tag': 'O'},
#   {'token': of, 'iob_tag': 'O'},
#   {'token': their, 'iob_tag': 'O'},
#   {'token': hand, 'iob_tag': 'B'},
#   {'token': -, 'iob_tag': 'I'},
#   {'token': crafted, 'iob_tag': 'I'},
#   {'token': beers, 'iob_tag': 'I'},
#   {'token': ., 'iob_tag': 'O'}],
#  [{'token': A, 'iob_tag': 'O'},
#   {'token': big, 'iob_tag': 'O'},
#   {'token': disappointment, 'iob_tag': 'O'},
#   {'token': ,, 'iob_tag': 'O'},
#   {'token': all, 'iob_tag': 'O'},
#   {'token': around, 'iob_tag': 'O'},
#   {'token': ., 'iob_tag': 'O'}],
#  [{'token': And, 'iob_tag': 'O'},
#   {'token': its, 'iob_tag': 'O'},
#   {'token': absolutely, 'iob_tag': 'O'},
#   {'token': DELICIOUS, 'iob_tag': 'O'},
#   {'token': ., 'iob_tag': 'O'}],
#  [{'token': No, 'iob_tag': 'O'},
#   {'token': free, 'iob_tag': 'O'},
#   {'token': drink, 'iob_tag': 'B'},
#   {'token': ., 'iob_tag': 'O'}],
#  [{'token': I, 'iob_tag': 'O'},
#   {'token': would, 'iob_tag': 'O'},
#   {'token': say, 'iob_tag': 'O'},
#   {'token': that, 'iob_tag': 'O'},
#   {'token': all, 'iob_tag': 'O'},
#   {'token': was, 'iob_tag': 'O'},
#   {'token': fine, 'iob_tag': 'O'},
#   {'token': and, 'iob_tag': 'O'},
#   {'token': tasty, 'iob_tag': 'O'},
#   {'token': but, 'iob_tag': 'O'},
#   {'token': the, 'iob_tag': 'O'},
#   {'token': heaviness, 'iob_tag': 'O'},
#   {'token': on, 'iob_tag': 'O'},
#   {'token': my, 'iob_tag': 'O'},
#   {'token': stomach, 'iob_tag': 'O'},
#   {'token': someting, 'iob_tag': 'O'},
#   {'token': that, 'iob_tag': 'O'},
#   {'token': i, 'iob_tag': 'O'},
#   {'token': ca, 'iob_tag': 'O'},
#   {'token': n't, 'iob_tag': 'O'},
#   {'token': not, 'iob_tag': 'O'},
#   {'token': mention, 'iob_tag': 'O'},
#   {'token': or, 'iob_tag': 'O'},
#   {'token': undermine, 'iob_tag': 'O'},
#   {'token': ., 'iob_tag': 'O'}],
#  [{'token': This, 'iob_tag': 'O'},
#   {'token': is, 'iob_tag': 'O'},
#   {'token': my, 'iob_tag': 'O'},
#   {'token': first, 'iob_tag': 'O'},
#   {'token': time, 'iob_tag': 'O'},
#   {'token': writing, 'iob_tag': 'O'},
#   {'token': a, 'iob_tag': 'O'},
#   {'token': review, 'iob_tag': 'O'},
#   {'token': for, 'iob_tag': 'O'},
#   {'token': a, 'iob_tag': 'O'},
#   {'token': restaurant, 'iob_tag': 'O'},
#   {'token': because, 'iob_tag': 'O'},
#   {'token': the, 'iob_tag': 'O'},
#   {'token': food, 'iob_tag': 'B'},
#   {'token': and, 'iob_tag': 'O'},
#   {'token': service, 'iob_tag': 'B'},
#   {'token': was, 'iob_tag': 'O'},
#   {'token': excellent, 'iob_tag': 'O'},
#   {'token': ., 'iob_tag': 'O'}],
#  [{'token': Definitely, 'iob_tag': 'O'},
#   {'token': Highly, 'iob_tag': 'O'},
#   {'token': NOT, 'iob_tag': 'O'},
#   {'token': recommended, 'iob_tag': 'O'},
#   {'token': ., 'iob_tag': 'O'}],
#  [{'token': While, 'iob_tag': 'O'},
#   {'token': they, 'iob_tag': 'O'},
#   {'token': keep, 'iob_tag': 'O'},
#   {'token': the, 'iob_tag': 'O'},
#   {'token': capex, 'iob_tag': 'B'},
#   {'token': to, 'iob_tag': 'O'},
#   {'token': a, 'iob_tag': 'O'},
#   {'token': minimum, 'iob_tag': 'O'},
#   {'token': ,, 'iob_tag': 'O'},
#   {'token': they, 'iob_tag': 'O'},
#   {'token': do, 'iob_tag': 'O'},
#   {'token': put, 'iob_tag': 'O'},
#   {'token': some, 'iob_tag': 'O'},
#   {'token': cash, 'iob_tag': 'O'},
#   {'token': into, 'iob_tag': 'O'},
#   {'token': the, 'iob_tag': 'O'},
#   {'token': bagels, 'iob_tag': 'B'},
#   {'token': ,, 'iob_tag': 'O'},
#   {'token': because, 'iob_tag': 'O'},
#   {'token': they, 'iob_tag': 'O'},
#   {'token': among, 'iob_tag': 'O'},
#   {'token': the, 'iob_tag': 'O'},
#   {'token': best, 'iob_tag': 'O'},
#   {'token': in, 'iob_tag': 'O'},
#   {'token': the, 'iob_tag': 'O'},
#   {'token': city, 'iob_tag': 'O'},
#   {'token': ., 'iob_tag': 'O'}],
#  [{'token': I, 'iob_tag': 'O'},
#   {'token': had, 'iob_tag': 'O'},
#   {'token': a, 'iob_tag': 'O'},
#   {'token': huge, 'iob_tag': 'O'},
#   {'token': group, 'iob_tag': 'O'},
#   {'token': for, 'iob_tag': 'O'},
#   {'token': my, 'iob_tag': 'O'},
#   {'token': birthday, 'iob_tag': 'O'},
#   {'token': and, 'iob_tag': 'O'},
#   {'token': we, 'iob_tag': 'O'},
#   {'token': were, 'iob_tag': 'O'},
#   {'token': well, 'iob_tag': 'O'},
#   {'token': taken, 'iob_tag': 'O'},
#   {'token': care, 'iob_tag': 'O'},
#   {'token': of, 'iob_tag': 'O'},
#   {'token': ., 'iob_tag': 'O'}],
#  [{'token': The, 'iob_tag': 'O'},
#   {'token': two, 'iob_tag': 'O'},
#   {'token': star, 'iob_tag': 'O'},
#   {'token': chefs, 'iob_tag': 'B'},
#   {'token': left, 'iob_tag': 'O'},
#   {'token': quite, 'iob_tag': 'O'},
#   {'token': some, 'iob_tag': 'O'},
#   {'token': time, 'iob_tag': 'O'},
#   {'token': ago, 'iob_tag': 'O'},
#   {'token': to, 'iob_tag': 'O'},
#   {'token': open, 'iob_tag': 'O'},
#   {'token': their, 'iob_tag': 'O'},
#   {'token': own, 'iob_tag': 'O'},
#   {'token': place, 'iob_tag': 'O'},
#   {'token': ., 'iob_tag': 'O'}],
#  [{'token': Do, 'iob_tag': 'O'},
#   {'token': n't, 'iob_tag': 'O'},
#   {'token': waste, 'iob_tag': 'O'},
#   {'token': money, 'iob_tag': 'O'},
#   {'token': on, 'iob_tag': 'O'},
#   {'token': decor, 'iob_tag': 'B'},
#   {'token': ., 'iob_tag': 'O'}],
#  [{'token': They, 'iob_tag': 'O'},
#   {'token': also, 'iob_tag': 'O'},
#   {'token': have, 'iob_tag': 'O'},
#   {'token': a, 'iob_tag': 'O'},
#   {'token': back, 'iob_tag': 'B'},
#   {'token': garden, 'iob_tag': 'I'},
#   {'token': open, 'iob_tag': 'O'},
#   {'token': in, 'iob_tag': 'O'},
#   {'token': the, 'iob_tag': 'O'},
#   {'token': summer, 'iob_tag': 'O'},
#   {'token': -, 'iob_tag': 'O'},
#   {'token': cute, 'iob_tag': 'O'},
#   {'token': and, 'iob_tag': 'O'},
#   {'token': French, 'iob_tag': 'O'},
#   {'token': with, 'iob_tag': 'O'},
#   {'token': outdoor, 'iob_tag': 'B'},
#   {'token': seating, 'iob_tag': 'I'},
#   {'token': -, 'iob_tag': 'O'},
#   {'token': what, 'iob_tag': 'O'},
#   {'token': more, 'iob_tag': 'O'},
#   {'token': could, 'iob_tag': 'O'},
#   {'token': you, 'iob_tag': 'O'},
#   {'token': ask, 'iob_tag': 'O'},
#   {'token': for, 'iob_tag': 'O'},
#   {'token': ?, 'iob_tag': 'O'}],
#  [{'token': go, 'iob_tag': 'O'},
#   {'token': to, 'iob_tag': 'O'},
#   {'token': any, 'iob_tag': 'O'},
#   {'token': corned, 'iob_tag': 'O'},
#   {'token': indian, 'iob_tag': 'O'},
#   {'token': restaurant, 'iob_tag': 'O'},
#   {'token': ,, 'iob_tag': 'O'},
#   {'token': and, 'iob_tag': 'O'},
#   {'token': the, 'iob_tag': 'O'},
#   {'token': little, 'iob_tag': 'O'},
#   {'token': india, 'iob_tag': 'O'},
#   {'token': strip, 'iob_tag': 'O'},
#   {'token': along, 'iob_tag': 'O'},
#   {'token': east, 'iob_tag': 'O'},
#   {'token': 6, 'iob_tag': 'O'},
#   {'token': st, 'iob_tag': 'O'},
#   {'token': rules, 'iob_tag': 'O'},
#   {'token': supreme, 'iob_tag': 'O'},
#   {'token': !, 'iob_tag': 'O'}],
#  [{'token': I, 'iob_tag': 'O'},
#   {'token': have, 'iob_tag': 'O'},
#   {'token': never, 'iob_tag': 'O'},
#   {'token': before, 'iob_tag': 'O'},
#   {'token': eaten, 'iob_tag': 'O'},
#   {'token': 40, 'iob_tag': 'O'},
#   {'token': pieces, 'iob_tag': 'O'},
#   {'token': of, 'iob_tag': 'O'},
#   {'token': relatively, 'iob_tag': 'O'},
#   {'token': good, 'iob_tag': 'O'},
#   {'token': nigiri, 'iob_tag': 'B'},
#   {'token': ., 'iob_tag': 'O'}],
#  ...]

# %% [markdown]
# Although I do not have access to the tokeniser used creating the original dataset, the check function I implemented above, as well as taking a quick look at the data myself has led me to conclude that that the character-based tagging was a success!
#
# Now I just need to do some feature engineering.  The following features are commonly used in this domain and include each token's part-of-speech tag and syntactic dependencies, as well as those of the surrounding tokens.

# %%
for sentence_list in token_list:
    for i in range(len(sentence_list)):
        token = sentence_list[i]
        token['text'] = token['token'].text
        token['pos'] = token['token'].pos_
        token['tag'] = token['token'].tag_
        token['dep'] = token['token'].dep_
        token['is_punct'] = token['token'].is_punct
        
        
        if i > 0:
            prev_token_1 = sentence_list[i-1]
            token['-1: pos'] = prev_token_1['token'].pos_
            token['-1: tag'] = prev_token_1['token'].tag_
            token['-1: dep'] = prev_token_1['token'].dep_
        
        if i > 1:
            prev_token_2 = sentence_list[i-2]
            token['-2: pos'] = prev_token_2['token'].pos_
            token['-2: tag'] = prev_token_2['token'].tag_
            token['-2: dep'] = prev_token_2['token'].dep_
        
        if i > 2:
            prev_token_3 = sentence_list[i-3]
            token['-3: pos'] = prev_token_3['token'].pos_
            token['-3: tag'] = prev_token_3['token'].tag_
            token['-3: dep'] = prev_token_3['token'].dep_

# %%
token_list[0]
# Out:
# [{'token': But,
#   'iob_tag': 'O',
#   'text': 'But',
#   'pos': 'CCONJ',
#   'tag': 'CC',
#   'dep': 'cc',
#   'is_punct': False},
#  {'token': the,
#   'iob_tag': 'O',
#   'text': 'the',
#   'pos': 'DET',
#   'tag': 'DT',
#   'dep': 'det',
#   'is_punct': False,
#   '-1: pos': 'CCONJ',
#   '-1: tag': 'CC',
#   '-1: dep': 'cc'},
#  {'token': staff,
#   'iob_tag': 'B',
#   'text': 'staff',
#   'pos': 'NOUN',
#   'tag': 'NN',
#   'dep': 'nsubj',
#   'is_punct': False,
#   '-1: pos': 'DET',
#   '-1: tag': 'DT',
#   '-1: dep': 'det',
#   '-2: pos': 'CCONJ',
#   '-2: tag': 'CC',
#   '-2: dep': 'cc'},
#  {'token': was,
#   'iob_tag': 'O',
#   'text': 'was',
#   'pos': 'VERB',
#   'tag': 'VBD',
#   'dep': 'ROOT',
#   'is_punct': False,
#   '-1: pos': 'NOUN',
#   '-1: tag': 'NN',
#   '-1: dep': 'nsubj',
#   '-2: pos': 'DET',
#   '-2: tag': 'DT',
#   '-2: dep': 'det',
#   '-3: pos': 'CCONJ',
#   '-3: tag': 'CC',
#   '-3: dep': 'cc'},
#  {'token': so,
#   'iob_tag': 'O',
#   'text': 'so',
#   'pos': 'ADV',
#   'tag': 'RB',
#   'dep': 'advmod',
#   'is_punct': False,
#   '-1: pos': 'VERB',
#   '-1: tag': 'VBD',
#   '-1: dep': 'ROOT',
#   '-2: pos': 'NOUN',
#   '-2: tag': 'NN',
#   '-2: dep': 'nsubj',
#   '-3: pos': 'DET',
#   '-3: tag': 'DT',
#   '-3: dep': 'det'},
#  {'token': horrible,
#   'iob_tag': 'O',
#   'text': 'horrible',
#   'pos': 'ADJ',
#   'tag': 'JJ',
#   'dep': 'acomp',
#   'is_punct': False,
#   '-1: pos': 'ADV',
#   '-1: tag': 'RB',
#   '-1: dep': 'advmod',
#   '-2: pos': 'VERB',
#   '-2: tag': 'VBD',
#   '-2: dep': 'ROOT',
#   '-3: pos': 'NOUN',
#   '-3: tag': 'NN',
#   '-3: dep': 'nsubj'},
#  {'token': to,
#   'iob_tag': 'O',
#   'text': 'to',
#   'pos': 'ADP',
#   'tag': 'IN',
#   'dep': 'prep',
#   'is_punct': False,
#   '-1: pos': 'ADJ',
#   '-1: tag': 'JJ',
#   '-1: dep': 'acomp',
#   '-2: pos': 'ADV',
#   '-2: tag': 'RB',
#   '-2: dep': 'advmod',
#   '-3: pos': 'VERB',
#   '-3: tag': 'VBD',
#   '-3: dep': 'ROOT'},
#  {'token': us,
#   'iob_tag': 'O',
#   'text': 'us',
#   'pos': 'PRON',
#   'tag': 'PRP',
#   'dep': 'pobj',
#   'is_punct': False,
#   '-1: pos': 'ADP',
#   '-1: tag': 'IN',
#   '-1: dep': 'prep',
#   '-2: pos': 'ADJ',
#   '-2: tag': 'JJ',
#   '-2: dep': 'acomp',
#   '-3: pos': 'ADV',
#   '-3: tag': 'RB',
#   '-3: dep': 'advmod'},
#  {'token': .,
#   'iob_tag': 'O',
#   'text': '.',
#   'pos': 'PUNCT',
#   'tag': '.',
#   'dep': 'punct',
#   'is_punct': True,
#   '-1: pos': 'PRON',
#   '-1: tag': 'PRP',
#   '-1: dep': 'pobj',
#   '-2: pos': 'ADP',
#   '-2: tag': 'IN',
#   '-2: dep': 'prep',
#   '-3: pos': 'ADJ',
#   '-3: tag': 'JJ',
#   '-3: dep': 'acomp'}]

# %% [markdown]
# As we can't use pickle to save spacy objects, the last thing to do is delete the token item in each dict with just the text it contains.

# %%
for sentence in token_list:
    for token in sentence:
        token.pop('token')

# %%
token_list[0]
# Out:
# [{'iob_tag': 'O',
#   'text': 'But',
#   'pos': 'CCONJ',
#   'tag': 'CC',
#   'dep': 'cc',
#   'is_punct': False},
#  {'iob_tag': 'O',
#   'text': 'the',
#   'pos': 'DET',
#   'tag': 'DT',
#   'dep': 'det',
#   'is_punct': False,
#   '-1: pos': 'CCONJ',
#   '-1: tag': 'CC',
#   '-1: dep': 'cc'},
#  {'iob_tag': 'B',
#   'text': 'staff',
#   'pos': 'NOUN',
#   'tag': 'NN',
#   'dep': 'nsubj',
#   'is_punct': False,
#   '-1: pos': 'DET',
#   '-1: tag': 'DT',
#   '-1: dep': 'det',
#   '-2: pos': 'CCONJ',
#   '-2: tag': 'CC',
#   '-2: dep': 'cc'},
#  {'iob_tag': 'O',
#   'text': 'was',
#   'pos': 'VERB',
#   'tag': 'VBD',
#   'dep': 'ROOT',
#   'is_punct': False,
#   '-1: pos': 'NOUN',
#   '-1: tag': 'NN',
#   '-1: dep': 'nsubj',
#   '-2: pos': 'DET',
#   '-2: tag': 'DT',
#   '-2: dep': 'det',
#   '-3: pos': 'CCONJ',
#   '-3: tag': 'CC',
#   '-3: dep': 'cc'},
#  {'iob_tag': 'O',
#   'text': 'so',
#   'pos': 'ADV',
#   'tag': 'RB',
#   'dep': 'advmod',
#   'is_punct': False,
#   '-1: pos': 'VERB',
#   '-1: tag': 'VBD',
#   '-1: dep': 'ROOT',
#   '-2: pos': 'NOUN',
#   '-2: tag': 'NN',
#   '-2: dep': 'nsubj',
#   '-3: pos': 'DET',
#   '-3: tag': 'DT',
#   '-3: dep': 'det'},
#  {'iob_tag': 'O',
#   'text': 'horrible',
#   'pos': 'ADJ',
#   'tag': 'JJ',
#   'dep': 'acomp',
#   'is_punct': False,
#   '-1: pos': 'ADV',
#   '-1: tag': 'RB',
#   '-1: dep': 'advmod',
#   '-2: pos': 'VERB',
#   '-2: tag': 'VBD',
#   '-2: dep': 'ROOT',
#   '-3: pos': 'NOUN',
#   '-3: tag': 'NN',
#   '-3: dep': 'nsubj'},
#  {'iob_tag': 'O',
#   'text': 'to',
#   'pos': 'ADP',
#   'tag': 'IN',
#   'dep': 'prep',
#   'is_punct': False,
#   '-1: pos': 'ADJ',
#   '-1: tag': 'JJ',
#   '-1: dep': 'acomp',
#   '-2: pos': 'ADV',
#   '-2: tag': 'RB',
#   '-2: dep': 'advmod',
#   '-3: pos': 'VERB',
#   '-3: tag': 'VBD',
#   '-3: dep': 'ROOT'},
#  {'iob_tag': 'O',
#   'text': 'us',
#   'pos': 'PRON',
#   'tag': 'PRP',
#   'dep': 'pobj',
#   'is_punct': False,
#   '-1: pos': 'ADP',
#   '-1: tag': 'IN',
#   '-1: dep': 'prep',
#   '-2: pos': 'ADJ',
#   '-2: tag': 'JJ',
#   '-2: dep': 'acomp',
#   '-3: pos': 'ADV',
#   '-3: tag': 'RB',
#   '-3: dep': 'advmod'},
#  {'iob_tag': 'O',
#   'text': '.',
#   'pos': 'PUNCT',
#   'tag': '.',
#   'dep': 'punct',
#   'is_punct': True,
#   '-1: pos': 'PRON',
#   '-1: tag': 'PRP',
#   '-1: dep': 'pobj',
#   '-2: pos': 'ADP',
#   '-2: tag': 'IN',
#   '-2: dep': 'prep',
#   '-3: pos': 'ADJ',
#   '-3: tag': 'JJ',
#   '-3: dep': 'acomp'}]

# %% [markdown]
# Looks good! Now we can save it.

# %%
with open('restaurant_iob.pickle', 'wb') as handle:
    pickle.dump(token_list, handle)
