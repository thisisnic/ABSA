# %% [markdown]
# In this notebook, I will use linear chain CRF to predict aspect terms for the restaurants dataset, but this time without the terms themselves.

# %%
import pickle
with open('restaurant_iob.pickle', 'rb') as handle:
    data = pickle.load(handle)

# %%
data[0]
# Out:
# [{'iob_tag': 'O',
#   'text': 'But',
#   'pos': 'CCONJ',
#   'tag': 'CC',
#   'dep': 'cc',
#   'is_punct': False},
#  {'iob_tag': 'O',
#   'text': 'the',
#   'pos': 'DET',
#   'tag': 'DT',
#   'dep': 'det',
#   'is_punct': False,
#   '-1: pos': 'CCONJ',
#   '-1: tag': 'CC',
#   '-1: dep': 'cc'},
#  {'iob_tag': 'B',
#   'text': 'staff',
#   'pos': 'NOUN',
#   'tag': 'NN',
#   'dep': 'nsubj',
#   'is_punct': False,
#   '-1: pos': 'DET',
#   '-1: tag': 'DT',
#   '-1: dep': 'det',
#   '-2: pos': 'CCONJ',
#   '-2: tag': 'CC',
#   '-2: dep': 'cc'},
#  {'iob_tag': 'O',
#   'text': 'was',
#   'pos': 'VERB',
#   'tag': 'VBD',
#   'dep': 'ROOT',
#   'is_punct': False,
#   '-1: pos': 'NOUN',
#   '-1: tag': 'NN',
#   '-1: dep': 'nsubj',
#   '-2: pos': 'DET',
#   '-2: tag': 'DT',
#   '-2: dep': 'det',
#   '-3: pos': 'CCONJ',
#   '-3: tag': 'CC',
#   '-3: dep': 'cc'},
#  {'iob_tag': 'O',
#   'text': 'so',
#   'pos': 'ADV',
#   'tag': 'RB',
#   'dep': 'advmod',
#   'is_punct': False,
#   '-1: pos': 'VERB',
#   '-1: tag': 'VBD',
#   '-1: dep': 'ROOT',
#   '-2: pos': 'NOUN',
#   '-2: tag': 'NN',
#   '-2: dep': 'nsubj',
#   '-3: pos': 'DET',
#   '-3: tag': 'DT',
#   '-3: dep': 'det'},
#  {'iob_tag': 'O',
#   'text': 'horrible',
#   'pos': 'ADJ',
#   'tag': 'JJ',
#   'dep': 'acomp',
#   'is_punct': False,
#   '-1: pos': 'ADV',
#   '-1: tag': 'RB',
#   '-1: dep': 'advmod',
#   '-2: pos': 'VERB',
#   '-2: tag': 'VBD',
#   '-2: dep': 'ROOT',
#   '-3: pos': 'NOUN',
#   '-3: tag': 'NN',
#   '-3: dep': 'nsubj'},
#  {'iob_tag': 'O',
#   'text': 'to',
#   'pos': 'ADP',
#   'tag': 'IN',
#   'dep': 'prep',
#   'is_punct': False,
#   '-1: pos': 'ADJ',
#   '-1: tag': 'JJ',
#   '-1: dep': 'acomp',
#   '-2: pos': 'ADV',
#   '-2: tag': 'RB',
#   '-2: dep': 'advmod',
#   '-3: pos': 'VERB',
#   '-3: tag': 'VBD',
#   '-3: dep': 'ROOT'},
#  {'iob_tag': 'O',
#   'text': 'us',
#   'pos': 'PRON',
#   'tag': 'PRP',
#   'dep': 'pobj',
#   'is_punct': False,
#   '-1: pos': 'ADP',
#   '-1: tag': 'IN',
#   '-1: dep': 'prep',
#   '-2: pos': 'ADJ',
#   '-2: tag': 'JJ',
#   '-2: dep': 'acomp',
#   '-3: pos': 'ADV',
#   '-3: tag': 'RB',
#   '-3: dep': 'advmod'},
#  {'iob_tag': 'O',
#   'text': '.',
#   'pos': 'PUNCT',
#   'tag': '.',
#   'dep': 'punct',
#   'is_punct': True,
#   '-1: pos': 'PRON',
#   '-1: tag': 'PRP',
#   '-1: dep': 'pobj',
#   '-2: pos': 'ADP',
#   '-2: tag': 'IN',
#   '-2: dep': 'prep',
#   '-3: pos': 'ADJ',
#   '-3: tag': 'JJ',
#   '-3: dep': 'acomp'}]

# %%
import sklearn_crfsuite
from sklearn_crfsuite import scorers
from sklearn_crfsuite import metrics

# %% [markdown]
# # Train/test split
#
# 80/20 split

# %%
import copy
train = data[0:2435]
test = data[2435:]

# %%
train[0]
# Out:
# [{'iob_tag': 'O',
#   'text': 'But',
#   'pos': 'CCONJ',
#   'tag': 'CC',
#   'dep': 'cc',
#   'is_punct': False},
#  {'iob_tag': 'O',
#   'text': 'the',
#   'pos': 'DET',
#   'tag': 'DT',
#   'dep': 'det',
#   'is_punct': False,
#   '-1: pos': 'CCONJ',
#   '-1: tag': 'CC',
#   '-1: dep': 'cc'},
#  {'iob_tag': 'B',
#   'text': 'staff',
#   'pos': 'NOUN',
#   'tag': 'NN',
#   'dep': 'nsubj',
#   'is_punct': False,
#   '-1: pos': 'DET',
#   '-1: tag': 'DT',
#   '-1: dep': 'det',
#   '-2: pos': 'CCONJ',
#   '-2: tag': 'CC',
#   '-2: dep': 'cc'},
#  {'iob_tag': 'O',
#   'text': 'was',
#   'pos': 'VERB',
#   'tag': 'VBD',
#   'dep': 'ROOT',
#   'is_punct': False,
#   '-1: pos': 'NOUN',
#   '-1: tag': 'NN',
#   '-1: dep': 'nsubj',
#   '-2: pos': 'DET',
#   '-2: tag': 'DT',
#   '-2: dep': 'det',
#   '-3: pos': 'CCONJ',
#   '-3: tag': 'CC',
#   '-3: dep': 'cc'},
#  {'iob_tag': 'O',
#   'text': 'so',
#   'pos': 'ADV',
#   'tag': 'RB',
#   'dep': 'advmod',
#   'is_punct': False,
#   '-1: pos': 'VERB',
#   '-1: tag': 'VBD',
#   '-1: dep': 'ROOT',
#   '-2: pos': 'NOUN',
#   '-2: tag': 'NN',
#   '-2: dep': 'nsubj',
#   '-3: pos': 'DET',
#   '-3: tag': 'DT',
#   '-3: dep': 'det'},
#  {'iob_tag': 'O',
#   'text': 'horrible',
#   'pos': 'ADJ',
#   'tag': 'JJ',
#   'dep': 'acomp',
#   'is_punct': False,
#   '-1: pos': 'ADV',
#   '-1: tag': 'RB',
#   '-1: dep': 'advmod',
#   '-2: pos': 'VERB',
#   '-2: tag': 'VBD',
#   '-2: dep': 'ROOT',
#   '-3: pos': 'NOUN',
#   '-3: tag': 'NN',
#   '-3: dep': 'nsubj'},
#  {'iob_tag': 'O',
#   'text': 'to',
#   'pos': 'ADP',
#   'tag': 'IN',
#   'dep': 'prep',
#   'is_punct': False,
#   '-1: pos': 'ADJ',
#   '-1: tag': 'JJ',
#   '-1: dep': 'acomp',
#   '-2: pos': 'ADV',
#   '-2: tag': 'RB',
#   '-2: dep': 'advmod',
#   '-3: pos': 'VERB',
#   '-3: tag': 'VBD',
#   '-3: dep': 'ROOT'},
#  {'iob_tag': 'O',
#   'text': 'us',
#   'pos': 'PRON',
#   'tag': 'PRP',
#   'dep': 'pobj',
#   'is_punct': False,
#   '-1: pos': 'ADP',
#   '-1: tag': 'IN',
#   '-1: dep': 'prep',
#   '-2: pos': 'ADJ',
#   '-2: tag': 'JJ',
#   '-2: dep': 'acomp',
#   '-3: pos': 'ADV',
#   '-3: tag': 'RB',
#   '-3: dep': 'advmod'},
#  {'iob_tag': 'O',
#   'text': '.',
#   'pos': 'PUNCT',
#   'tag': '.',
#   'dep': 'punct',
#   'is_punct': True,
#   '-1: pos': 'PRON',
#   '-1: tag': 'PRP',
#   '-1: dep': 'pobj',
#   '-2: pos': 'ADP',
#   '-2: tag': 'IN',
#   '-2: dep': 'prep',
#   '-3: pos': 'ADJ',
#   '-3: tag': 'JJ',
#   '-3: dep': 'acomp'}]

# %% [markdown]
# Separate into X and y - the dict of features, and the correct IOB tag

# %%
y_train = [[token.pop('iob_tag') for token in sentence] for sentence in train]

# %%
[[token.pop('text') for token in sentence] for sentence in train]
X_train = train

# %% [markdown]
# # Fit the CRF Model

# %%
crf = sklearn_crfsuite.CRF(
    algorithm='lbfgs', 
    c1=0.1, 
    c2=0.1, 
    max_iterations=500, 
    all_possible_transitions=True
)
crf.fit(X_train, y_train)
# Out:
# c:\users\will\appdata\local\programs\python\python37\lib\site-packages\sklearn\base.py:197: FutureWarning: From version 0.24, get_params will raise an AttributeError if a parameter cannot be retrieved as an instance attribute. Previously it would return None.
#   FutureWarning)
# CRF(algorithm='lbfgs', all_possible_states=None, all_possible_transitions=True,
#     averaging=None, c=None, c1=0.1, c2=0.1, calibration_candidates=None,
#     calibration_eta=None, calibration_max_trials=None, calibration_rate=None,
#     calibration_samples=None, delta=None, epsilon=None, error_sensitive=None,
#     gamma=None, keep_tempfiles=None, linesearch=None, max_iterations=500,
#     max_linesearch=None, min_freq=None, model_filename=None, num_memories=None,
#     pa_type=None, period=None, trainer_cls=None, variance=None, verbose=False)

# %% [markdown]
# # Evaluate the Model

# %%
y_test = [[token.pop('iob_tag') for token in sentence] for sentence in test]
X_test = test

# %% [markdown]
# We remove the 'O' class otherwise our overall F1 score would be excessively high.

# %%
labels = list(crf.classes_)
labels.remove('O')

# %%
y_pred = crf.predict(X_test)
metrics.flat_f1_score(y_test, y_pred, average='weighted', labels=labels)
# Out:
# 0.5772470904926429

# %%
sorted_labels = sorted(labels, key=lambda name: (name[1:], name[0]))
print(metrics.flat_classification_report(
    y_test, y_pred, labels=sorted_labels, digits=3
))
# Out:
#               precision    recall  f1-score   support
#
#            B      0.671     0.534     0.595       738
#            I      0.552     0.512     0.531       281
#
#    micro avg      0.634     0.528     0.576      1019
#    macro avg      0.611     0.523     0.563      1019
# weighted avg      0.638     0.528     0.577      1019

# %% [markdown]
# The new model has an overall F1 score of 0.58.  It's not as good as the previous score of 0.77, but it's still a useful baseling.
#
# Let's take a look at the raw predictions again.

# %%
for x_sentence, y_tag, y_prediction in zip(X_test, y_test, y_pred):
    for x_token, y_truth, y_pred_val in zip(x_sentence, y_tag, y_prediction):
        print(x_token['text'] + "\t\t\t tag: " + y_truth + "\t prediction: " + y_pred_val + " " + str(y_pred_val==y_truth))
# Out:
# I			 tag: O	 prediction: O True
# was			 tag: O	 prediction: O True
# here			 tag: O	 prediction: O True
# a			 tag: O	 prediction: O True
# few			 tag: O	 prediction: O True
# weeks			 tag: O	 prediction: O True
# back			 tag: O	 prediction: O True
# and			 tag: O	 prediction: O True
# we			 tag: O	 prediction: O True
# had			 tag: O	 prediction: O True
# the			 tag: O	 prediction: O True
# worst			 tag: O	 prediction: O True
# customer			 tag: B	 prediction: B True
# service			 tag: I	 prediction: I True
# experience			 tag: O	 prediction: I False
# at			 tag: O	 prediction: O True
# a			 tag: O	 prediction: O True
# restaurant			 tag: O	 prediction: O True
# ever			 tag: O	 prediction: O True
# .			 tag: O	 prediction: O True
# (			 tag: O	 prediction: O True
# I			 tag: O	 prediction: O True
# 've			 tag: O	 prediction: O True
# ordered			 tag: O	 prediction: O True
# from			 tag: O	 prediction: O True
# the			 tag: O	 prediction: O True
# 2nd			 tag: O	 prediction: O True
# ave			 tag: O	 prediction: O True
# .			 tag: O	 prediction: O True
# Nothing			 tag: O	 prediction: B False
# against			 tag: O	 prediction: O True
# a			 tag: O	 prediction: O True
# good			 tag: O	 prediction: O True
# sales			 tag: O	 prediction: O True
# call			 tag: O	 prediction: O True
# ,			 tag: O	 prediction: O True
# but			 tag: O	 prediction: O True
# the			 tag: O	 prediction: O True
# tactics			 tag: O	 prediction: B False
# at			 tag: O	 prediction: O True
# Amma			 tag: O	 prediction: O True
# are			 tag: O	 prediction: O True
# just			 tag: O	 prediction: O True
# too			 tag: O	 prediction: O True
# obvious			 tag: O	 prediction: O True
# .			 tag: O	 prediction: O True
# Went			 tag: O	 prediction: O True
# on			 tag: O	 prediction: O True
# a			 tag: O	 prediction: O True
# 3			 tag: O	 prediction: O True
# day			 tag: O	 prediction: B False
# oyster			 tag: B	 prediction: I False
# binge			 tag: O	 prediction: I False
# ,			 tag: O	 prediction: O True
# with			 tag: O	 prediction: O True
# Fish			 tag: B	 prediction: O False
# bringing			 tag: O	 prediction: O True
# up			 tag: O	 prediction: O True
# the			 tag: O	 prediction: O True
# closing			 tag: O	 prediction: B False
# ,			 tag: O	 prediction: O True
# and			 tag: O	 prediction: O True
# I			 tag: O	 prediction: O True
# am			 tag: O	 prediction: O True
# so			 tag: O	 prediction: O True
# glad			 tag: O	 prediction: O True
# this			 tag: O	 prediction: O True
# was			 tag: O	 prediction: O True
# the			 tag: O	 prediction: O True
# place			 tag: B	 prediction: O False
# it			 tag: O	 prediction: O True
# O			 tag: O	 prediction: O True
# trip			 tag: O	 prediction: B False
# ended			 tag: O	 prediction: O True
# ,			 tag: O	 prediction: O True
# because			 tag: O	 prediction: O True
# it			 tag: O	 prediction: O True
# was			 tag: O	 prediction: O True
# so			 tag: O	 prediction: O True
# great			 tag: O	 prediction: O True
# !			 tag: O	 prediction: O True
# Took			 tag: O	 prediction: O True
# my			 tag: O	 prediction: O True
# mom			 tag: O	 prediction: O True
# for			 tag: O	 prediction: O True
# Mother			 tag: O	 prediction: O True
# 's			 tag: O	 prediction: O True
# Day			 tag: O	 prediction: O True
# ,			 tag: O	 prediction: O True
# and			 tag: O	 prediction: O True
# the			 tag: O	 prediction: O True
# maitre			 tag: B	 prediction: B True
# d			 tag: I	 prediction: I True
# '			 tag: I	 prediction: O False
# was			 tag: O	 prediction: O True
# pretty			 tag: O	 prediction: O True
# rude			 tag: O	 prediction: O True
# .			 tag: O	 prediction: O True
# My			 tag: O	 prediction: O True
# husband			 tag: O	 prediction: O True
# and			 tag: O	 prediction: O True
# I			 tag: O	 prediction: O True
# have			 tag: O	 prediction: O True
# been			 tag: O	 prediction: O True
# there			 tag: O	 prediction: O True
# a			 tag: O	 prediction: O True
# couple			 tag: O	 prediction: O True
# of			 tag: O	 prediction: O True
# times			 tag: O	 prediction: O True
# and			 tag: O	 prediction: O True
# each			 tag: O	 prediction: O True
# time			 tag: O	 prediction: O True
# we			 tag: O	 prediction: O True
# sat			 tag: O	 prediction: O True
# at			 tag: O	 prediction: O True
# the			 tag: O	 prediction: O True
# sushi			 tag: B	 prediction: B True
# bar			 tag: I	 prediction: I True
# (			 tag: O	 prediction: I False
# chef			 tag: B	 prediction: I False
# Yoshi			 tag: O	 prediction: I False
# )			 tag: O	 prediction: O True
# and			 tag: O	 prediction: O True
# ordered			 tag: O	 prediction: O True
# everything			 tag: O	 prediction: B False
# ala			 tag: B	 prediction: I False
# carte			 tag: I	 prediction: I True
# .			 tag: O	 prediction: O True
# The			 tag: O	 prediction: O True
# vibe			 tag: B	 prediction: B True
# is			 tag: O	 prediction: O True
# very			 tag: O	 prediction: O True
# relaxed			 tag: O	 prediction: O True
# and			 tag: O	 prediction: O True
# cozy			 tag: O	 prediction: O True
# ,			 tag: O	 prediction: O True
# service			 tag: B	 prediction: B True
# was			 tag: O	 prediction: O True
# great			 tag: O	 prediction: O True
# and			 tag: O	 prediction: O True
# the			 tag: O	 prediction: O True
# food			 tag: B	 prediction: B True
# was			 tag: O	 prediction: O True
# excellent			 tag: O	 prediction: O True
# !			 tag: O	 prediction: O True
# If			 tag: O	 prediction: O True
# the			 tag: O	 prediction: O True
# weather			 tag: O	 prediction: B False
# is			 tag: O	 prediction: O True
# nice			 tag: O	 prediction: O True
# ,			 tag: O	 prediction: O True
# try			 tag: O	 prediction: O True
# to			 tag: O	 prediction: O True
# snag			 tag: O	 prediction: O True
# an			 tag: O	 prediction: O True
# outside			 tag: O	 prediction: O True
# table			 tag: B	 prediction: O False
# .			 tag: O	 prediction: O True
# If			 tag: O	 prediction: O True
# you			 tag: O	 prediction: O True
# are			 tag: O	 prediction: O True
# looking			 tag: O	 prediction: O True
# for			 tag: O	 prediction: O True
# a			 tag: O	 prediction: O True
# good			 tag: O	 prediction: O True
# quality			 tag: B	 prediction: O False
# ,			 tag: O	 prediction: O True
# cheap			 tag: O	 prediction: O True
# eats			 tag: O	 prediction: O True
# -			 tag: O	 prediction: O True
# this			 tag: O	 prediction: O True
# is			 tag: O	 prediction: O True
# the			 tag: O	 prediction: O True
# place			 tag: O	 prediction: O True
# .			 tag: O	 prediction: O True
# However			 tag: O	 prediction: O True
# ,			 tag: O	 prediction: O True
# for			 tag: O	 prediction: O True
# what			 tag: O	 prediction: O True
# we			 tag: O	 prediction: O True
# spent			 tag: O	 prediction: O True
# ,			 tag: O	 prediction: O True
# overall			 tag: O	 prediction: O True
# ,			 tag: O	 prediction: O True
# it			 tag: O	 prediction: O True
# just			 tag: O	 prediction: O True
# was			 tag: O	 prediction: O True
# not			 tag: O	 prediction: O True
# up			 tag: O	 prediction: O True
# to			 tag: O	 prediction: O True
# par			 tag: O	 prediction: O True
# .			 tag: O	 prediction: O True
# The			 tag: O	 prediction: O True
# service			 tag: B	 prediction: B True
# was			 tag: O	 prediction: O True
# friendly			 tag: O	 prediction: O True
# and			 tag: O	 prediction: O True
# the			 tag: O	 prediction: O True
# atmosphere			 tag: B	 prediction: B True
# was			 tag: O	 prediction: O True
# casual			 tag: O	 prediction: O True
# .			 tag: O	 prediction: O True
# A			 tag: O	 prediction: O True
# friend			 tag: O	 prediction: B False
# from			 tag: O	 prediction: O True
# Seattle			 tag: O	 prediction: O True
# and			 tag: O	 prediction: O True
# I			 tag: O	 prediction: O True
# went			 tag: O	 prediction: O True
# on			 tag: O	 prediction: O True
# a			 tag: O	 prediction: O True
# Thursday			 tag: O	 prediction: O True
# night			 tag: O	 prediction: O True
# around			 tag: O	 prediction: O True
# 8:30			 tag: O	 prediction: O True
# .			 tag: O	 prediction: O True
# When			 tag: O	 prediction: O True
# I			 tag: O	 prediction: O True
# lived			 tag: O	 prediction: O True
# upstate			 tag: O	 prediction: O True
# for			 tag: O	 prediction: O True
# a			 tag: O	 prediction: O True
# while			 tag: O	 prediction: O True
# I			 tag: O	 prediction: O True
# would			 tag: O	 prediction: O True
# buy			 tag: O	 prediction: O True
# freeze			 tag: O	 prediction: O True
# the			 tag: O	 prediction: O True
# bagels			 tag: B	 prediction: B True
# and			 tag: O	 prediction: O True
# they			 tag: O	 prediction: O True
# would			 tag: O	 prediction: O True
# still			 tag: O	 prediction: O True
# be			 tag: O	 prediction: O True
# better			 tag: O	 prediction: O True
# than			 tag: O	 prediction: O True
# any			 tag: O	 prediction: O True
# else			 tag: O	 prediction: O True
# .			 tag: O	 prediction: O True
# I			 tag: O	 prediction: O True
# recommend			 tag: O	 prediction: O True
# their			 tag: O	 prediction: O True
# Pad			 tag: B	 prediction: O False
# See			 tag: I	 prediction: O False
# Ew			 tag: I	 prediction: O False
# ,			 tag: O	 prediction: O True
# Pork			 tag: B	 prediction: O False
# Chops			 tag: I	 prediction: O False
# or			 tag: O	 prediction: O True
# Tofu			 tag: B	 prediction: O False
# plates			 tag: I	 prediction: O False
# .			 tag: O	 prediction: O True
# Never			 tag: O	 prediction: O True
# in			 tag: O	 prediction: O True
# my			 tag: O	 prediction: O True
# life			 tag: O	 prediction: O True
# did			 tag: O	 prediction: O True
# I			 tag: O	 prediction: O True
# think			 tag: O	 prediction: O True
# that			 tag: O	 prediction: O True
# I			 tag: O	 prediction: O True
# could			 tag: O	 prediction: O True
# be			 tag: O	 prediction: O True
# satisfied			 tag: O	 prediction: O True
# both			 tag: O	 prediction: O True
# in			 tag: O	 prediction: O True
# taste			 tag: B	 prediction: B True
# and			 tag: O	 prediction: O True
# in			 tag: O	 prediction: O True
# quantity			 tag: B	 prediction: B True
# for			 tag: O	 prediction: O True
# $			 tag: O	 prediction: O True
# 3.00			 tag: O	 prediction: O True
# in			 tag: O	 prediction: O True
# NYC			 tag: O	 prediction: O True
# .			 tag: O	 prediction: O True
# this			 tag: O	 prediction: O True
# is			 tag: O	 prediction: O True
# the			 tag: O	 prediction: O True
# best			 tag: O	 prediction: O True
# secret			 tag: O	 prediction: O True
# place			 tag: O	 prediction: O True
# in			 tag: O	 prediction: O True
# midtown			 tag: O	 prediction: O True
# '			 tag: O	 prediction: O True
# ,			 tag: O	 prediction: O True
# I			 tag: O	 prediction: O True
# heard			 tag: O	 prediction: O True
# that			 tag: O	 prediction: O True
# from			 tag: O	 prediction: O True
# the			 tag: O	 prediction: O True
# bartender			 tag: B	 prediction: O False
# ,			 tag: O	 prediction: O True
# after			 tag: O	 prediction: O True
# having			 tag: O	 prediction: O True
# brilliant			 tag: O	 prediction: O True
# food			 tag: B	 prediction: B True
# (			 tag: O	 prediction: O True
# try			 tag: O	 prediction: O True
# steak			 tag: B	 prediction: B True
# with			 tag: I	 prediction: O False
# portobello			 tag: I	 prediction: B False
# mushrooms			 tag: I	 prediction: I True
# )			 tag: O	 prediction: O True
# and			 tag: O	 prediction: O True
# drinks			 tag: B	 prediction: O False
# on			 tag: O	 prediction: O True
# the			 tag: O	 prediction: O True
# bar			 tag: B	 prediction: O False
# last			 tag: O	 prediction: O True
# Tuesday			 tag: O	 prediction: O True
# .			 tag: O	 prediction: O True
# The			 tag: O	 prediction: O True
# service			 tag: B	 prediction: B True
# was			 tag: O	 prediction: O True
# excellent			 tag: O	 prediction: O True
# -			 tag: O	 prediction: O True
# friendly			 tag: O	 prediction: O True
# and			 tag: O	 prediction: O True
# attentive			 tag: O	 prediction: O True
# .			 tag: O	 prediction: O True
# The			 tag: O	 prediction: O True
# main			 tag: B	 prediction: B True
# course			 tag: I	 prediction: I True
# had			 tag: O	 prediction: O True
# an			 tag: O	 prediction: O True
# average			 tag: O	 prediction: O True
# portion			 tag: B	 prediction: O False
# ,			 tag: O	 prediction: O True
# and			 tag: O	 prediction: O True
# was			 tag: O	 prediction: O True
# decent			 tag: O	 prediction: O True
# overall			 tag: O	 prediction: O True
# .			 tag: O	 prediction: O True
# 20			 tag: O	 prediction: O True
# minutes			 tag: O	 prediction: O True
# for			 tag: O	 prediction: O True
# our			 tag: O	 prediction: O True
# reservation			 tag: B	 prediction: O False
# but			 tag: O	 prediction: O True
# it			 tag: O	 prediction: O True
# gave			 tag: O	 prediction: O True
# us			 tag: O	 prediction: O True
# time			 tag: O	 prediction: O True
# to			 tag: O	 prediction: O True
# have			 tag: O	 prediction: O True
# a			 tag: O	 prediction: O True
# few			 tag: O	 prediction: O True
# cocktails			 tag: B	 prediction: B True
# and			 tag: O	 prediction: O True
# enjoy			 tag: O	 prediction: O True
# our			 tag: O	 prediction: O True
# surroundings			 tag: B	 prediction: O False
# and			 tag: O	 prediction: O True
# each			 tag: O	 prediction: O True
# other			 tag: O	 prediction: O True
# .			 tag: O	 prediction: O True
# Just			 tag: O	 prediction: O True
# remember			 tag: O	 prediction: O True
# ,			 tag: O	 prediction: O True
# the			 tag: O	 prediction: O True
# later			 tag: O	 prediction: O True
# you			 tag: O	 prediction: O True
# go			 tag: O	 prediction: O True
# ,			 tag: O	 prediction: O True
# the			 tag: O	 prediction: O True
# longer			 tag: O	 prediction: O True
# you			 tag: O	 prediction: O True
# may			 tag: O	 prediction: O True
# have			 tag: O	 prediction: O True
# to			 tag: O	 prediction: O True
# wait			 tag: O	 prediction: O True
# .			 tag: O	 prediction: O True
# Waitstaff			 tag: B	 prediction: O False
# is			 tag: O	 prediction: O True
# great			 tag: O	 prediction: O True
# ,			 tag: O	 prediction: O True
# very			 tag: O	 prediction: O True
# attentive			 tag: O	 prediction: O True
# .			 tag: O	 prediction: O True
# I			 tag: O	 prediction: O True
# live			 tag: O	 prediction: O True
# in			 tag: O	 prediction: O True
# the			 tag: O	 prediction: O True
# neightborhood			 tag: O	 prediction: O True
# and			 tag: O	 prediction: O True
# am			 tag: O	 prediction: O True
# a			 tag: O	 prediction: O True
# regular			 tag: O	 prediction: O True
# .			 tag: O	 prediction: O True
# The			 tag: O	 prediction: O True
# dinner			 tag: B	 prediction: B True
# menu			 tag: I	 prediction: I True
# is			 tag: O	 prediction: O True
# diverse			 tag: O	 prediction: O True
# and			 tag: O	 prediction: O True
# top			 tag: O	 prediction: O True
# -			 tag: O	 prediction: O True
# notch			 tag: O	 prediction: O True
# as			 tag: O	 prediction: O True
# well			 tag: O	 prediction: O True
# .			 tag: O	 prediction: O True
# IT			 tag: O	 prediction: O True
# IS			 tag: O	 prediction: O True
# WHAT			 tag: O	 prediction: O True
# MODERN			 tag: O	 prediction: O True
# CUISINE			 tag: B	 prediction: O False
# IS			 tag: O	 prediction: O True
# ALL			 tag: O	 prediction: O True
# ABOUT			 tag: O	 prediction: O True
# .			 tag: O	 prediction: O True
# In			 tag: O	 prediction: O True
# any			 tag: O	 prediction: O True
# event			 tag: O	 prediction: O True
# ,			 tag: O	 prediction: O True
# even			 tag: O	 prediction: O True
# though			 tag: O	 prediction: O True
# its			 tag: O	 prediction: O True
# a			 tag: O	 prediction: O True
# bit			 tag: O	 prediction: O True
# on			 tag: O	 prediction: O True
# the			 tag: O	 prediction: O True
# pricey			 tag: O	 prediction: O True
# side			 tag: O	 prediction: O True
# ,			 tag: O	 prediction: O True
# we			 tag: O	 prediction: O True
# still			 tag: O	 prediction: O True
# love			 tag: O	 prediction: O True
# this			 tag: O	 prediction: O True
# restaurant			 tag: O	 prediction: O True
# and			 tag: O	 prediction: O True
# will			 tag: O	 prediction: O True
# definitely			 tag: O	 prediction: O True
# go			 tag: O	 prediction: O True
# back			 tag: O	 prediction: O True
# .			 tag: O	 prediction: O True
# I			 tag: O	 prediction: O True
# definitely			 tag: O	 prediction: O True
# will			 tag: O	 prediction: O True
# go			 tag: O	 prediction: O True
# back			 tag: O	 prediction: O True
# .			 tag: O	 prediction: O True
# I			 tag: O	 prediction: O True
# do			 tag: O	 prediction: O True
# n't			 tag: O	 prediction: O True
# like			 tag: O	 prediction: O True
# Indian			 tag: B	 prediction: O False
# food			 tag: I	 prediction: B False
# too			 tag: O	 prediction: O True
# much			 tag: O	 prediction: O True
# and			 tag: O	 prediction: O True
# this			 tag: O	 prediction: O True
# was			 tag: O	 prediction: O True
# delicious			 tag: O	 prediction: O True
# ,			 tag: O	 prediction: O True
# however			 tag: O	 prediction: O True
# you			 tag: O	 prediction: O True
# want			 tag: O	 prediction: O True
# to			 tag: O	 prediction: O True
# factor			 tag: O	 prediction: O True
# that			 tag: O	 prediction: O True
# into			 tag: O	 prediction: O True
# the			 tag: O	 prediction: O True
# equation			 tag: O	 prediction: O True
# .			 tag: O	 prediction: O True
# at			 tag: O	 prediction: O True
# taj			 tag: O	 prediction: O True
# ,			 tag: O	 prediction: O True
# vegetarians			 tag: O	 prediction: B False
# can			 tag: O	 prediction: O True
# rejoice			 tag: O	 prediction: O True
# -			 tag: O	 prediction: O True
# all			 tag: O	 prediction: O True
# the			 tag: O	 prediction: O True
# dishes			 tag: B	 prediction: B True
# are			 tag: O	 prediction: O True
# manna			 tag: O	 prediction: O True
# from			 tag: O	 prediction: O True
# heaven			 tag: O	 prediction: O True
# .			 tag: O	 prediction: O True
# Finally			 tag: O	 prediction: O True
# !			 tag: O	 prediction: O True
# Forget			 tag: O	 prediction: O True
# the			 tag: O	 prediction: O True
# rush			 tag: B	 prediction: B True
# and			 tag: O	 prediction: O True
# the			 tag: O	 prediction: O True
# wait			 tag: B	 prediction: B True
# and			 tag: O	 prediction: O True
# the			 tag: O	 prediction: O True
# noise			 tag: B	 prediction: B True
# (			 tag: O	 prediction: O True
# which			 tag: O	 prediction: O True
# is			 tag: O	 prediction: O True
# n't			 tag: O	 prediction: O True
# actually			 tag: O	 prediction: O True
# that			 tag: O	 prediction: O True
# bad			 tag: O	 prediction: O True
# )			 tag: O	 prediction: O True
# ,			 tag: O	 prediction: O True
# I			 tag: O	 prediction: O True
# mean			 tag: O	 prediction: O True
# please			 tag: O	 prediction: O True
# ,			 tag: O	 prediction: O True
# who			 tag: O	 prediction: O True
# goes			 tag: O	 prediction: O True
# to			 tag: O	 prediction: O True
# a			 tag: O	 prediction: O True
# steakhouse			 tag: O	 prediction: O True
# to			 tag: O	 prediction: O True
# be			 tag: O	 prediction: O True
# coddled			 tag: O	 prediction: O True
# and			 tag: O	 prediction: O True
# romantic			 tag: O	 prediction: O True
# ?			 tag: O	 prediction: O True
# Having			 tag: O	 prediction: O True
# hunted			 tag: O	 prediction: O True
# around			 tag: O	 prediction: O True
# for			 tag: O	 prediction: O True
# a			 tag: O	 prediction: O True
# quiet			 tag: O	 prediction: O True
# ,			 tag: O	 prediction: O True
# romantic			 tag: O	 prediction: O True
# ,			 tag: O	 prediction: O True
# yet			 tag: O	 prediction: O True
# not			 tag: O	 prediction: O True
# hideously			 tag: O	 prediction: O True
# expensive			 tag: O	 prediction: O True
# restaurant			 tag: O	 prediction: B False
# I			 tag: O	 prediction: O True
# stumbled			 tag: O	 prediction: O True
# across			 tag: O	 prediction: O True
# reviews			 tag: O	 prediction: O True
# for			 tag: O	 prediction: O True
# La			 tag: O	 prediction: O True
# Lanterna			 tag: O	 prediction: O True
# and			 tag: O	 prediction: O True
# gave			 tag: O	 prediction: O True
# it			 tag: O	 prediction: O True
# a			 tag: O	 prediction: O True
# shot			 tag: O	 prediction: O True
# .			 tag: O	 prediction: O True
# I			 tag: O	 prediction: O True
# 've			 tag: O	 prediction: O True
# never			 tag: O	 prediction: O True
# been			 tag: O	 prediction: O True
# disappointed			 tag: O	 prediction: O True
# .			 tag: O	 prediction: O True
# I			 tag: O	 prediction: O True
# wo			 tag: O	 prediction: O True
# n't			 tag: O	 prediction: O True
# go			 tag: O	 prediction: O True
# back			 tag: O	 prediction: O True
# unless			 tag: O	 prediction: O True
# someone			 tag: O	 prediction: O True
# else			 tag: O	 prediction: O True
# is			 tag: O	 prediction: O True
# footing			 tag: O	 prediction: O True
# the			 tag: O	 prediction: O True
# bill			 tag: B	 prediction: O False
# .			 tag: O	 prediction: O True
# We			 tag: O	 prediction: O True
# live			 tag: O	 prediction: O True
# in			 tag: O	 prediction: O True
# New			 tag: O	 prediction: O True
# Jersey			 tag: O	 prediction: O True
# and			 tag: O	 prediction: O True
# whenever			 tag: O	 prediction: O True
# we			 tag: O	 prediction: O True
# go			 tag: O	 prediction: O True
# into			 tag: O	 prediction: O True
# New			 tag: O	 prediction: O True
# York			 tag: O	 prediction: O True
# City			 tag: O	 prediction: O True
# we			 tag: O	 prediction: O True
# buy			 tag: O	 prediction: O True
# bagels			 tag: B	 prediction: O False
# to			 tag: O	 prediction: O True
# eat			 tag: O	 prediction: O True
# hot			 tag: O	 prediction: O True
# and			 tag: O	 prediction: O True
# then			 tag: O	 prediction: O True
# to			 tag: O	 prediction: O True
# freeze			 tag: O	 prediction: O True
# (			 tag: O	 prediction: O True
# they			 tag: O	 prediction: O True
# told			 tag: O	 prediction: O True
# me			 tag: O	 prediction: O True
# that			 tag: O	 prediction: O True
# if			 tag: O	 prediction: O True
# I			 tag: O	 prediction: O True
# call			 tag: O	 prediction: O True
# in			 tag: O	 prediction: O True
# the			 tag: O	 prediction: O True
# order			 tag: O	 prediction: O True
# ,			 tag: O	 prediction: O True
# they			 tag: O	 prediction: O True
# 'd			 tag: O	 prediction: O True
# bring			 tag: O	 prediction: O True
# it			 tag: O	 prediction: O True
# out			 tag: O	 prediction: O True
# to			 tag: O	 prediction: O True
# the			 tag: O	 prediction: O True
# car			 tag: O	 prediction: O True
# so			 tag: O	 prediction: O True
# I			 tag: O	 prediction: O True
# would			 tag: O	 prediction: O True
# n't			 tag: O	 prediction: O True
# have			 tag: O	 prediction: O True
# to			 tag: O	 prediction: O True
# look			 tag: O	 prediction: O True
# for			 tag: O	 prediction: O True
# parking			 tag: O	 prediction: O True
# )			 tag: O	 prediction: O True
# .			 tag: O	 prediction: O True
# From			 tag: O	 prediction: O True
# the			 tag: O	 prediction: O True
# street			 tag: O	 prediction: O True
# it			 tag: O	 prediction: O True
# looks			 tag: O	 prediction: O True
# very			 tag: O	 prediction: O True
# hidden			 tag: O	 prediction: O True
# ,			 tag: O	 prediction: O True
# and			 tag: O	 prediction: O True
# is			 tag: O	 prediction: O True
# actually			 tag: O	 prediction: O True
# an			 tag: O	 prediction: O True
# old			 tag: O	 prediction: O True
# warehouse			 tag: O	 prediction: O True
# .			 tag: O	 prediction: O True
# Jimmy			 tag: O	 prediction: O True
# 's			 tag: O	 prediction: O True
# is			 tag: O	 prediction: O True
# hands			 tag: O	 prediction: O True
# down			 tag: O	 prediction: O True
# the			 tag: O	 prediction: O True
# hottest			 tag: O	 prediction: O True
# night			 tag: O	 prediction: B False
# spot			 tag: B	 prediction: I False
# in			 tag: O	 prediction: O True
# the			 tag: O	 prediction: O True
# Bronx			 tag: O	 prediction: O True
# .			 tag: O	 prediction: O True
# And			 tag: O	 prediction: O True
# I			 tag: O	 prediction: O True
# would			 tag: O	 prediction: O True
# have			 tag: O	 prediction: O True
# to			 tag: O	 prediction: O True
# agree			 tag: O	 prediction: O True
# with			 tag: O	 prediction: O True
# the			 tag: O	 prediction: O True
# masses			 tag: O	 prediction: O True
# in			 tag: O	 prediction: O True
# terms			 tag: O	 prediction: O True
# of			 tag: O	 prediction: O True
# service			 tag: B	 prediction: O False
# -			 tag: O	 prediction: O True
# delivery			 tag: B	 prediction: O False
# is			 tag: O	 prediction: O True
# their			 tag: O	 prediction: O True
# Achilles			 tag: O	 prediction: O True
# '			 tag: O	 prediction: O True
# heel			 tag: O	 prediction: O True
# .			 tag: O	 prediction: O True
# My			 tag: O	 prediction: O True
# boyfriend			 tag: O	 prediction: O True
# and			 tag: O	 prediction: O True
# I			 tag: O	 prediction: O True
# have			 tag: O	 prediction: O True
# been			 tag: O	 prediction: O True
# to			 tag: O	 prediction: O True
# The			 tag: O	 prediction: O True
# Minnow			 tag: O	 prediction: O True
# four			 tag: O	 prediction: O True
# times			 tag: O	 prediction: O True
# now			 tag: O	 prediction: O True
# and			 tag: O	 prediction: O True
# we			 tag: O	 prediction: O True
# have			 tag: O	 prediction: O True
# consistently			 tag: O	 prediction: O True
# been			 tag: O	 prediction: O True
# impressed			 tag: O	 prediction: O True
# .			 tag: O	 prediction: O True
# The			 tag: O	 prediction: O True
# $			 tag: O	 prediction: O True
# 300			 tag: O	 prediction: O True
# bill			 tag: B	 prediction: B True
# was			 tag: O	 prediction: O True
# a			 tag: O	 prediction: O True
# bit			 tag: O	 prediction: O True
# steep			 tag: O	 prediction: O True
# ,			 tag: O	 prediction: O True
# but			 tag: O	 prediction: O True
# the			 tag: O	 prediction: O True
# experience			 tag: O	 prediction: B False
# was			 tag: O	 prediction: O True
# great			 tag: O	 prediction: O True
# .			 tag: O	 prediction: O True
# I			 tag: O	 prediction: O True
# would			 tag: O	 prediction: O True
# n't			 tag: O	 prediction: O True
# mind			 tag: O	 prediction: O True
# going			 tag: O	 prediction: O True
# back			 tag: O	 prediction: O True
# some			 tag: O	 prediction: O True
# time			 tag: O	 prediction: O True
# ,			 tag: O	 prediction: O True
# but			 tag: O	 prediction: O True
# not			 tag: O	 prediction: O True
# before			 tag: O	 prediction: O True
# trying			 tag: O	 prediction: O True
# others			 tag: O	 prediction: O True
# nearby			 tag: O	 prediction: O True
# .			 tag: O	 prediction: O True
# Nice			 tag: O	 prediction: O True
# ambiance			 tag: B	 prediction: B True
# ,			 tag: O	 prediction: O True
# nice			 tag: O	 prediction: O True
# little			 tag: O	 prediction: O True
# bar			 tag: B	 prediction: B True
# ,			 tag: O	 prediction: O True
# good			 tag: O	 prediction: O True
# bartender			 tag: B	 prediction: B True
# ,			 tag: O	 prediction: O True
# Francois			 tag: O	 prediction: O True
# ,			 tag: O	 prediction: O True
# and			 tag: O	 prediction: O True
# good			 tag: O	 prediction: O True
# service			 tag: B	 prediction: B True
# .			 tag: O	 prediction: O True
# I			 tag: O	 prediction: O True
# found			 tag: O	 prediction: O True
# this			 tag: O	 prediction: O True
# restaurant			 tag: O	 prediction: B False
# to			 tag: O	 prediction: O True
# be			 tag: O	 prediction: O True
# one			 tag: O	 prediction: O True
# that			 tag: O	 prediction: O True
# truly			 tag: O	 prediction: O True
# values			 tag: O	 prediction: O True
# its			 tag: O	 prediction: O True
# patrons			 tag: O	 prediction: O True
# .			 tag: O	 prediction: O True
# The			 tag: O	 prediction: O True
# calamari			 tag: B	 prediction: B True
# comes			 tag: O	 prediction: O True
# with			 tag: O	 prediction: O True
# an			 tag: O	 prediction: O True
# incredible			 tag: O	 prediction: O True
# sauce			 tag: B	 prediction: O False
# ,			 tag: O	 prediction: O True
# and			 tag: O	 prediction: O True
# the			 tag: O	 prediction: O True
# duck			 tag: B	 prediction: B True
# noodles			 tag: I	 prediction: I True
# are			 tag: O	 prediction: O True
# yummy			 tag: O	 prediction: O True
# as			 tag: O	 prediction: O True
# well			 tag: O	 prediction: O True
# .			 tag: O	 prediction: O True
# I			 tag: O	 prediction: O True
# would			 tag: O	 prediction: O True
# definitely			 tag: O	 prediction: O True
# go			 tag: O	 prediction: O True
# back			 tag: O	 prediction: O True
# --			 tag: O	 prediction: O True
# if			 tag: O	 prediction: O True
# only			 tag: O	 prediction: O True
# for			 tag: O	 prediction: O True
# some			 tag: O	 prediction: O True
# of			 tag: O	 prediction: O True
# those			 tag: O	 prediction: O True
# exotic			 tag: O	 prediction: O True
# martinis			 tag: B	 prediction: O False
# on			 tag: O	 prediction: O True
# the			 tag: O	 prediction: O True
# blackboard			 tag: O	 prediction: O True
# .			 tag: O	 prediction: O True
# For			 tag: O	 prediction: O True
# some			 tag: O	 prediction: O True
# reason			 tag: O	 prediction: O True
# the			 tag: O	 prediction: O True
# place			 tag: O	 prediction: B False
# was			 tag: O	 prediction: O True
# empty			 tag: O	 prediction: O True
# when			 tag: O	 prediction: O True
# we			 tag: O	 prediction: O True
# got			 tag: O	 prediction: O True
# in			 tag: O	 prediction: O True
# and			 tag: O	 prediction: O True
# remained			 tag: O	 prediction: O True
# so			 tag: O	 prediction: O True
# for			 tag: O	 prediction: O True
# the			 tag: O	 prediction: O True
# entire			 tag: O	 prediction: O True
# evening			 tag: O	 prediction: O True
# ,			 tag: O	 prediction: O True
# I			 tag: O	 prediction: O True
# do			 tag: O	 prediction: O True
# n't			 tag: O	 prediction: O True
# understand			 tag: O	 prediction: O True
# why			 tag: O	 prediction: O True
# but			 tag: O	 prediction: O True
# we			 tag: O	 prediction: O True
# had			 tag: O	 prediction: O True
# a			 tag: O	 prediction: O True
# blast			 tag: O	 prediction: O True
# and			 tag: O	 prediction: O True
# will			 tag: O	 prediction: O True
# definately			 tag: O	 prediction: O True
# go			 tag: O	 prediction: O True
# back			 tag: O	 prediction: O True
# the			 tag: O	 prediction: O True
# next			 tag: O	 prediction: O True
# time			 tag: O	 prediction: O True
# we			 tag: O	 prediction: O True
# are			 tag: O	 prediction: O True
# in			 tag: O	 prediction: O True
# the			 tag: O	 prediction: O True
# area			 tag: O	 prediction: O True
# .			 tag: O	 prediction: O True
# Simple			 tag: O	 prediction: O True
# comfort			 tag: B	 prediction: B True
# food			 tag: I	 prediction: I True
# and			 tag: O	 prediction: O True
# what			 tag: O	 prediction: O True
# hot			 tag: O	 prediction: O True
# and			 tag: O	 prediction: O True
# lage			 tag: O	 prediction: O True
# portions			 tag: B	 prediction: B True
# .			 tag: O	 prediction: O True
# But			 tag: O	 prediction: O True
# I			 tag: O	 prediction: O True
# just			 tag: O	 prediction: O True
# would			 tag: O	 prediction: O True
# like			 tag: O	 prediction: O True
# to			 tag: O	 prediction: O True
# say			 tag: O	 prediction: O True
# I			 tag: O	 prediction: O True
# read			 tag: O	 prediction: O True
# the			 tag: O	 prediction: O True
# reviews			 tag: O	 prediction: O True
# people			 tag: O	 prediction: O True
# left			 tag: O	 prediction: O True
# and			 tag: O	 prediction: O True
# that			 tag: O	 prediction: O True
# s			 tag: O	 prediction: O True
# why			 tag: O	 prediction: O True
# I			 tag: O	 prediction: O True
# checked			 tag: O	 prediction: O True
# it			 tag: O	 prediction: O True
# out			 tag: O	 prediction: O True
# .			 tag: O	 prediction: O True
# Stay			 tag: O	 prediction: O True
# away			 tag: O	 prediction: O True
# from			 tag: O	 prediction: O True
# the			 tag: O	 prediction: O True
# two			 tag: O	 prediction: O True
# specialty			 tag: O	 prediction: O True
# rolls			 tag: B	 prediction: O False
# on			 tag: O	 prediction: O True
# the			 tag: O	 prediction: O True
# menu			 tag: B	 prediction: O False
# ,			 tag: O	 prediction: O True
# though-			 tag: O	 prediction: O True
# too			 tag: O	 prediction: O True
# much			 tag: O	 prediction: O True
# avocado			 tag: B	 prediction: B True
# and			 tag: O	 prediction: O True
# rice			 tag: B	 prediction: B True
# will			 tag: O	 prediction: O True
# fill			 tag: O	 prediction: O True
# you			 tag: O	 prediction: O True
# up			 tag: O	 prediction: O True
# right			 tag: O	 prediction: O True
# quick			 tag: O	 prediction: O True
# .			 tag: O	 prediction: O True
# I			 tag: O	 prediction: O True
# 've			 tag: O	 prediction: O True
# eaten			 tag: O	 prediction: O True
# at			 tag: O	 prediction: O True
# Pizza			 tag: O	 prediction: O True
# Gruppo			 tag: O	 prediction: O True
# a			 tag: O	 prediction: O True
# few			 tag: O	 prediction: O True
# times			 tag: O	 prediction: O True
# ,			 tag: O	 prediction: O True
# but			 tag: O	 prediction: O True
# more			 tag: O	 prediction: O True
# often			 tag: O	 prediction: O True
# I			 tag: O	 prediction: O True
# order			 tag: O	 prediction: O True
# delivery			 tag: O	 prediction: O True
# .			 tag: O	 prediction: O True
# We			 tag: O	 prediction: O True
# did			 tag: O	 prediction: O True
# n't			 tag: O	 prediction: O True
# get			 tag: O	 prediction: O True
# drink			 tag: B	 prediction: B True
# refills			 tag: I	 prediction: I True
# and			 tag: O	 prediction: O True
# she			 tag: O	 prediction: O True
# did			 tag: O	 prediction: O True
# n't			 tag: O	 prediction: O True
# even			 tag: O	 prediction: O True
# offer			 tag: O	 prediction: O True
# us			 tag: O	 prediction: O True
# the			 tag: O	 prediction: O True
# option			 tag: O	 prediction: O True
# of			 tag: O	 prediction: O True
# dessert			 tag: B	 prediction: O False
# .			 tag: O	 prediction: O True
# Beautiful			 tag: O	 prediction: O True
# experience			 tag: O	 prediction: B False
# .			 tag: O	 prediction: O True
# The			 tag: O	 prediction: O True
# bagels			 tag: B	 prediction: B True
# are			 tag: O	 prediction: O True
# also			 tag: O	 prediction: O True
# reasonably			 tag: O	 prediction: O True
# priced			 tag: B	 prediction: O False
# for			 tag: O	 prediction: O True
# NYC			 tag: O	 prediction: O True
# .			 tag: O	 prediction: O True
# If			 tag: O	 prediction: O True
# you			 tag: O	 prediction: O True
# can			 tag: O	 prediction: O True
# handle			 tag: O	 prediction: O True
# that			 tag: O	 prediction: O True
# ,			 tag: O	 prediction: O True
# it			 tag: O	 prediction: O True
# 's			 tag: O	 prediction: O True
# a			 tag: O	 prediction: O True
# great			 tag: O	 prediction: O True
# place			 tag: O	 prediction: O True
# for			 tag: O	 prediction: O True
# a			 tag: O	 prediction: O True
# business			 tag: B	 prediction: B True
# dinner			 tag: I	 prediction: I True
# ,			 tag: O	 prediction: O True
# fun			 tag: O	 prediction: O True
# with			 tag: O	 prediction: O True
# friends			 tag: O	 prediction: O True
# or			 tag: O	 prediction: O True
# simply			 tag: O	 prediction: O True
# a			 tag: O	 prediction: O True
# table			 tag: B	 prediction: B True
# for			 tag: O	 prediction: O True
# 2			 tag: O	 prediction: O True
# .			 tag: O	 prediction: O True
# Decor			 tag: B	 prediction: O False
# leaves			 tag: O	 prediction: O True
# something			 tag: O	 prediction: O True
# to			 tag: O	 prediction: O True
# be			 tag: O	 prediction: O True
# desired			 tag: O	 prediction: O True
# .			 tag: O	 prediction: O True
# Jimmy			 tag: O	 prediction: O True
# is			 tag: O	 prediction: O True
# Dominican			 tag: O	 prediction: O True
# !			 tag: O	 prediction: O True
# Also			 tag: O	 prediction: O True
# ,			 tag: O	 prediction: O True
# specify			 tag: O	 prediction: O True
# if			 tag: O	 prediction: O True
# you			 tag: O	 prediction: O True
# like			 tag: O	 prediction: O True
# your			 tag: O	 prediction: O True
# food			 tag: B	 prediction: O False
# spicy-			 tag: O	 prediction: O True
# its			 tag: O	 prediction: O True
# rather			 tag: O	 prediction: O True
# bland			 tag: O	 prediction: O True
# if			 tag: O	 prediction: O True
# you			 tag: O	 prediction: O True
# do			 tag: O	 prediction: O True
# n't			 tag: O	 prediction: O True
# .			 tag: O	 prediction: O True
# Our			 tag: O	 prediction: O True
# waiter			 tag: B	 prediction: O False
# was			 tag: O	 prediction: O True
# fine			 tag: O	 prediction: O True
# ,			 tag: O	 prediction: O True
# the			 tag: O	 prediction: O True
# place			 tag: B	 prediction: B True
# looks			 tag: O	 prediction: O True
# nice			 tag: O	 prediction: O True
# in			 tag: O	 prediction: O True
# that			 tag: O	 prediction: O True
# not			 tag: O	 prediction: O True
# -			 tag: O	 prediction: O True
# trying			 tag: O	 prediction: O True
# -			 tag: O	 prediction: O True
# too			 tag: O	 prediction: O True
# -			 tag: O	 prediction: O True
# hard			 tag: O	 prediction: O True
# way			 tag: O	 prediction: O True
# ,			 tag: O	 prediction: O True
# but			 tag: O	 prediction: O True
# at			 tag: O	 prediction: O True
# those			 tag: O	 prediction: O True
# prices			 tag: B	 prediction: O False
# ,			 tag: O	 prediction: O True
# a			 tag: O	 prediction: O True
# little			 tag: O	 prediction: O True
# more			 tag: O	 prediction: O True
# should			 tag: O	 prediction: O True
# be			 tag: O	 prediction: O True
# expected			 tag: O	 prediction: O True
# of			 tag: O	 prediction: O True
# your			 tag: O	 prediction: O True
# food			 tag: B	 prediction: O False
# .			 tag: O	 prediction: O True
# Coming			 tag: O	 prediction: O True
# from			 tag: O	 prediction: O True
# Boston			 tag: O	 prediction: O True
# this			 tag: O	 prediction: O True
# place			 tag: O	 prediction: B False
# is			 tag: O	 prediction: O True
# like			 tag: O	 prediction: O True
# Emma			 tag: O	 prediction: O True
# 's			 tag: O	 prediction: O True
# Pizza			 tag: O	 prediction: O True
# in			 tag: O	 prediction: O True
# Kendall			 tag: O	 prediction: O True
# Square			 tag: O	 prediction: O True
# in			 tag: O	 prediction: O True
# Cambridge			 tag: O	 prediction: O True
# (			 tag: O	 prediction: O True
# although			 tag: O	 prediction: O True
# they			 tag: O	 prediction: O True
# have			 tag: O	 prediction: O True
# more			 tag: O	 prediction: O True
# funky			 tag: O	 prediction: O True
# toppings			 tag: B	 prediction: O False
# !			 tag: O	 prediction: O True
# )			 tag: O	 prediction: O True
# When			 tag: O	 prediction: O True
# my			 tag: O	 prediction: O True
# husband			 tag: O	 prediction: O True
# and			 tag: O	 prediction: O True
# go			 tag: O	 prediction: O True
# there			 tag: O	 prediction: O True
# ,			 tag: O	 prediction: O True
# we			 tag: O	 prediction: O True
# spend			 tag: O	 prediction: O True
# $			 tag: O	 prediction: O True
# 60.00			 tag: O	 prediction: O True
# (			 tag: O	 prediction: O True
# have			 tag: O	 prediction: O True
# LOBSTER			 tag: B	 prediction: B True
# TAILS			 tag: I	 prediction: I True
# UMMMMM			 tag: O	 prediction: O True
# need			 tag: O	 prediction: O True
# I			 tag: O	 prediction: O True
# say			 tag: O	 prediction: O True
# more			 tag: O	 prediction: O True
# )			 tag: O	 prediction: O True
# I			 tag: O	 prediction: O True
# ca			 tag: O	 prediction: O True
# n't			 tag: O	 prediction: O True
# say			 tag: O	 prediction: O True
# any			 tag: O	 prediction: O True
# more			 tag: O	 prediction: O True
# ,			 tag: O	 prediction: O True
# it			 tag: O	 prediction: O True
# a			 tag: O	 prediction: O True
# place			 tag: B	 prediction: O False
# you			 tag: O	 prediction: O True
# 'll			 tag: O	 prediction: O True
# never			 tag: O	 prediction: O True
# forget			 tag: O	 prediction: O True
# If			 tag: O	 prediction: O True
# you			 tag: O	 prediction: O True
# never			 tag: O	 prediction: O True
# go			 tag: O	 prediction: O True
# ,			 tag: O	 prediction: O True
# you			 tag: O	 prediction: O True
# 'll			 tag: O	 prediction: O True
# miss			 tag: O	 prediction: O True
# A			 tag: O	 prediction: O True
# Meal			 tag: B	 prediction: O False
# of			 tag: O	 prediction: O True
# your			 tag: O	 prediction: O True
# life			 tag: O	 prediction: B False
# time			 tag: O	 prediction: I False
# in			 tag: O	 prediction: O True
# an			 tag: O	 prediction: O True
# effort			 tag: O	 prediction: O True
# to			 tag: O	 prediction: O True
# increase			 tag: O	 prediction: O True
# turnover			 tag: O	 prediction: O True
# ,			 tag: O	 prediction: O True
# the			 tag: O	 prediction: O True
# restaurant			 tag: O	 prediction: B False
# offers			 tag: O	 prediction: O True
# no			 tag: O	 prediction: O True
# desserts			 tag: B	 prediction: O False
# beyond			 tag: O	 prediction: O True
# the			 tag: O	 prediction: O True
# complimentary			 tag: O	 prediction: O True
# espresso			 tag: B	 prediction: B True
# cup			 tag: I	 prediction: I True
# filled			 tag: I	 prediction: I True
# with			 tag: I	 prediction: I True
# chocolate			 tag: I	 prediction: I True
# mousse			 tag: I	 prediction: I True
# .			 tag: O	 prediction: O True
# I			 tag: O	 prediction: O True
# 've			 tag: O	 prediction: O True
# been			 tag: O	 prediction: O True
# to			 tag: O	 prediction: O True
# this			 tag: O	 prediction: O True
# restaurant			 tag: O	 prediction: O True
# more			 tag: O	 prediction: O True
# than			 tag: O	 prediction: O True
# a			 tag: O	 prediction: O True
# dozen			 tag: O	 prediction: O True
# times			 tag: O	 prediction: O True
# and			 tag: O	 prediction: O True
# when			 tag: O	 prediction: O True
# I			 tag: O	 prediction: O True
# 'm			 tag: O	 prediction: O True
# craving			 tag: O	 prediction: O True
# for			 tag: O	 prediction: O True
# Pho			 tag: B	 prediction: O False
# ,			 tag: O	 prediction: O True
# Lemon			 tag: B	 prediction: B True
# grass			 tag: I	 prediction: I True
# chicken			 tag: I	 prediction: I True
# or			 tag: O	 prediction: O True
# Beef			 tag: B	 prediction: B True
# Cube			 tag: I	 prediction: I True
# on			 tag: I	 prediction: I True
# rice			 tag: I	 prediction: I True
# ,			 tag: O	 prediction: O True
# this			 tag: O	 prediction: O True
# is			 tag: O	 prediction: O True
# the			 tag: O	 prediction: O True
# place			 tag: O	 prediction: O True
# to			 tag: O	 prediction: O True
# go			 tag: O	 prediction: O True
# .			 tag: O	 prediction: O True
# Oh			 tag: O	 prediction: O True
# yes			 tag: O	 prediction: O True
# ,			 tag: O	 prediction: O True
# and			 tag: O	 prediction: O True
# if			 tag: O	 prediction: O True
# you			 tag: O	 prediction: O True
# are			 tag: O	 prediction: O True
# a			 tag: O	 prediction: O True
# fan			 tag: O	 prediction: O True
# of			 tag: O	 prediction: O True
# Indian			 tag: O	 prediction: O True
# oldies			 tag: O	 prediction: B False
# film			 tag: O	 prediction: I False
# stars			 tag: O	 prediction: I False
# ,			 tag: O	 prediction: O True
# there			 tag: O	 prediction: O True
# are			 tag: O	 prediction: O True
# plenty			 tag: O	 prediction: O True
# of			 tag: O	 prediction: O True
# portraits			 tag: B	 prediction: O False
# of			 tag: O	 prediction: O True
# Indian			 tag: O	 prediction: O True
# actors			 tag: O	 prediction: O True
# and			 tag: O	 prediction: O True
# actresses			 tag: O	 prediction: B False
# in			 tag: O	 prediction: O True
# classic			 tag: O	 prediction: O True
# black			 tag: O	 prediction: O True
# white			 tag: O	 prediction: O True
# that			 tag: O	 prediction: O True
# adorn			 tag: O	 prediction: O True
# the			 tag: O	 prediction: O True
# walls			 tag: O	 prediction: O True
# ,			 tag: O	 prediction: O True
# some			 tag: O	 prediction: O True
# of			 tag: O	 prediction: O True
# which			 tag: O	 prediction: O True
# ,			 tag: O	 prediction: O True
# I			 tag: O	 prediction: O True
# would			 tag: O	 prediction: O True
# love			 tag: O	 prediction: O True
# to			 tag: O	 prediction: O True
# know			 tag: O	 prediction: O True
# where			 tag: O	 prediction: O True
# they			 tag: O	 prediction: O True
# obtained			 tag: O	 prediction: O True
# .			 tag: O	 prediction: O True
# The			 tag: O	 prediction: O True
# food			 tag: B	 prediction: B True
# is			 tag: O	 prediction: O True
# spectacular			 tag: O	 prediction: O True
# ,			 tag: O	 prediction: O True
# from			 tag: O	 prediction: O True
# the			 tag: O	 prediction: O True
# appitizers			 tag: B	 prediction: O False
# to			 tag: O	 prediction: O True
# the			 tag: O	 prediction: O True
# main			 tag: B	 prediction: O False
# course			 tag: I	 prediction: O False
# ,			 tag: O	 prediction: O True
# and			 tag: O	 prediction: O True
# then			 tag: O	 prediction: O True
# of			 tag: O	 prediction: O True
# course			 tag: O	 prediction: O True
# the			 tag: O	 prediction: O True
# desserts			 tag: B	 prediction: B True
# ,			 tag: O	 prediction: O True
# (			 tag: O	 prediction: O True
# WOW			 tag: O	 prediction: O True
# )			 tag: O	 prediction: O True
# you			 tag: O	 prediction: O True
# 'll			 tag: O	 prediction: O True
# need			 tag: O	 prediction: O True
# no			 tag: O	 prediction: O True
# more			 tag: O	 prediction: O True
# .			 tag: O	 prediction: O True
# The			 tag: O	 prediction: O True
# neighborhood			 tag: O	 prediction: B False
# was			 tag: O	 prediction: O True
# nice			 tag: O	 prediction: O True
# though			 tag: O	 prediction: O True
# so			 tag: O	 prediction: O True
# check			 tag: O	 prediction: O True
# out			 tag: O	 prediction: O True
# another			 tag: O	 prediction: O True
# restaurant			 tag: O	 prediction: O True
# instead			 tag: O	 prediction: O True
# .			 tag: O	 prediction: O True
# My			 tag: O	 prediction: O True
# fish			 tag: B	 prediction: O False
# was			 tag: O	 prediction: O True
# delicious			 tag: O	 prediction: O True
# in			 tag: O	 prediction: O True
# an			 tag: O	 prediction: O True
# incredible			 tag: O	 prediction: O True
# curry			 tag: B	 prediction: B True
# sauce			 tag: I	 prediction: I True
# .			 tag: O	 prediction: O True
# If			 tag: O	 prediction: O True
# you			 tag: O	 prediction: O True
# are			 tag: O	 prediction: O True
# in			 tag: O	 prediction: O True
# search			 tag: O	 prediction: O True
# of			 tag: O	 prediction: O True
# the			 tag: O	 prediction: O True
# most			 tag: O	 prediction: O True
# authentic			 tag: O	 prediction: O True
# NYC			 tag: O	 prediction: O True
# deli			 tag: B	 prediction: O False
# experience			 tag: O	 prediction: O True
# look			 tag: O	 prediction: O True
# no			 tag: O	 prediction: O True
# further			 tag: O	 prediction: O True
# than			 tag: O	 prediction: O True
# the			 tag: O	 prediction: O True
# famous			 tag: O	 prediction: O True
# and			 tag: O	 prediction: O True
# historic			 tag: O	 prediction: O True
# Katz			 tag: O	 prediction: O True
# 's			 tag: O	 prediction: O True
# Deli			 tag: O	 prediction: O True
# down			 tag: O	 prediction: O True
# on			 tag: O	 prediction: O True
# the			 tag: O	 prediction: O True
# Lower			 tag: O	 prediction: O True
# East			 tag: O	 prediction: O True
# Side			 tag: O	 prediction: O True
# .			 tag: O	 prediction: O True
# Even			 tag: O	 prediction: O True
# upon			 tag: O	 prediction: O True
# delivery			 tag: O	 prediction: O True
# ,			 tag: O	 prediction: O True
# their			 tag: O	 prediction: O True
# juicy			 tag: O	 prediction: O True
# pork			 tag: B	 prediction: B True
# buns			 tag: I	 prediction: I True
# are			 tag: O	 prediction: O True
# quite			 tag: O	 prediction: O True
# good			 tag: O	 prediction: O True
# .			 tag: O	 prediction: O True
# .			 tag: O	 prediction: O True
# This			 tag: O	 prediction: O True
# is			 tag: O	 prediction: O True
# also			 tag: O	 prediction: O True
# where			 tag: O	 prediction: O True
# I			 tag: O	 prediction: O True
# was			 tag: O	 prediction: O True
# from			 tag: O	 prediction: O True
# .			 tag: O	 prediction: O True
# Everything			 tag: O	 prediction: B False
# is			 tag: O	 prediction: O True
# for			 tag: O	 prediction: O True
# sale			 tag: O	 prediction: O True
# in			 tag: O	 prediction: O True
# here			 tag: O	 prediction: O True
# including			 tag: O	 prediction: O True
# the			 tag: O	 prediction: O True
# sculptured			 tag: O	 prediction: O True
# iron			 tag: O	 prediction: B False
# statue			 tag: O	 prediction: I False
# on			 tag: O	 prediction: O True
# the			 tag: O	 prediction: O True
# table			 tag: O	 prediction: O True
# .			 tag: O	 prediction: O True
# Average			 tag: O	 prediction: O True
# to			 tag: O	 prediction: O True
# good			 tag: O	 prediction: O True
# Thai			 tag: B	 prediction: O False
# food			 tag: I	 prediction: O False
# ,			 tag: O	 prediction: O True
# but			 tag: O	 prediction: O True
# terrible			 tag: O	 prediction: O True
# delivery			 tag: B	 prediction: B True
# .			 tag: O	 prediction: O True
# The			 tag: O	 prediction: O True
# space			 tag: B	 prediction: B True
# is			 tag: O	 prediction: O True
# nice			 tag: O	 prediction: O True
# but			 tag: O	 prediction: O True
# when			 tag: O	 prediction: O True
# we			 tag: O	 prediction: O True
# order			 tag: O	 prediction: O True
# our			 tag: O	 prediction: O True
# drink			 tag: B	 prediction: O False
# we			 tag: O	 prediction: O True
# were			 tag: O	 prediction: O True
# in			 tag: O	 prediction: O True
# for			 tag: O	 prediction: O True
# a			 tag: O	 prediction: O True
# surprise			 tag: O	 prediction: O True
# .			 tag: O	 prediction: O True
# The			 tag: O	 prediction: O True
# entire			 tag: O	 prediction: B False
# place			 tag: B	 prediction: I False
# and			 tag: O	 prediction: O True
# the			 tag: O	 prediction: O True
# treatment			 tag: O	 prediction: B False
# we			 tag: O	 prediction: O True
# received			 tag: O	 prediction: O True
# felt			 tag: O	 prediction: O True
# as			 tag: O	 prediction: O True
# a			 tag: O	 prediction: O True
# conveyor			 tag: O	 prediction: O True
# belt			 tag: O	 prediction: O True
# .			 tag: O	 prediction: O True
# Joe			 tag: O	 prediction: O True
# 's			 tag: O	 prediction: O True
# Pizza			 tag: O	 prediction: O True
# used			 tag: O	 prediction: O True
# to			 tag: O	 prediction: O True
# have			 tag: O	 prediction: O True
# the			 tag: O	 prediction: O True
# best			 tag: O	 prediction: O True
# slice			 tag: B	 prediction: B True
# until			 tag: O	 prediction: O True
# this			 tag: O	 prediction: O True
# pizzeria			 tag: O	 prediction: B False
# opened			 tag: O	 prediction: O True
# up			 tag: O	 prediction: O True
# .			 tag: O	 prediction: O True
# I			 tag: O	 prediction: O True
# in			 tag: O	 prediction: O True
# all			 tag: O	 prediction: O True
# reality			 tag: O	 prediction: O True
# felt			 tag: O	 prediction: O True
# as			 tag: O	 prediction: O True
# if			 tag: O	 prediction: O True
# I			 tag: O	 prediction: O True
# had			 tag: O	 prediction: O True
# just			 tag: O	 prediction: O True
# gotten			 tag: O	 prediction: O True
# off			 tag: O	 prediction: O True
# Air			 tag: O	 prediction: O True
# France			 tag: O	 prediction: O True
# and			 tag: O	 prediction: O True
# ...
# was			 tag: O	 prediction: O True
# available			 tag: O	 prediction: O True
# .			 tag: O	 prediction: O True
# The			 tag: O	 prediction: O True
# restaraurant			 tag: O	 prediction: B False
# is			 tag: O	 prediction: O True
# very			 tag: O	 prediction: O True
# small			 tag: O	 prediction: O True
# so			 tag: O	 prediction: O True
# reservations			 tag: B	 prediction: B True
# are			 tag: O	 prediction: O True
# a			 tag: O	 prediction: O True
# must			 tag: O	 prediction: O True
# .			 tag: O	 prediction: O True
# Visited			 tag: O	 prediction: O True
# there			 tag: O	 prediction: O True
# while			 tag: O	 prediction: O True
# on			 tag: O	 prediction: O True
# vacation			 tag: O	 prediction: O True
# and			 tag: O	 prediction: O True
# reading			 tag: O	 prediction: O True
# the			 tag: O	 prediction: O True
# reviews			 tag: O	 prediction: O True
# .			 tag: O	 prediction: O True
# A			 tag: O	 prediction: O True
# one			 tag: O	 prediction: O True
# women			 tag: O	 prediction: O True
# show			 tag: O	 prediction: O True
# !			 tag: O	 prediction: O True
# You			 tag: O	 prediction: O True
# ca			 tag: O	 prediction: O True
# n't			 tag: O	 prediction: O True
# go			 tag: O	 prediction: O True
# wrong			 tag: O	 prediction: O True
# here			 tag: O	 prediction: O True
# .			 tag: O	 prediction: O True
# At			 tag: O	 prediction: O True
# first			 tag: O	 prediction: O True
# i			 tag: O	 prediction: O True
# was			 tag: O	 prediction: O True
# rolling			 tag: O	 prediction: O True
# my			 tag: O	 prediction: O True
# ideas			 tag: O	 prediction: O True
# of			 tag: O	 prediction: O True
# yet			 tag: O	 prediction: O True
# another			 tag: O	 prediction: O True
# French			 tag: O	 prediction: O True
# place			 tag: O	 prediction: O True
# on			 tag: O	 prediction: O True
# the			 tag: O	 prediction: O True
# UES			 tag: O	 prediction: O True
# .			 tag: O	 prediction: O True
# To			 tag: O	 prediction: O True
# my			 tag: O	 prediction: O True
# right			 tag: O	 prediction: O True
# ,			 tag: O	 prediction: O True
# the			 tag: O	 prediction: O True
# hostess			 tag: B	 prediction: B True
# stood			 tag: O	 prediction: O True
# over			 tag: O	 prediction: O True
# a			 tag: O	 prediction: O True
# busboy			 tag: B	 prediction: O False
# and			 tag: O	 prediction: O True
# hissed			 tag: O	 prediction: O True
# rapido			 tag: O	 prediction: B False
# ,			 tag: O	 prediction: O True
# rapido			 tag: O	 prediction: B False
# as			 tag: O	 prediction: O True
# he			 tag: O	 prediction: O True
# tried			 tag: O	 prediction: O True
# to			 tag: O	 prediction: O True
# clear			 tag: O	 prediction: O True
# and			 tag: O	 prediction: O True
# re			 tag: O	 prediction: O True
# -			 tag: O	 prediction: O True
# set			 tag: O	 prediction: O True
# a			 tag: O	 prediction: O True
# table			 tag: B	 prediction: B True
# for			 tag: O	 prediction: O True
# six			 tag: O	 prediction: O True
# .			 tag: O	 prediction: O True
# In			 tag: O	 prediction: O True
# China			 tag: O	 prediction: O True
# the			 tag: O	 prediction: O True
# phrase			 tag: O	 prediction: B False
# for			 tag: O	 prediction: O True
# a			 tag: O	 prediction: O True
# good			 tag: O	 prediction: B False
# restaurant			 tag: O	 prediction: I False
# is			 tag: O	 prediction: O True
# hot			 tag: O	 prediction: O True
# and			 tag: O	 prediction: O True
# loud			 tag: O	 prediction: O True
# .			 tag: O	 prediction: O True
# After			 tag: O	 prediction: O True
# dealing			 tag: O	 prediction: O True
# with			 tag: O	 prediction: O True
# subpar			 tag: O	 prediction: O True
# pizza			 tag: B	 prediction: O False
# all			 tag: O	 prediction: O True
# over			 tag: O	 prediction: O True
# the			 tag: O	 prediction: O True
# Kensington			 tag: O	 prediction: O True
# neighborhood			 tag: O	 prediction: O True
# -			 tag: O	 prediction: O True
# I			 tag: O	 prediction: O True
# 've			 tag: O	 prediction: O True
# found			 tag: O	 prediction: O True
# little			 tag: O	 prediction: O True
# toninos			 tag: O	 prediction: B False
# .			 tag: O	 prediction: O True
# I			 tag: O	 prediction: O True
# thought			 tag: O	 prediction: O True
# this			 tag: O	 prediction: O True
# place			 tag: O	 prediction: B False
# was			 tag: O	 prediction: O True
# totally			 tag: O	 prediction: O True
# overrated			 tag: O	 prediction: O True
# .			 tag: O	 prediction: O True
# then			 tag: O	 prediction: O True
# we			 tag: O	 prediction: O True
# ordered			 tag: O	 prediction: O True
# a			 tag: O	 prediction: O True
# dinosaur			 tag: B	 prediction: B True
# rolls			 tag: I	 prediction: I True
# and			 tag: O	 prediction: O True
# white			 tag: B	 prediction: O False
# tuna			 tag: I	 prediction: B False
# sashimi			 tag: I	 prediction: I True
# .			 tag: O	 prediction: O True
# You			 tag: O	 prediction: O True
# wo			 tag: O	 prediction: O True
# n't			 tag: O	 prediction: O True
# find			 tag: O	 prediction: O True
# that			 tag: O	 prediction: O True
# anywhere			 tag: O	 prediction: O True
# in			 tag: O	 prediction: O True
# Manhattan			 tag: O	 prediction: O True
# .			 tag: O	 prediction: O True
# How			 tag: O	 prediction: O True
# do			 tag: O	 prediction: O True
# you			 tag: O	 prediction: O True
# rate			 tag: O	 prediction: O True
# home			 tag: O	 prediction: O True
# ?			 tag: O	 prediction: O True
# I			 tag: O	 prediction: O True
# went			 tag: O	 prediction: O True
# here			 tag: O	 prediction: O True
# in			 tag: O	 prediction: O True
# the			 tag: O	 prediction: O True
# afternoon			 tag: O	 prediction: O True
# with			 tag: O	 prediction: O True
# a			 tag: O	 prediction: O True
# friend			 tag: O	 prediction: O True
# .			 tag: O	 prediction: O True
# Our			 tag: O	 prediction: O True
# first			 tag: O	 prediction: O True
# greeting			 tag: O	 prediction: O True
# when			 tag: O	 prediction: O True
# we			 tag: O	 prediction: O True
# entered			 tag: O	 prediction: O True
# was			 tag: O	 prediction: O True
# The			 tag: O	 prediction: O True
# last			 tag: O	 prediction: O True
# call			 tag: O	 prediction: B False
# is			 tag: O	 prediction: O True
# at			 tag: O	 prediction: O True
# 10:15			 tag: O	 prediction: O True
# .			 tag: O	 prediction: O True
# Interior			 tag: O	 prediction: O True
# was			 tag: O	 prediction: O True
# so			 tag: O	 prediction: O True
# so			 tag: O	 prediction: O True
# .			 tag: O	 prediction: O True
# I			 tag: O	 prediction: O True
# 'm			 tag: O	 prediction: O True
# partial			 tag: O	 prediction: O True
# to			 tag: O	 prediction: O True
# the			 tag: O	 prediction: O True
# Gnocchi			 tag: B	 prediction: O False
# .			 tag: O	 prediction: O True
# I			 tag: O	 prediction: O True
# guess			 tag: O	 prediction: O True
# the			 tag: O	 prediction: O True
# way			 tag: O	 prediction: O True
# my			 tag: O	 prediction: O True
# friends			 tag: O	 prediction: O True
# and			 tag: O	 prediction: O True
# I			 tag: O	 prediction: O True
# described			 tag: O	 prediction: O True
# it			 tag: O	 prediction: O True
# was			 tag: O	 prediction: O True
# The			 tag: O	 prediction: O True
# French			 tag: O	 prediction: O True
# Colonies			 tag: O	 prediction: O True
# .			 tag: O	 prediction: O True
# they			 tag: O	 prediction: O True
# were			 tag: O	 prediction: O True
# able			 tag: O	 prediction: O True
# to			 tag: O	 prediction: O True
# squeeze			 tag: O	 prediction: O True
# me			 tag: O	 prediction: O True
# in			 tag: O	 prediction: O True
# at			 tag: O	 prediction: O True
# 6			 tag: O	 prediction: O True
# after			 tag: O	 prediction: O True
# i			 tag: O	 prediction: O True
# called			 tag: O	 prediction: O True
# the			 tag: O	 prediction: O True
# night			 tag: O	 prediction: B False
# before			 tag: O	 prediction: O True
# my			 tag: O	 prediction: O True
# anniversary			 tag: O	 prediction: O True
# for			 tag: O	 prediction: O True
# a			 tag: O	 prediction: O True
# friday			 tag: O	 prediction: B False
# night			 tag: O	 prediction: I False
# reservation			 tag: B	 prediction: I False
# and			 tag: O	 prediction: O True
# told			 tag: O	 prediction: O True
# me			 tag: O	 prediction: O True
# they			 tag: O	 prediction: O True
# 'd			 tag: O	 prediction: O True
# treat			 tag: O	 prediction: O True
# us			 tag: O	 prediction: O True
# well			 tag: O	 prediction: O True
# for			 tag: O	 prediction: O True
# the			 tag: O	 prediction: O True
# occasion			 tag: O	 prediction: O True
# .			 tag: O	 prediction: O True
# Boy			 tag: O	 prediction: O True
# was			 tag: O	 prediction: O True
# I			 tag: O	 prediction: O True
# wrong			 tag: O	 prediction: O True
# !			 tag: O	 prediction: O True
# I			 tag: O	 prediction: O True
# visit			 tag: O	 prediction: O True
# New			 tag: O	 prediction: O True
# Green			 tag: O	 prediction: O True
# Bo			 tag: O	 prediction: O True
# when			 tag: O	 prediction: O True
# I			 tag: O	 prediction: O True
# have			 tag: O	 prediction: O True
# money			 tag: O	 prediction: O True
# or			 tag: O	 prediction: O True
# when			 tag: O	 prediction: O True
# I			 tag: O	 prediction: O True
# am			 tag: O	 prediction: O True
# broke			 tag: O	 prediction: O True
# .			 tag: O	 prediction: O True
# Note			 tag: O	 prediction: O True
# that			 tag: O	 prediction: O True
# they			 tag: O	 prediction: O True
# do			 tag: O	 prediction: O True
# not			 tag: O	 prediction: O True
# serve			 tag: O	 prediction: O True
# beer			 tag: B	 prediction: O False
# ,			 tag: O	 prediction: O True
# you			 tag: O	 prediction: O True
# must			 tag: O	 prediction: O True
# bring			 tag: O	 prediction: O True
# your			 tag: O	 prediction: O True
# own			 tag: O	 prediction: O True
# .			 tag: O	 prediction: O True
# We			 tag: O	 prediction: O True
# ate			 tag: O	 prediction: O True
# outside			 tag: O	 prediction: O True
# at			 tag: O	 prediction: O True
# Haru			 tag: O	 prediction: O True
# 's			 tag: O	 prediction: O True
# Sake			 tag: O	 prediction: O True
# bar			 tag: B	 prediction: O False
# because			 tag: O	 prediction: O True
# Haru			 tag: O	 prediction: O True
# 's			 tag: O	 prediction: O True
# restaurant			 tag: O	 prediction: O True
# next			 tag: O	 prediction: O True
# door			 tag: O	 prediction: O True
# was			 tag: O	 prediction: O True
# overflowing			 tag: O	 prediction: O True
# .			 tag: O	 prediction: O True
# When			 tag: O	 prediction: O True
# we			 tag: O	 prediction: O True
# walked			 tag: O	 prediction: O True
# in			 tag: O	 prediction: O True
# it			 tag: O	 prediction: O True
# seemed			 tag: O	 prediction: O True
# like			 tag: O	 prediction: O True
# it			 tag: O	 prediction: O True
# was			 tag: O	 prediction: O True
# there			 tag: O	 prediction: O True
# for			 tag: O	 prediction: O True
# 200			 tag: O	 prediction: O True
# years			 tag: O	 prediction: O True
# .			 tag: O	 prediction: O True
# Ahhh			 tag: O	 prediction: O True
# ...			 tag: O	 prediction: O True
# Better			 tag: O	 prediction: O True
# than			 tag: O	 prediction: O True
# the			 tag: O	 prediction: O True
# bagel			 tag: O	 prediction: B False
# shop			 tag: O	 prediction: I False
# on			 tag: O	 prediction: O True
# the			 tag: O	 prediction: O True
# corner			 tag: O	 prediction: O True
# ,			 tag: O	 prediction: O True
# but			 tag: O	 prediction: O True
# not			 tag: O	 prediction: O True
# worth			 tag: O	 prediction: O True
# going			 tag: O	 prediction: O True
# out			 tag: O	 prediction: O True
# of			 tag: O	 prediction: O True
# your			 tag: O	 prediction: O True
# way			 tag: O	 prediction: O True
# for			 tag: O	 prediction: O True
# ,			 tag: O	 prediction: O True
# in			 tag: O	 prediction: O True
# my			 tag: O	 prediction: O True
# opinion			 tag: O	 prediction: O True
# .			 tag: O	 prediction: O True
# it			 tag: O	 prediction: O True
# helps			 tag: O	 prediction: O True
# if			 tag: O	 prediction: O True
# you			 tag: O	 prediction: O True
# know			 tag: O	 prediction: O True
# what			 tag: O	 prediction: O True
# to			 tag: O	 prediction: O True
# order			 tag: O	 prediction: O True
# .			 tag: O	 prediction: O True
# The			 tag: O	 prediction: O True
# service			 tag: B	 prediction: B True
# was			 tag: O	 prediction: O True
# typical			 tag: O	 prediction: O True
# short			 tag: O	 prediction: O True
# -			 tag: O	 prediction: O True
# order			 tag: O	 prediction: O True
# ,			 tag: O	 prediction: O True
# dinner			 tag: O	 prediction: B False
# type			 tag: O	 prediction: I False
# .			 tag: O	 prediction: O True
# We			 tag: O	 prediction: O True
# shared			 tag: O	 prediction: O True
# a			 tag: O	 prediction: O True
# bottle			 tag: B	 prediction: O False
# of			 tag: I	 prediction: O False
# sake			 tag: I	 prediction: O False
# ,			 tag: O	 prediction: O True
# an			 tag: O	 prediction: O True
# order			 tag: O	 prediction: B False
# of			 tag: O	 prediction: O True
# edamames			 tag: B	 prediction: O False
# ,			 tag: O	 prediction: O True
# and			 tag: O	 prediction: O True
# she			 tag: O	 prediction: O True
# had			 tag: O	 prediction: O True
# the			 tag: O	 prediction: O True
# sushi			 tag: B	 prediction: B True
# plate			 tag: I	 prediction: I True
# while			 tag: O	 prediction: O True
# I			 tag: O	 prediction: O True
# had			 tag: O	 prediction: O True
# the			 tag: O	 prediction: O True
# sashimi			 tag: B	 prediction: B True
# .			 tag: O	 prediction: O True
# I			 tag: O	 prediction: O True
# ca			 tag: O	 prediction: O True
# n't			 tag: O	 prediction: O True
# believe			 tag: O	 prediction: O True
# people			 tag: O	 prediction: O True
# complain			 tag: O	 prediction: O True
# about			 tag: O	 prediction: O True
# no			 tag: O	 prediction: O True
# cheese			 tag: B	 prediction: O False
# sticks			 tag: I	 prediction: O False
# ?			 tag: O	 prediction: O True
# But			 tag: O	 prediction: O True
# that			 tag: O	 prediction: O True
# is			 tag: O	 prediction: O True
# highly			 tag: O	 prediction: O True
# forgivable			 tag: O	 prediction: O True
# .			 tag: O	 prediction: O True
# From			 tag: O	 prediction: O True
# the			 tag: O	 prediction: O True
# appetizers			 tag: B	 prediction: O False
# we			 tag: O	 prediction: O True
# ate			 tag: O	 prediction: O True
# ,			 tag: O	 prediction: O True
# the			 tag: O	 prediction: O True
# dim			 tag: B	 prediction: O False
# sum			 tag: I	 prediction: O False
# and			 tag: O	 prediction: O True
# other			 tag: O	 prediction: O True
# variety			 tag: O	 prediction: B False
# of			 tag: O	 prediction: O True
# foods			 tag: B	 prediction: O False
# ,			 tag: O	 prediction: O True
# it			 tag: O	 prediction: O True
# was			 tag: O	 prediction: O True
# impossible			 tag: O	 prediction: O True
# to			 tag: O	 prediction: O True
# criticize			 tag: O	 prediction: O True
# the			 tag: O	 prediction: O True
# food			 tag: B	 prediction: O False
# .			 tag: O	 prediction: O True
# When			 tag: O	 prediction: O True
# we			 tag: O	 prediction: O True
# arrived			 tag: O	 prediction: O True
# at			 tag: O	 prediction: O True
# 6:00			 tag: O	 prediction: O True
# PM			 tag: O	 prediction: O True
# ,			 tag: O	 prediction: O True
# the			 tag: O	 prediction: O True
# restaurant			 tag: O	 prediction: B False
# was			 tag: O	 prediction: O True
# practically			 tag: O	 prediction: O True
# empty			 tag: O	 prediction: O True
# .			 tag: O	 prediction: O True
# Each			 tag: O	 prediction: O True
# table			 tag: B	 prediction: B True
# has			 tag: O	 prediction: O True
# a			 tag: O	 prediction: O True
# pot			 tag: B	 prediction: B True
# of			 tag: I	 prediction: I True
# boiling			 tag: I	 prediction: I True
# water			 tag: I	 prediction: I True
# sunken			 tag: O	 prediction: O True
# into			 tag: O	 prediction: O True
# its			 tag: O	 prediction: O True
# surface			 tag: O	 prediction: O True
# ,			 tag: O	 prediction: O True
# and			 tag: O	 prediction: O True
# you			 tag: O	 prediction: O True
# get			 tag: O	 prediction: O True
# platters			 tag: O	 prediction: B False
# of			 tag: O	 prediction: I False
# thin			 tag: O	 prediction: I False
# sliced			 tag: O	 prediction: I False
# meats			 tag: B	 prediction: I False
# ,			 tag: O	 prediction: O True
# various			 tag: O	 prediction: O True
# vegetables			 tag: B	 prediction: B True
# ,			 tag: O	 prediction: O True
# and			 tag: O	 prediction: O True
# rice			 tag: B	 prediction: B True
# and			 tag: O	 prediction: I False
# glass			 tag: B	 prediction: I False
# noodles			 tag: I	 prediction: I True
# .			 tag: O	 prediction: O True
# I			 tag: O	 prediction: O True
# am			 tag: O	 prediction: O True
# going			 tag: O	 prediction: O True
# to			 tag: O	 prediction: O True
# the			 tag: O	 prediction: O True
# mid			 tag: O	 prediction: O True
# town			 tag: O	 prediction: B False
# location			 tag: O	 prediction: I False
# next			 tag: O	 prediction: O True
# .			 tag: O	 prediction: O True

# %% [markdown]
# Next: which features were most important in making our predictions?

# %%
from collections import Counter

def print_state_features(state_features):
    for (attr, label), weight in state_features:
        print("%0.6f %-8s %s" % (weight, label, attr))

print("Top positive:")
print_state_features(Counter(crf.state_features_).most_common(15))

print("\nTop negative:")
print_state_features(Counter(crf.state_features_).most_common()[-15:])
# Out:
# Top positive:
# 4.515974 O        tag:.
# 3.587735 O        pos:PRON
# 2.810508 O        pos:DET
# 2.729803 B        tag:``
# 2.638645 O        dep:aux
# 2.289212 O        -1: dep:quantmod
# 2.243440 O        tag:JJS
# 2.206088 O        -1: tag:VBZ
# 2.191445 O        is_punct
# 2.164092 O        pos:CCONJ
# 2.164092 O        tag:CC
# 2.144207 I        -2: tag:JJS
# 2.134981 O        dep:auxpass
# 2.066429 I        tag:-RRB-
# 2.021199 B        -3: dep:csubjpass
#
# Top negative:
# -1.182835 B        -1: dep:aux
# -1.191195 I        pos:ADV
# -1.193424 B        dep:det
# -1.247642 B        pos:DET
# -1.278350 B        -1: dep:mark
# -1.329944 O        tag:VBN
# -1.414571 B        -1: dep:case
# -1.517487 I        -1: tag:-RRB-
# -1.585555 B        is_punct
# -1.716770 I        dep:poss
# -1.724424 I        dep:amod
# -1.901046 B        -2: dep:subtok
# -1.930212 O        tag:-RRB-
# -2.047419 I        pos:VERB
# -2.559037 B        dep:prep

# %% [markdown]
# OK, this is an improvement on last time.  We can see that the features surrounding the token are useful in predicting its tag.
